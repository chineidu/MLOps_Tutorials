# %% [markdown]
# # Week 2 Day 2
#
# # SQL (Continued)
#
# * [Cheatsheet 1](https://www.sqltutorial.org/sql-cheat-sheet/)
# * [Cheatsheet 2](https://www.datacamp.com/cheat-sheet/sql-basics-cheat-sheet)
#
# ## Objectives
#
# ### 1. Connecting To Postgres With Python
#
# ### Installing psycopg2
#
# * Use the command below:
#
# ```bash
# pip install psycopg2-binary
# ```
#
# <br>
#
#
# The following keywords/statements will be covered
#
# ### 2. Aggregate Functions
#
# * `AVG()`
#
# * `MIN()`
#
# * `MAX()`
#
# * `COUNT()`
#
# * `SUM()`
#
# ### Other Statements
# * `GROUP BY`
# * `HAVING`
# * `CASE`

# %%
# Import 3rd party libararies
import pandas as pd

# Import builtin modules
import sqlite3
import json
from typing import List, Tuple, Dict, Union, Optional


import psycopg2  # Postgres Python Connector

# Black code formatter (Optional. You can comment this!)
# %load_ext lab_black

# %%
# Load file
fp = "secret.json"

with open(fp, "r") as file:
    secret = json.load(file)

# %%
secrets_ = {
    "dbname": "myDB",
    "user": "postgres",
    "password": "password",
    "host": "localhost",
    "port": "5432",
}

secrets_
# Out:
# {'dbname': 'myDB',
#  'user': 'postgres',
#  'password': 'password',
#  'host': 'localhost',
#  'port': '5432'}

# %% [markdown]
# ### Connect To A Postgres DB  (Method 1)
#
# ```shell
# pip install psycopg2
# ```
#
# * [Docs](https://docs.sqlalchemy.org/en/20/core/engines.html#database-urls)
#
# ```Python
# # Connect to your postgres DB
# conn = psycopg2.connect("dbname=db_name user=postgres password=enter_your_password")
#
# # OR
# conn = psycopg2.connect(dbname="db_name",
#                         user="postgres",
#                         password="enter_your_password")
#
# # Open a cursor to perform database operations
# cursor = conn.cursor()
#
# # Execute a query
# cursor.execute("SELECT * FROM table_name")
#
# # Retrieve query results
# records = cursor.fetchall()
# records
# ```

# %% [raw]
# conn = psycopg2.connect(dbname="db_name",
#                         user="postgres",
#                         password="enter_your_password")

# %%
def random_function(
    Course: str, Instructor: str, Time: str, Date: str, Duration: str
) -> dict:
    result = dict()
    # Add the key-value pairs
    result["Course"] = Course
    result["Instructor"] = Instructor
    result["Time"] = Time
    result["Date"] = Date
    result["Duration"] = Duration
    result["Message"] = "Success!"
    return result

# %%
random_function(
    Course="Data Science",
    Instructor="Adam",
    Time="1PM",
    Date="Feb 14, 2023",
    Duration="2 hours",
)
# Out:
# {'Course': 'Data Science',
#  'Instructor': 'Adam',
#  'Time': '1PM',
#  'Date': 'Feb 14, 2023',
#  'Duration': '2 hours',
#  'Message': 'Success!'}

# %%
my_dict = dict(
    Course="Data Science",
    Instructor="Adam",
    Time="1PM",
    Date="Feb 14, 2023",
    Duration="2 hours",
)

my_dict
# Out:
# {'Course': 'Data Science',
#  'Instructor': 'Adam',
#  'Time': '1PM',
#  'Date': 'Feb 14, 2023',
#  'Duration': '2 hours'}

# %%
random_function(**my_dict)
# Out:
# {'Course': 'Data Science',
#  'Instructor': 'Adam',
#  'Time': '1PM',
#  'Date': 'Feb 14, 2023',
#  'Duration': '2 hours',
#  'Message': 'Success!'}

# %%
# Method 1
random_function(
    Course="Software Engineering",
    Instructor="Idowu Lawal",
    Time="6:00PM",
    Date="10-11-2022",
    Duration="3 hours",
)
# Out:
# {'Course': 'Software Engineering',
#  'Instructor': 'Idowu Lawal',
#  'Time': '6:00PM',
#  'Date': '10-11-2022',
#  'Duration': '3 hours',
#  'Message': 'Success!'}

# %%
# Method 2 (Dict unpacking)
my_dict = {
    "Course": "Data Science",
    "Instructor": "Chinedu",
    "Time": "5:00PM",
    "Date": "10-11-2022",
    "Duration": "2 hours",
}


random_function(**my_dict)
# Out:
# {'Course': 'Data Science',
#  'Instructor': 'Chinedu',
#  'Time': '5:00PM',
#  'Date': '10-11-2022',
#  'Duration': '2 hours',
#  'Message': 'Success!'}

# %% [markdown]
# <br>
# <hr>
#
# ```python
# conn = psycopg2.connect(dbname="db_name",
#                         user="postgres",
#                         password="enter_your_password")
# ```

# %%
# Create connection
conn = psycopg2.connect(**secret)

# %%
# Create a cursor to perform database operations
cursor = conn.cursor()

# Execute a query
cursor.execute("SELECT * FROM employees")

# Retrieve query results
records = cursor.fetchall()
records
# Out:
# [(1, 'Benjamin', datetime.date(2016, 1, 1), 'Data', 109000),
#  (2, 'Uju', datetime.date(2012, 11, 1), 'Engineering', 122000),
#  (3, 'Kemi', datetime.date(2019, 1, 12), 'HR', 31400),
#  (4, 'Obi', datetime.date(2012, 8, 29), 'Management', 239700),
#  (5, 'Usman', datetime.date(2016, 8, 29), 'Management', 129700),
#  (6, 'Steve', datetime.date(2021, 9, 1), 'Data', 94800),
#  (7, 'Vince', datetime.date(2019, 1, 12), 'Product', 90400),
#  (8, 'Clement', datetime.date(2022, 3, 1), 'Engineering', 82000),
#  (9, 'Marylene', datetime.date(2019, 5, 11), 'HR', 73400),
#  (10, 'Paul', datetime.date(2019, 1, 12), 'Product', 63400),
#  (11, 'Samantha', datetime.date(2012, 8, 29), 'Management', 89700),
#  (12, 'Curry', datetime.date(2021, 9, 1), 'Data', 194800),
#  (13, 'Segun', datetime.date(2019, 1, 12), 'Product', 110000),
#  (14, 'Anita', datetime.date(2022, 3, 1), 'Engineering', 178000),
#  (15, 'Marylene', datetime.date(2019, 5, 11), 'HR', 73400),
#  (16, 'Aisha', datetime.date(2016, 8, 29), 'Management', 179700),
#  (17, 'Sebastian', datetime.date(2018, 8, 1), 'Data', 109000),
#  (18, 'Carlos', datetime.date(2022, 1, 30), 'Engineering', 99000)]

# %%
pd.DataFrame(data=records, columns=["id", "name", "date", "role", "salary"])
# Out:
#     id       name        date         role  salary
# 0    1   Benjamin  2016-01-01         Data  109000
# 1    2        Uju  2012-11-01  Engineering  122000
# 2    3       Kemi  2019-01-12           HR   31400
# 3    4        Obi  2012-08-29   Management  239700
# 4    5      Usman  2016-08-29   Management  129700
# 5    6      Steve  2021-09-01         Data   94800
# 6    7      Vince  2019-01-12      Product   90400
# 7    8    Clement  2022-03-01  Engineering   82000
# 8    9   Marylene  2019-05-11           HR   73400
# 9   10       Paul  2019-01-12      Product   63400
# 10  11   Samantha  2012-08-29   Management   89700
# 11  12      Curry  2021-09-01         Data  194800
# 12  13      Segun  2019-01-12      Product  110000
# 13  14      Anita  2022-03-01  Engineering  178000
# 14  15   Marylene  2019-05-11           HR   73400
# 15  16      Aisha  2016-08-29   Management  179700
# 16  17  Sebastian  2018-08-01         Data  109000
# 17  18     Carlos  2022-01-30  Engineering   99000

# %%
# Execute a query
cursor.execute("SELECT COUNT(*) FROM atlanta_crime;")

# Retrieve query results
records = cursor.fetchall()
records
# Out:
# [(5001,)]

# %% [markdown]
# ## Using Pandas, SQLAlchemy And Postgres (Method 2)
#
# * [Docs](https://docs.sqlalchemy.org/en/20/core/engines.html#database-urls)
#
# ```bash
# Scheme: "postgresql+psycopg2://<USERNAME>:<PASSWORD>@<HOST>:<PORT>/<DATABASE_NAME>"
#
# DATABASE_URI = 'postgresql+psycopg2://postgres:password@localhost:5432/myDB'
# ```

# %%
# Get credentials  (Postgres)
username = secret.get("user")
password = secret.get("password")
dbname = secret.get("dbname")
host = secret.get("host")
port = secret.get("port")

DATABASE_URI = f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{dbname}"

# %%
# (SQLAlchemy)
from sqlalchemy import create_engine


# Create an Engine instance which enables
# you to interact and connect to the DB
db_engine = create_engine(DATABASE_URI, pool_recycle=-1).connect()

# %%
sql_query = """
            SELECT * FROM employees;
         """

# Read using Pandas
pd.read_sql(sql=sql_query, con=db_engine)
# Out:
#     employee_id employee_name year_joined   department  salary
# 0             1      Benjamin  2016-01-01         Data  109000
# 1             2           Uju  2012-11-01  Engineering  122000
# 2             3          Kemi  2019-01-12           HR   31400
# 3             4           Obi  2012-08-29   Management  239700
# 4             5         Usman  2016-08-29   Management  129700
# 5             6         Steve  2021-09-01         Data   94800
# 6             7         Vince  2019-01-12      Product   90400
# 7             8       Clement  2022-03-01  Engineering   82000
# 8             9      Marylene  2019-05-11           HR   73400
# 9            10          Paul  2019-01-12      Product   63400
# 10           11      Samantha  2012-08-29   Management   89700
# 11           12         Curry  2021-09-01         Data  194800
# 12           13         Segun  2019-01-12      Product  110000
# 13           14         Anita  2022-03-01  Engineering  178000
# 14           15      Marylene  2019-05-11           HR   73400
# 15           16         Aisha  2016-08-29   Management  179700
# 16           17     Sebastian  2018-08-01         Data  109000
# 17           18        Carlos  2022-01-30  Engineering   99000

# %% [markdown]
# ### Create A JSON File

# %%
secrets_ = {
    "dbname": "myDB",
    "user": "postgres",
    "password": "password",
    "host": "localhost",
    "port": "my_port",
}

secrets_
# Out:
# {'dbname': 'myDB',
#  'user': 'postgres',
#  'password': 'password',
#  'host': 'localhost',
#  'port': 'my_port'}

# %%
filepath = "data/secrets_1.json"

# w: create file
with open(file=filepath, mode="w") as fp:
    json.dump(obj=secrets_, fp=fp, indent=4)

# %% [markdown]
# ## Aggregate Functions
#
# ### AVERAGE

# %%
sql_query = """
            SELECT * FROM employees
            LIMIT 5;
         """

# Read using Pandas
pd.read_sql(sql=sql_query, con=db_engine)
# Out:
#    employee_id employee_name year_joined   department  salary
# 0            1      Benjamin  2016-01-01         Data  109000
# 1            2           Uju  2012-11-01  Engineering  122000
# 2            3          Kemi  2019-01-12           HR   31400
# 3            4           Obi  2012-08-29   Management  239700
# 4            5         Usman  2016-08-29   Management  129700

# %%
# What is the average salary of the employees?

# %%
sql_query = """
        SELECT AVG(salary) AS avg_salary
        FROM employees;
        """

# Read using Pandas
pd.read_sql(sql=sql_query, con=db_engine)
# Out:
#       avg_salary
# 0  114966.666667

# %%
sql_query = """
        SELECT ROUND(AVG(salary), 2) AS avg_salary
        FROM employees;
        """

# Read using Pandas
pd.read_sql(sql=sql_query, con=db_engine)
# Out:
#    avg_salary
# 0   114966.67

# %% [markdown]
# ### Connect Using IPython-sql
#
# * [Docs](https://pypi.org/project/ipython-sql/)

# %%
# Get credentials  (Postgres)
username = secret.get("user")
password = secret.get("password")
dbname = secret.get("dbname")
host = secret.get("host")
port = secret.get("port")

DATABASE_URI = f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{dbname}"

# %%
# Load library
# %load_ext sql


# Load DB
# %sql sqlite:///db/example.db
# %sql postgresql://{username}:{password}@{host}/{dbname}

# %% [markdown]
# ### MINIMUM

# %%
# What is the minimum salary of the employees?

# %%
# %%sql
#
# SELECT ROUND(MIN(salary), 2) AS avg_salary
#         FROM employees;
# Out:
#  * postgresql://postgres:***@localhost/myDB
# 1 rows affected.
# [(Decimal('31400.00'),)]

# %% [markdown]
# ### I'll Use A SQLite DB So That You Can Replicate The Examples On Your Own
#
# * The DB can be found [here](https://drive.google.com/file/d/1Lh87-ribiksg9AcOjl6o6Y9QCk6X9gvQ/view?usp=sharing)

# %%
# Load library
# %load_ext sql


# Load DB
# %sql sqlite:///db/attr_data.db
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %%sql
#
# SELECT name FROM sqlite_master;
# Out:
#    postgresql://postgres:***@localhost/myDB
#  * sqlite:///db/attr_data.db
# Done.
# [('attrition_records',), ('sqlite_sequence',)]

# %%
# %%sql
#
# SELECT * FROM attrition_records
# LIMIT 20;
# Out:
#    postgresql://postgres:***@localhost/myDB
#  * sqlite:///db/attr_data.db
# Done.
# [(1, 41, 'Yes', 'Travel_Rarely', 1102, 'Sales', 1, 2, 'Life Sciences', 1, 1, 2, 'Female', 94, 3, 2, 'Sales Executive', 4, 'Single', 5993, 19479, 8, 'Y', 'Yes', 11, 3, 1, 80, 0, 8, 0, 1, 6, 4, 0, 5),
#  (2, 49, 'No', 'Travel_Frequently', 279, 'Research & Development', 8, 1, 'Life Sciences', 1, 2, 3, 'Male', 61, 2, 2, 'Research Scientist', 2, 'Married', 5130, 24907, 1, 'Y', 'No', 23, 4, 4, 80, 1, 10, 3, 3, 10, 7, 1, 7),
#  (3, 37, 'Yes', 'Travel_Rarely', 1373, 'Research & Development', 2, 2, 'Other', 1, 4, 4, 'Male', 92, 2, 1, 'Laboratory Technician', 3, 'Single', 2090, 2396, 6, 'Y', 'Yes', 15, 3, 2, 80, 0, 7, 3, 3, 0, 0, 0, 0),
#  (4, 33, 'No', 'Travel_Frequently', 1392, 'Research & Development', 3, 4, 'Life Sciences', 1, 5, 4, 'Female', 56, 3, 1, 'Research Scientist', 3, 'Married', 2909, 23159, 1, 'Y', 'Yes', 11, 3, 3, 80, 0, 8, 3, 3, 8, 7, 3, 0),
#  (5, 27, 'No', 'Travel_Rarely', 591, 'Research & Development', 2, 1, 'Medical', 1, 7, 1, 'Male', 40, 3, 1, 'Laboratory Technician', 2, 'Married', 3468, 16632, 9, 'Y', 'No', 12, 3, 4, 80, 1, 6, 3, 3, 2, 2, 2, 2),
#  (6, 32, 'No', 'Travel_Frequently', 1005, 'Research & Development', 2, 2, 'Life Sciences', 1, 8, 4, 'Male', 79, 3, 1, 'Laboratory Technician', 4, 'Single', 3068, 11864, 0, 'Y', 'No', 13, 3, 3, 80, 0, 8, 2, 2, 7, 7, 3, 6),
#  (7, 59, 'No', 'Travel_Rarely', 1324, 'Research & Development', 3, 3, 'Medical', 1, 10, 3, 'Female', 81, 4, 1, 'Laboratory Technician', 1, 'Married', 2670, 9964, 4, 'Y', 'Yes', 20, 4, 1, 80, 3, 12, 3, 2, 1, 0, 0, 0),
#  (8, 30, 'No', 'Travel_Rarely', 1358, 'Research & Development', 24, 1, 'Life Sciences', 1, 11, 4, 'Male', 67, 3, 1, 'Laboratory Technician', 3, 'Divorced', 2693, 13335, 1, 'Y', 'No', 22, 4, 2, 80, 1, 1, 2, 3, 1, 0, 0, 0),
#  (9, 38, 'No', 'Travel_Frequently', 216, 'Research & Development', 23, 3, 'Life Sciences', 1, 12, 4, 'Male', 44, 2, 3, 'Manufacturing Director', 3, 'Single', 9526, 8787, 0, 'Y', 'No', 21, 4, 2, 80, 0, 10, 2, 3, 9, 7, 1, 8),
#  (10, 36, 'No', 'Travel_Rarely', 1299, 'Research & Development', 27, 3, 'Medical', 1, 13, 3, 'Male', 94, 3, 2, 'Healthcare Representative', 3, 'Married', 5237, 16577, 6, 'Y', 'No', 13, 3, 2, 80, 2, 17, 3, 2, 7, 7, 7, 7),
#  (11, 35, 'No', 'Travel_Rarely', 809, 'Research & Development', 16, 3, 'Medical', 1, 14, 1, 'Male', 84, 4, 1, 'Laboratory Technician', 2, 'Married', 2426, 16479, 0, 'Y', 'No', 13, 3, 3, 80, 1, 6, 5, 3, 5, 4, 0, 3),
#  (12, 29, 'No', 'Travel_Rarely', 153, 'Research & Development', 15, 2, 'Life Sciences', 1, 15, 4, 'Female', 49, 2, 2, 'Laboratory Technician', 3, 'Single', 4193, 12682, 0, 'Y', 'Yes', 12, 3, 4, 80, 0, 10, 3, 3, 9, 5, 0, 8),
#  (13, 31, 'No', 'Travel_Rarely', 670, 'Research & Development', 26, 1, 'Life Sciences', 1, 16, 1, 'Male', 31, 3, 1, 'Research Scientist', 3, 'Divorced', 2911, 15170, 1, 'Y', 'No', 17, 3, 4, 80, 1, 5, 1, 2, 5, 2, 4, 3),
#  (14, 34, 'No', 'Travel_Rarely', 1346, 'Research & Development', 19, 2, 'Medical', 1, 18, 2, 'Male', 93, 3, 1, 'Laboratory Technician', 4, 'Divorced', 2661, 8758, 0, 'Y', 'No', 11, 3, 3, 80, 1, 3, 2, 3, 2, 2, 1, 2),
#  (15, 28, 'Yes', 'Travel_Rarely', 103, 'Research & Development', 24, 3, 'Life Sciences', 1, 19, 3, 'Male', 50, 2, 1, 'Laboratory Technician', 3, 'Single', 2028, 12947, 5, 'Y', 'Yes', 14, 3, 2, 80, 0, 6, 4, 3, 4, 2, 0, 3),
#  (16, 29, 'No', 'Travel_Rarely', 1389, 'Research & Development', 21, 4, 'Life Sciences', 1, 20, 2, 'Female', 51, 4, 3, 'Manufacturing Director', 1, 'Divorced', 9980, 10195, 1, 'Y', 'No', 11, 3, 3, 80, 1, 10, 1, 3, 10, 9, 8, 8),
#  (17, 32, 'No', 'Travel_Rarely', 334, 'Research & Development', 5, 2, 'Life Sciences', 1, 21, 1, 'Male', 80, 4, 1, 'Research Scientist', 2, 'Divorced', 3298, 15053, 0, 'Y', 'Yes', 12, 3, 4, 80, 2, 7, 5, 2, 6, 2, 0, 5),
#  (18, 22, 'No', 'Non-Travel', 1123, 'Research & Development', 16, 2, 'Medical', 1, 22, 4, 'Male', 96, 4, 1, 'Laboratory Technician', 4, 'Divorced', 2935, 7324, 1, 'Y', 'Yes', 13, 3, 2, 80, 2, 1, 2, 2, 1, 0, 0, 0),
#  (19, 53, 'No', 'Travel_Rarely', 1219, 'Sales', 2, 4, 'Life Sciences', 1, 23, 1, 'Female', 78, 2, 4, 'Manager', 4, 'Married', 15427, 22021, 2, 'Y', 'No', 16, 3, 3, 80, 0, 31, 3, 3, 25, 8, 3, 7),
#  (20, 38, 'No', 'Travel_Rarely', 371, 'Research & Development', 2, 3, 'Life Sciences', 1, 24, 4, 'Male', 45, 3, 1, 'Research Scientist', 4, 'Single', 3944, 4306, 5, 'Y', 'Yes', 11, 3, 3, 80, 0, 6, 3, 3, 3, 2, 1, 2)]

# %%
# How old is the oldest employee?

# %%
# %%sql
#
# SELECT ROUND(MAX(Age), 2) AS max_age
#         FROM attrition_records;
# Out:
#    postgresql://postgres:***@localhost/myDB
#  * sqlite:///db/attr_data.db
# Done.
# [(60.0,)]

# %%
# Who is/are the oldest employee(s?
# You might need to use sub-queries

# %%
# %%sql
#
# SELECT ROUND(MAX(Age), 2) AS max_age
#         FROM attrition_records;
# Out:
#    postgresql://postgres:***@localhost/myDB
#  * sqlite:///db/attr_data.db
# Done.
# [(60.0,)]

# %% [markdown]
# ### Avoid Hard-coding Values!!!

# %%
# %%sql
#
# SELECT *
#     FROM attrition_records
# WHERE Age = 60;
# Out:
#    postgresql://postgres:***@localhost/myDB
#  * sqlite:///db/attr_data.db
# Done.
# [(412, 60, 'No', 'Travel_Rarely', 422, 'Research & Development', 7, 3, 'Life Sciences', 1, 549, 1, 'Female', 41, 3, 5, 'Manager', 1, 'Married', 19566, 3854, 5, 'Y', 'No', 11, 3, 4, 80, 0, 33, 5, 1, 29, 8, 11, 10),
#  (428, 60, 'No', 'Travel_Frequently', 1499, 'Sales', 28, 3, 'Marketing', 1, 573, 3, 'Female', 80, 2, 3, 'Sales Executive', 1, 'Married', 10266, 2845, 4, 'Y', 'No', 19, 3, 4, 80, 0, 22, 5, 4, 18, 13, 13, 11),
#  (537, 60, 'No', 'Travel_Rarely', 1179, 'Sales', 16, 4, 'Marketing', 1, 732, 1, 'Male', 84, 3, 2, 'Sales Executive', 1, 'Single', 5405, 11924, 8, 'Y', 'No', 14, 3, 4, 80, 0, 10, 1, 3, 2, 2, 2, 2),
#  (880, 60, 'No', 'Travel_Rarely', 696, 'Sales', 7, 4, 'Marketing', 1, 1233, 2, 'Male', 52, 4, 2, 'Sales Executive', 4, 'Divorced', 5220, 10893, 0, 'Y', 'Yes', 18, 3, 2, 80, 1, 12, 3, 3, 11, 7, 1, 9),
#  (1210, 60, 'No', 'Travel_Rarely', 370, 'Research & Development', 1, 4, 'Medical', 1, 1697, 3, 'Male', 92, 1, 3, 'Healthcare Representative', 4, 'Divorced', 10883, 20467, 3, 'Y', 'No', 20, 4, 3, 80, 1, 19, 2, 4, 1, 0, 0, 0),
#  (1882, 60, 'No', 'Travel_Rarely', 422, 'Research & Development', 7, 3, 'Life Sciences', 1, 549, 1, 'Female', 41, 3, 5, 'Manager', 1, 'Married', 19566, 3854, 5, 'Y', 'No', 11, 3, 4, 80, 0, 33, 5, 1, 29, 8, 11, 10),
#  (1898, 60, 'No', 'Travel_Frequently', 1499, 'Sales', 28, 3, 'Marketing', 1, 573, 3, 'Female', 80, 2, 3, 'Sales Executive', 1, 'Married', 10266, 2845, 4, 'Y', 'No', 19, 3, 4, 80, 0, 22, 5, 4, 18, 13, 13, 11),
#  (2007, 60, 'No', 'Travel_Rarely', 1179, 'Sales', 16, 4, 'Marketing', 1, 732, 1, 'Male', 84, 3, 2, 'Sales Executive', 1, 'Single', 5405, 11924, 8, 'Y', 'No', 14, 3, 4, 80, 0, 10, 1, 3, 2, 2, 2, 2),
#  (2350, 60, 'No', 'Travel_Rarely', 696, 'Sales', 7, 4, 'Marketing', 1, 1233, 2, 'Male', 52, 4, 2, 'Sales Executive', 4, 'Divorced', 5220, 10893, 0, 'Y', 'Yes', 18, 3, 2, 80, 1, 12, 3, 3, 11, 7, 1, 9),
#  (2680, 60, 'No', 'Travel_Rarely', 370, 'Research & Development', 1, 4, 'Medical', 1, 1697, 3, 'Male', 92, 1, 3, 'Healthcare Representative', 4, 'Divorced', 10883, 20467, 3, 'Y', 'No', 20, 4, 3, 80, 1, 19, 2, 4, 1, 0, 0, 0)]

# %%
# %%sql
#
# SELECT COUNT(*)
#     FROM attrition_records
# WHERE Age = 60;
# Out:
#    postgresql://postgres:***@localhost/myDB
#  * sqlite:///db/attr_data.db
# Done.
# [(10,)]

# %% [markdown]
# ### A Better Approach

# %%
# %%sql
#
# SELECT COUNT(*)
#     FROM attrition_records
# WHERE Age = (SELECT ROUND(MAX(Age), 2) AS max_age
#         FROM attrition_records);
# Out:
#    postgresql://postgres:***@localhost/myDB
#  * sqlite:///db/attr_data.db
# Done.
# [(10,)]

# %% [markdown]
# ### COUNT

# %%
# How many employees are in the database?

# %%
# %%sql
#
# SELECT COUNT(Age) AS num_employees
#         FROM attrition_records;
# Out:
#    postgresql://postgres:***@localhost/myDB
#  * sqlite:///db/attr_data.db
# Done.
# [(2940,)]

# %%
# What is the total monthly income of the divorced employees?

# %% [markdown]
# ### SUM

# %%
# %%sql
#
# SELECT * FROM attrition_records
# LIMIT 2
# Out:
#    postgresql://postgres:***@localhost/myDB
#  * sqlite:///db/attr_data.db
# Done.
# [(1, 41, 'Yes', 'Travel_Rarely', 1102, 'Sales', 1, 2, 'Life Sciences', 1, 1, 2, 'Female', 94, 3, 2, 'Sales Executive', 4, 'Single', 5993, 19479, 8, 'Y', 'Yes', 11, 3, 1, 80, 0, 8, 0, 1, 6, 4, 0, 5),
#  (2, 49, 'No', 'Travel_Frequently', 279, 'Research & Development', 8, 1, 'Life Sciences', 1, 2, 3, 'Male', 61, 2, 2, 'Research Scientist', 2, 'Married', 5130, 24907, 1, 'Y', 'No', 23, 4, 4, 80, 1, 10, 3, 3, 10, 7, 1, 7)]

# %%
# %%sql
#
# SELECT DISTINCT(MaritalStatus)
# FROM attrition_records;
# Out:
#    postgresql://postgres:***@localhost/myDB
#  * sqlite:///db/attr_data.db
# Done.
# [('Single',), ('Married',), ('Divorced',)]

# %%
# %%sql
#
# SELECT * FROM attrition_records
# WHERE LOWER(MaritalStatus) LIKE "%divorce%";
# Out:
#    postgresql://postgres:***@localhost/myDB
#  * sqlite:///db/attr_data.db
# Done.
# [(8, 30, 'No', 'Travel_Rarely', 1358, 'Research & Development', 24, 1, 'Life Sciences', 1, 11, 4, 'Male', 67, 3, 1, 'Laboratory Technician', 3, 'Divorced', 2693, 13335, 1, 'Y', 'No', 22, 4, 2, 80, 1, 1, 2, 3, 1, 0, 0, 0),
#  (13, 31, 'No', 'Travel_Rarely', 670, 'Research & Development', 26, 1, 'Life Sciences', 1, 16, 1, 'Male', 31, 3, 1, 'Research Scientist', 3, 'Divorced', 2911, 15170, 1, 'Y', 'No', 17, 3, 4, 80, 1, 5, 1, 2, 5, 2, 4, 3),
#  (14, 34, 'No', 'Travel_Rarely', 1346, 'Research & Development', 19, 2, 'Medical', 1, 18, 2, 'Male', 93, 3, 1, 'Laboratory Technician', 4, 'Divorced', 2661, 8758, 0, 'Y', 'No', 11, 3, 3, 80, 1, 3, 2, 3, 2, 2, 1, 2),
#  (16, 29, 'No', 'Travel_Rarely', 1389, 'Research & Development', 21, 4, 'Life Sciences', 1, 20, 2, 'Female', 51, 4, 3, 'Manufacturing Director', 1, 'Divorced', 9980, 10195, 1, 'Y', 'No', 11, 3, 3, 80, 1, 10, 1, 3, 10, 9, 8, 8),
#  (17, 32, 'No', 'Travel_Rarely', 334, 'Research & Development', 5, 2, 'Life Sciences', 1, 21, 1, 'Male', 80, 4, 1, 'Research Scientist', 2, 'Divorced', 3298, 15053, 0, 'Y', 'Yes', 12, 3, 4, 80, 2, 7, 5, 2, 6, 2, 0, 5),
#  (18, 22, 'No', 'Non-Travel', 1123, 'Research & Development', 16, 2, 'Medical', 1, 22, 4, 'Male', 96, 4, 1, 'Laboratory Technician', 4, 'Divorced', 2935, 7324, 1, 'Y', 'Yes', 13, 3, 2, 80, 2, 1, 2, 2, 1, 0, 0, 0),
#  (21, 24, 'No', 'Non-Travel', 673, 'Research & Development', 11, 2, 'Other', 1, 26, 1, 'Female', 96, 4, 2, 'Manufacturing Director', 3, 'Divorced', 4011, 8232, 0, 'Y', 'No', 18, 3, 4, 80, 1, 5, 5, 2, 4, 2, 1, 3),
#  (26, 53, 'No', 'Travel_Rarely', 1282, 'Research & Development', 5, 3, 'Other', 1, 32, 3, 'Female', 58, 3, 5, 'Manager', 3, 'Divorced', 19094, 10735, 4, 'Y', 'No', 11, 3, 4, 80, 1, 26, 3, 2, 14, 13, 4, 8),
#  (36, 43, 'No', 'Travel_Rarely', 1273, 'Research & Development', 2, 2, 'Medical', 1, 46, 4, 'Female', 72, 4, 1, 'Research Scientist', 3, 'Divorced', 2645, 21923, 1, 'Y', 'No', 12, 3, 4, 80, 2, 6, 3, 2, 5, 3, 1, 4),
#  (41, 35, 'No', 'Travel_Rarely', 464, 'Research & Development', 4, 2, 'Other', 1, 53, 3, 'Male', 75, 3, 1, 'Laboratory Technician', 4, 'Divorced', 1951, 10910, 1, 'Y', 'No', 12, 3, 3, 80, 1, 1, 3, 3, 1, 0, 0, 0),
#  (42, 27, 'No', 'Travel_Rarely', 1240, 'Research & Development', 2, 4, 'Life Sciences', 1, 54, 4, 'Female', 33, 3, 1, 'Laboratory Technician', 1, 'Divorced', 2341, 19715, 1, 'Y', 'No', 13, 3, 4, 80, 1, 1, 6, 3, 1, 0, 0, 0),
#  (53, 44, 'No', 'Travel_Rarely', 1488, 'Sales', 1, 5, 'Marketing', 1, 68, 2, 'Female', 75, 3, 2, 'Sales Executive', 1, 'Divorced', 5454, 4009, 5, 'Y', 'Yes', 21, 4, 3, 80, 1, 9, 2, 2, 4, 3, 1, 3),
#  (59, 31, 'No', 'Travel_Rarely', 655, 'Research & Development', 7, 4, 'Life Sciences', 1, 76, 4, 'Male', 48, 3, 2, 'Laboratory Technician', 4, 'Divorced', 5915, 9528, 3, 'Y', 'No', 22, 4, 4, 80, 1, 10, 3, 2, 7, 7, 1, 7),
#  (60, 37, 'No', 'Travel_Rarely', 1115, 'Research & Development', 1, 4, 'Life Sciences', 1, 77, 1, 'Male', 51, 2, 2, 'Manufacturing Director', 3, 'Divorced', 5993, 2689, 1, 'Y', 'No', 18, 3, 3, 80, 1, 7, 2, 4, 7, 5, 0, 7),
#  (63, 50, 'No', 'Travel_Rarely', 989, 'Research & Development', 7, 2, 'Medical', 1, 80, 2, 'Female', 43, 2, 5, 'Research Director', 3, 'Divorced', 18740, 16701, 5, 'Y', 'Yes', 12, 3, 4, 80, 1, 29, 2, 2, 27, 3, 13, 8),
#  (65, 36, 'No', 'Travel_Rarely', 1223, 'Research & Development', 8, 3, 'Technical Degree', 1, 83, 3, 'Female', 59, 3, 3, 'Healthcare Representative', 3, 'Divorced', 10096, 8202, 1, 'Y', 'No', 13, 3, 2, 80, 3, 17, 2, 3, 17, 14, 12, 8),
#  (66, 55, 'No', 'Travel_Rarely', 836, 'Research & Development', 8, 3, 'Medical', 1, 84, 4, 'Female', 33, 3, 4, 'Manager', 3, 'Divorced', 14756, 19730, 2, 'Y', 'Yes', 14, 3, 3, 80, 3, 21, 2, 3, 5, 0, 0, 2),
#  (68, 45, 'No', 'Travel_Rarely', 1339, 'Research & Development', 7, 3, 'Life Sciences', 1, 86, 2, 'Male', 59, 3, 3, 'Research Scientist', 1, 'Divorced', 9724, 18787, 2, 'Y', 'No', 17, 3, 3, 80, 1, 25, 2, 3, 1, 0, 0, 0),
#  (80, 46, 'No', 'Travel_Rarely', 945, 'Human Resources', 5, 2, 'Medical', 1, 103, 2, 'Male', 80, 3, 2, 'Human Resources', 2, 'Divorced', 5021, 10425, 8, 'Y', 'Yes', 22, 4, 4, 80, 1, 16, 2, 3, 4, 2, 0, 2),
#  (84, 38, 'No', 'Non-Travel', 573, 'Research & Development', 6, 3, 'Medical', 1, 107, 2, 'Female', 79, 1, 2, 'Research Scientist', 4, 'Divorced', 5329, 15717, 7, 'Y', 'Yes', 12, 3, 4, 80, 3, 17, 3, 3, 13, 11, 1, 9),
#  (87, 23, 'No', 'Travel_Rarely', 541, 'Sales', 2, 1, 'Technical Degree', 1, 113, 3, 'Male', 62, 3, 1, 'Sales Representative', 1, 'Divorced', 2322, 9518, 3, 'Y', 'No', 13, 3, 3, 80, 1, 3, 3, 3, 0, 0, 0, 0),
#  (93, 30, 'No', 'Travel_Rarely', 1334, 'Sales', 4, 2, 'Medical', 1, 121, 3, 'Female', 63, 2, 2, 'Sales Executive', 2, 'Divorced', 5209, 19760, 1, 'Y', 'Yes', 12, 3, 2, 80, 3, 11, 4, 2, 11, 8, 2, 7),
#  (101, 37, 'Yes', 'Travel_Rarely', 807, 'Human Resources', 6, 4, 'Human Resources', 1, 133, 3, 'Male', 63, 3, 1, 'Human Resources', 1, 'Divorced', 2073, 23648, 4, 'Y', 'Yes', 22, 4, 4, 80, 0, 7, 3, 3, 3, 2, 0, 2),
#  (105, 37, 'No', 'Non-Travel', 1040, 'Research & Development', 2, 2, 'Life Sciences', 1, 139, 3, 'Male', 100, 2, 2, 'Healthcare Representative', 4, 'Divorced', 5163, 15850, 5, 'Y', 'No', 14, 3, 4, 80, 1, 17, 2, 4, 1, 0, 0, 0),
#  (115, 34, 'No', 'Travel_Rarely', 1031, 'Research & Development', 6, 4, 'Life Sciences', 1, 151, 3, 'Female', 45, 2, 2, 'Research Scientist', 2, 'Divorced', 4505, 15000, 6, 'Y', 'No', 15, 3, 3, 80, 1, 12, 3, 3, 1, 0, 0, 0),
#  (119, 36, 'No', 'Travel_Rarely', 922, 'Research & Development', 3, 2, 'Life Sciences', 1, 155, 1, 'Female', 39, 3, 1, 'Laboratory Technician', 4, 'Divorced', 2835, 2561, 5, 'Y', 'No', 22, 4, 1, 80, 1, 7, 2, 3, 1, 0, 0, 0),
#  (121, 30, 'No', 'Travel_Frequently', 1312, 'Research & Development', 23, 3, 'Life Sciences', 1, 159, 1, 'Male', 96, 1, 1, 'Research Scientist', 3, 'Divorced', 2613, 22310, 1, 'Y', 'No', 25, 4, 3, 80, 3, 10, 2, 2, 10, 7, 0, 9),
#  (134, 41, 'No', 'Travel_Rarely', 802, 'Sales', 9, 1, 'Life Sciences', 1, 176, 3, 'Male', 96, 3, 3, 'Sales Executive', 3, 'Divorced', 8189, 21196, 3, 'Y', 'Yes', 13, 3, 3, 80, 1, 12, 2, 3, 9, 7, 0, 7),
#  (136, 36, 'No', 'Travel_Rarely', 216, 'Research & Development', 6, 2, 'Medical', 1, 178, 2, 'Male', 84, 3, 2, 'Manufacturing Director', 2, 'Divorced', 4941, 2819, 6, 'Y', 'No', 20, 4, 4, 80, 2, 7, 0, 3, 3, 2, 0, 1),
#  (145, 32, 'No', 'Travel_Frequently', 689, 'Sales', 9, 2, 'Medical', 1, 195, 4, 'Male', 35, 1, 2, 'Sales Executive', 4, 'Divorced', 4668, 22812, 0, 'Y', 'No', 17, 3, 4, 80, 3, 9, 2, 4, 8, 7, 0, 7),
#  (146, 30, 'No', 'Travel_Rarely', 201, 'Research & Development', 5, 3, 'Technical Degree', 1, 197, 4, 'Female', 84, 3, 1, 'Research Scientist', 1, 'Divorced', 3204, 10415, 5, 'Y', 'No', 14, 3, 4, 80, 1, 8, 3, 3, 3, 2, 2, 2),
#  (148, 41, 'No', 'Travel_Frequently', 857, 'Research & Development', 10, 3, 'Life Sciences', 1, 199, 4, 'Male', 91, 2, 4, 'Manager', 1, 'Divorced', 17181, 12888, 4, 'Y', 'No', 13, 3, 2, 80, 1, 21, 2, 2, 7, 6, 7, 7),
#  (151, 40, 'No', 'Travel_Frequently', 1395, 'Research & Development', 26, 3, 'Medical', 1, 202, 2, 'Female', 54, 3, 2, 'Research Scientist', 2, 'Divorced', 5605, 8504, 1, 'Y', 'No', 11, 3, 1, 80, 1, 20, 2, 3, 20, 7, 2, 13),
#  (154, 45, 'No', 'Travel_Rarely', 194, 'Research & Development', 9, 3, 'Life Sciences', 1, 206, 2, 'Male', 60, 3, 2, 'Laboratory Technician', 2, 'Divorced', 2348, 10901, 8, 'Y', 'No', 18, 3, 3, 80, 1, 20, 2, 1, 17, 9, 0, 15),
#  (162, 27, 'No', 'Non-Travel', 691, 'Research & Development', 9, 3, 'Medical', 1, 218, 4, 'Male', 57, 3, 1, 'Research Scientist', 2, 'Divorced', 2024, 5970, 6, 'Y', 'No', 18, 3, 4, 80, 1, 6, 1, 1, 2, 2, 2, 2),
#  (164, 57, 'No', 'Travel_Rarely', 334, 'Research & Development', 24, 2, 'Life Sciences', 1, 223, 3, 'Male', 83, 4, 3, 'Healthcare Representative', 4, 'Divorced', 9439, 23402, 3, 'Y', 'Yes', 16, 3, 2, 80, 1, 12, 2, 1, 5, 3, 1, 4),
#  (165, 27, 'No', 'Non-Travel', 1450, 'Research & Development', 3, 3, 'Medical', 1, 224, 3, 'Male', 79, 2, 1, 'Research Scientist', 3, 'Divorced', 2566, 25326, 1, 'Y', 'Yes', 15, 3, 4, 80, 1, 1, 2, 2, 1, 1, 0, 1),
#  (167, 41, 'No', 'Travel_Rarely', 465, 'Research & Development', 14, 3, 'Life Sciences', 1, 227, 1, 'Male', 56, 3, 1, 'Research Scientist', 3, 'Divorced', 2451, 4609, 4, 'Y', 'No', 12, 3, 1, 80, 1, 13, 2, 3, 9, 8, 1, 8),
#  (174, 30, 'No', 'Non-Travel', 111, 'Research & Development', 9, 3, 'Medical', 1, 239, 3, 'Male', 66, 3, 2, 'Laboratory Technician', 1, 'Divorced', 3072, 11012, 1, 'Y', 'No', 11, 3, 3, 80, 2, 12, 4, 3, 12, 9, 6, 10),
#  (175, 45, 'No', 'Travel_Rarely', 1268, 'Sales', 4, 2, 'Life Sciences', 1, 240, 3, 'Female', 30, 3, 2, 'Sales Executive', 1, 'Divorced', 5006, 6319, 4, 'Y', 'Yes', 11, 3, 1, 80, 1, 9, 3, 4, 5, 4, 0, 3),
#  (176, 56, 'No', 'Travel_Rarely', 713, 'Research & Development', 8, 3, 'Life Sciences', 1, 241, 3, 'Female', 67, 3, 1, 'Research Scientist', 1, 'Divorced', 4257, 13939, 4, 'Y', 'Yes', 18, 3, 3, 80, 1, 19, 3, 3, 2, 2, 2, 2),
#  (179, 46, 'No', 'Travel_Rarely', 526, 'Sales', 1, 2, 'Marketing', 1, 244, 2, 'Female', 92, 3, 3, 'Sales Executive', 1, 'Divorced', 10453, 2137, 1, 'Y', 'No', 25, 4, 3, 80, 3, 24, 2, 3, 24, 13, 15, 7),
#  (185, 53, 'No', 'Travel_Rarely', 1084, 'Research & Development', 13, 2, 'Medical', 1, 250, 4, 'Female', 57, 4, 2, 'Manufacturing Director', 1, 'Divorced', 4450, 26250, 1, 'Y', 'No', 11, 3, 3, 80, 2, 5, 3, 3, 4, 2, 1, 3),
#  (194, 43, 'No', 'Non-Travel', 1344, 'Research & Development', 7, 3, 'Medical', 1, 262, 4, 'Male', 37, 4, 1, 'Research Scientist', 4, 'Divorced', 2089, 5228, 4, 'Y', 'No', 14, 3, 4, 80, 3, 7, 3, 4, 5, 4, 2, 2),
#  (198, 42, 'No', 'Non-Travel', 926, 'Research & Development', 21, 2, 'Medical', 1, 270, 3, 'Female', 36, 3, 2, 'Manufacturing Director', 3, 'Divorced', 5265, 16439, 2, 'Y', 'No', 16, 3, 2, 80, 1, 11, 5, 3, 5, 3, 0, 2),
#  (202, 49, 'No', 'Non-Travel', 1002, 'Research & Development', 18, 4, 'Life Sciences', 1, 275, 4, 'Male', 92, 3, 2, 'Manufacturing Director', 4, 'Divorced', 6804, 23793, 1, 'Y', 'Yes', 15, 3, 1, 80, 2, 7, 0, 3, 7, 7, 1, 7),
#  (203, 34, 'No', 'Travel_Frequently', 878, 'Research & Development', 10, 4, 'Medical', 1, 277, 4, 'Male', 43, 3, 1, 'Research Scientist', 3, 'Divorced', 3815, 5972, 1, 'Y', 'Yes', 17, 3, 4, 80, 1, 5, 4, 4, 5, 3, 2, 0),
#  (207, 22, 'No', 'Travel_Rarely', 1136, 'Research & Development', 5, 3, 'Life Sciences', 1, 284, 4, 'Male', 60, 4, 1, 'Research Scientist', 2, 'Divorced', 2328, 12392, 1, 'Y', 'Yes', 16, 3, 1, 80, 1, 4, 2, 2, 4, 2, 2, 2),
#  (210, 46, 'No', 'Travel_Rarely', 644, 'Research & Development', 1, 4, 'Medical', 1, 288, 4, 'Male', 97, 3, 3, 'Healthcare Representative', 1, 'Divorced', 9396, 12368, 7, 'Y', 'No', 16, 3, 3, 80, 1, 17, 3, 3, 4, 2, 0, 3),
#  (223, 37, 'No', 'Travel_Frequently', 663, 'Research & Development', 11, 3, 'Other', 1, 306, 2, 'Male', 47, 3, 3, 'Research Director', 4, 'Divorced', 12185, 10056, 1, 'Y', 'Yes', 14, 3, 3, 80, 3, 10, 1, 3, 10, 8, 0, 7),
#  (224, 38, 'No', 'Travel_Rarely', 119, 'Sales', 3, 3, 'Life Sciences', 1, 307, 1, 'Male', 76, 3, 3, 'Sales Executive', 3, 'Divorced', 10609, 9647, 0, 'Y', 'No', 12, 3, 3, 80, 2, 17, 6, 2, 16, 10, 5, 13),
#  (227, 37, 'No', 'Travel_Frequently', 319, 'Sales', 4, 4, 'Marketing', 1, 311, 1, 'Male', 41, 3, 1, 'Sales Representative', 4, 'Divorced', 2793, 2539, 4, 'Y', 'No', 17, 3, 3, 80, 1, 13, 2, 3, 9, 8, 5, 8),
#  (234, 50, 'No', 'Travel_Rarely', 854, 'Sales', 1, 4, 'Medical', 1, 323, 4, 'Female', 68, 3, 5, 'Manager', 4, 'Divorced', 19517, 24118, 3, 'Y', 'No', 11, 3, 3, 80, 1, 32, 3, 2, 7, 0, 0, 6),
#  (241, 39, 'No', 'Travel_Rarely', 1431, 'Research & Development', 1, 4, 'Medical', 1, 332, 3, 'Female', 96, 3, 1, 'Laboratory Technician', 3, 'Divorced', 2232, 15417, 7, 'Y', 'No', 14, 3, 3, 80, 3, 7, 1, 3, 3, 2, 1, 2),
#  (243, 41, 'No', 'Travel_Rarely', 1411, 'Research & Development', 19, 2, 'Life Sciences', 1, 334, 3, 'Male', 36, 3, 2, 'Research Scientist', 1, 'Divorced', 3072, 19877, 2, 'Y', 'No', 16, 3, 1, 80, 2, 17, 2, 2, 1, 0, 0, 0),
#  (244, 40, 'No', 'Travel_Rarely', 1300, 'Research & Development', 24, 2, 'Technical Degree', 1, 335, 1, 'Male', 62, 3, 2, 'Research Scientist', 4, 'Divorced', 3319, 24447, 1, 'Y', 'No', 17, 3, 1, 80, 2, 9, 3, 3, 9, 8, 4, 7),
#  (246, 31, 'No', 'Travel_Frequently', 1327, 'Research & Development', 3, 4, 'Medical', 1, 337, 2, 'Male', 73, 3, 3, 'Research Director', 3, 'Divorced', 13675, 13523, 9, 'Y', 'No', 12, 3, 1, 80, 1, 9, 3, 3, 2, 2, 2, 2),
#  (251, 37, 'Yes', 'Travel_Frequently', 504, 'Research & Development', 10, 3, 'Medical', 1, 342, 1, 'Male', 61, 3, 3, 'Manufacturing Director', 3, 'Divorced', 10048, 22573, 6, 'Y', 'No', 11, 3, 2, 80, 2, 17, 5, 3, 1, 0, 0, 0),
#  (255, 29, 'No', 'Travel_Rarely', 1247, 'Sales', 20, 2, 'Marketing', 1, 349, 4, 'Male', 45, 3, 2, 'Sales Executive', 4, 'Divorced', 6931, 10732, 2, 'Y', 'No', 14, 3, 4, 80, 1, 10, 2, 3, 3, 2, 0, 2),
#  (257, 42, 'No', 'Travel_Rarely', 269, 'Research & Development', 2, 3, 'Medical', 1, 351, 4, 'Female', 56, 2, 1, 'Laboratory Technician', 1, 'Divorced', 2593, 8007, 0, 'Y', 'Yes', 11, 3, 3, 80, 1, 10, 4, 3, 9, 6, 7, 8),
#  (258, 40, 'No', 'Travel_Rarely', 1416, 'Research & Development', 2, 2, 'Medical', 1, 352, 1, 'Male', 49, 3, 5, 'Research Director', 3, 'Divorced', 19436, 5949, 0, 'Y', 'No', 19, 3, 4, 80, 1, 22, 5, 3, 21, 7, 3, 9),
#  (268, 25, 'No', 'Non-Travel', 675, 'Research & Development', 5, 2, 'Life Sciences', 1, 369, 2, 'Male', 85, 4, 2, 'Healthcare Representative', 1, 'Divorced', 4000, 18384, 1, 'Y', 'No', 12, 3, 4, 80, 2, 6, 2, 3, 6, 3, 1, 5),
#  (276, 37, 'No', 'Non-Travel', 728, 'Research & Development', 1, 4, 'Medical', 1, 380, 1, 'Female', 80, 3, 3, 'Research Director', 4, 'Divorced', 13603, 11677, 2, 'Y', 'Yes', 18, 3, 1, 80, 2, 15, 2, 3, 5, 2, 0, 2),
#  (277, 35, 'No', 'Travel_Rarely', 1315, 'Research & Development', 22, 3, 'Life Sciences', 1, 381, 2, 'Female', 71, 4, 3, 'Manager', 2, 'Divorced', 11996, 19100, 7, 'Y', 'No', 18, 3, 2, 80, 1, 10, 6, 2, 7, 7, 6, 2),
#  (278, 38, 'No', 'Travel_Rarely', 322, 'Sales', 7, 2, 'Medical', 1, 382, 1, 'Female', 44, 4, 2, 'Sales Executive', 1, 'Divorced', 5605, 19191, 1, 'Y', 'Yes', 24, 4, 3, 80, 1, 8, 3, 3, 8, 0, 7, 7),
#  (279, 26, 'No', 'Travel_Frequently', 1479, 'Research & Development', 1, 3, 'Life Sciences', 1, 384, 3, 'Female', 84, 3, 2, 'Manufacturing Director', 2, 'Divorced', 6397, 26767, 1, 'Y', 'No', 20, 4, 1, 80, 1, 6, 6, 1, 6, 5, 1, 4),
#  (280, 50, 'No', 'Travel_Rarely', 797, 'Research & Development', 4, 1, 'Life Sciences', 1, 385, 1, 'Male', 96, 3, 5, 'Research Director', 2, 'Divorced', 19144, 15815, 3, 'Y', 'No', 14, 3, 1, 80, 2, 28, 4, 2, 10, 4, 1, 6),
#  (287, 44, 'Yes', 'Travel_Frequently', 920, 'Research & Development', 24, 3, 'Life Sciences', 1, 392, 4, 'Male', 43, 3, 1, 'Laboratory Technician', 3, 'Divorced', 3161, 19920, 3, 'Y', 'Yes', 22, 4, 4, 80, 1, 19, 0, 1, 1, 0, 0, 0),
#  (288, 38, 'No', 'Travel_Rarely', 688, 'Research & Development', 23, 4, 'Life Sciences', 1, 393, 4, 'Male', 82, 3, 2, 'Healthcare Representative', 4, 'Divorced', 5745, 18899, 9, 'Y', 'No', 14, 3, 2, 80, 1, 10, 2, 3, 2, 2, 1, 2),
#  (289, 26, 'Yes', 'Travel_Rarely', 1449, 'Research & Development', 16, 4, 'Medical', 1, 394, 1, 'Male', 45, 3, 1, 'Laboratory Technician', 2, 'Divorced', 2373, 14180, 2, 'Y', 'Yes', 13, 3, 4, 80, 1, 5, 2, 3, 3, 2, 0, 2),
#  (293, 31, 'No', 'Travel_Frequently', 444, 'Sales', 5, 3, 'Marketing', 1, 399, 4, 'Female', 84, 3, 1, 'Sales Representative', 2, 'Divorced', 2789, 3909, 1, 'Y', 'No', 11, 3, 3, 80, 1, 2, 5, 2, 2, 2, 2, 2),
#  (300, 51, 'No', 'Travel_Rarely', 1302, 'Research & Development', 2, 3, 'Medical', 1, 408, 4, 'Male', 84, 1, 2, 'Manufacturing Director', 2, 'Divorced', 5482, 16321, 5, 'Y', 'No', 18, 3, 4, 80, 1, 13, 3, 3, 4, 1, 1, 2),
#  (305, 39, 'No', 'Travel_Rarely', 1132, 'Research & Development', 1, 3, 'Medical', 1, 417, 3, 'Male', 48, 4, 3, 'Healthcare Representative', 4, 'Divorced', 9613, 10942, 0, 'Y', 'No', 17, 3, 1, 80, 3, 19, 5, 2, 18, 10, 3, 7),
#  (309, 58, 'No', 'Non-Travel', 390, 'Research & Development', 1, 4, 'Life Sciences', 1, 422, 4, 'Male', 32, 1, 2, 'Healthcare Representative', 3, 'Divorced', 5660, 17056, 2, 'Y', 'Yes', 13, 3, 4, 80, 1, 12, 2, 3, 5, 3, 1, 2),
#  (312, 45, 'No', 'Travel_Frequently', 1249, 'Research & Development', 7, 3, 'Life Sciences', 1, 425, 1, 'Male', 97, 3, 3, 'Laboratory Technician', 1, 'Divorced', 5210, 20308, 1, 'Y', 'No', 18, 3, 1, 80, 1, 24, 2, 3, 24, 9, 9, 11),
#  (313, 31, 'No', 'Travel_Rarely', 192, 'Research & Development', 2, 4, 'Life Sciences', 1, 426, 3, 'Male', 32, 3, 1, 'Research Scientist', 4, 'Divorced', 2695, 7747, 0, 'Y', 'Yes', 18, 3, 2, 80, 1, 3, 2, 1, 2, 2, 2, 2),
#  (322, 31, 'No', 'Travel_Rarely', 691, 'Sales', 7, 3, 'Marketing', 1, 438, 4, 'Male', 73, 3, 2, 'Sales Executive', 4, 'Divorced', 7547, 7143, 4, 'Y', 'No', 12, 3, 4, 80, 3, 13, 3, 3, 7, 7, 1, 7),
#  (331, 43, 'No', 'Travel_Frequently', 559, 'Research & Development', 10, 4, 'Life Sciences', 1, 448, 3, 'Female', 82, 2, 2, 'Laboratory Technician', 3, 'Divorced', 5257, 6227, 1, 'Y', 'No', 11, 3, 2, 80, 1, 9, 3, 4, 9, 7, 0, 0),
#  (339, 30, 'No', 'Travel_Rarely', 570, 'Sales', 5, 3, 'Marketing', 1, 456, 4, 'Female', 30, 2, 2, 'Sales Executive', 3, 'Divorced', 6118, 5431, 1, 'Y', 'No', 13, 3, 3, 80, 3, 10, 2, 3, 10, 9, 1, 2),
#  (341, 37, 'No', 'Travel_Rarely', 1192, 'Research & Development', 5, 2, 'Medical', 1, 460, 4, 'Male', 61, 3, 2, 'Manufacturing Director', 4, 'Divorced', 6347, 23177, 7, 'Y', 'No', 16, 3, 3, 80, 2, 8, 2, 2, 6, 2, 0, 4),
#  (342, 38, 'No', 'Travel_Rarely', 343, 'Research & Development', 15, 2, 'Life Sciences', 1, 461, 3, 'Male', 92, 2, 3, 'Research Director', 4, 'Divorced', 11510, 15682, 0, 'Y', 'Yes', 14, 3, 2, 80, 1, 12, 3, 3, 11, 10, 2, 9),
#  (344, 29, 'No', 'Travel_Rarely', 144, 'Sales', 10, 1, 'Marketing', 1, 463, 4, 'Female', 39, 2, 2, 'Sales Executive', 2, 'Divorced', 8268, 11866, 1, 'Y', 'Yes', 14, 3, 1, 80, 2, 7, 2, 3, 7, 7, 1, 7),
#  (346, 23, 'No', 'Travel_Rarely', 1309, 'Research & Development', 26, 1, 'Life Sciences', 1, 465, 3, 'Male', 83, 3, 1, 'Research Scientist', 4, 'Divorced', 2904, 16092, 1, 'Y', 'No', 12, 3, 3, 80, 2, 4, 2, 2, 4, 2, 0, 2),
#  (351, 42, 'No', 'Travel_Rarely', 544, 'Human Resources', 2, 1, 'Technical Degree', 1, 470, 3, 'Male', 52, 3, 1, 'Human Resources', 3, 'Divorced', 2696, 24017, 0, 'Y', 'Yes', 11, 3, 3, 80, 1, 4, 5, 3, 3, 2, 1, 0),
#  (354, 37, 'No', 'Travel_Rarely', 1319, 'Research & Development', 6, 3, 'Medical', 1, 474, 3, 'Male', 51, 4, 2, 'Research Scientist', 1, 'Divorced', 5974, 17001, 4, 'Y', 'Yes', 13, 3, 1, 80, 2, 13, 2, 3, 7, 7, 6, 7),
#  (374, 27, 'No', 'Travel_Rarely', 1469, 'Research & Development', 1, 2, 'Medical', 1, 497, 4, 'Male', 82, 3, 1, 'Laboratory Technician', 2, 'Divorced', 3816, 17881, 1, 'Y', 'No', 11, 3, 2, 80, 1, 5, 2, 3, 5, 2, 0, 4),
#  (381, 24, 'No', 'Travel_Rarely', 1371, 'Sales', 10, 4, 'Marketing', 1, 507, 4, 'Female', 77, 3, 2, 'Sales Executive', 3, 'Divorced', 4260, 5915, 1, 'Y', 'Yes', 12, 3, 4, 80, 1, 5, 2, 4, 5, 2, 0, 3),
#  (387, 37, 'No', 'Travel_Rarely', 1107, 'Research & Development', 14, 3, 'Life Sciences', 1, 515, 4, 'Female', 95, 3, 1, 'Laboratory Technician', 1, 'Divorced', 3034, 26914, 1, 'Y', 'No', 12, 3, 3, 80, 1, 18, 2, 2, 18, 7, 12, 17),
#  (388, 40, 'No', 'Travel_Rarely', 759, 'Sales', 2, 2, 'Marketing', 1, 516, 4, 'Female', 46, 3, 2, 'Sales Executive', 2, 'Divorced', 5715, 22553, 7, 'Y', 'No', 12, 3, 3, 80, 2, 8, 5, 3, 5, 4, 1, 3),
#  (389, 42, 'No', 'Travel_Rarely', 201, 'Research & Development', 1, 4, 'Life Sciences', 1, 517, 2, 'Female', 95, 3, 1, 'Laboratory Technician', 1, 'Divorced', 2576, 20490, 3, 'Y', 'No', 16, 3, 2, 80, 1, 8, 5, 3, 5, 2, 1, 2),
#  (391, 43, 'No', 'Travel_Rarely', 982, 'Research & Development', 12, 3, 'Life Sciences', 1, 520, 1, 'Male', 59, 2, 4, 'Research Director', 2, 'Divorced', 14336, 4345, 1, 'Y', 'No', 11, 3, 3, 80, 1, 25, 3, 3, 25, 10, 3, 9),
#  (397, 43, 'No', 'Travel_Rarely', 1473, 'Research & Development', 8, 4, 'Other', 1, 526, 3, 'Female', 74, 3, 2, 'Healthcare Representative', 3, 'Divorced', 4522, 2227, 4, 'Y', 'Yes', 14, 3, 4, 80, 0, 8, 3, 3, 5, 2, 0, 2),
#  (401, 39, 'No', 'Travel_Frequently', 1218, 'Research & Development', 1, 1, 'Life Sciences', 1, 531, 2, 'Male', 52, 3, 5, 'Manager', 3, 'Divorced', 19197, 8213, 1, 'Y', 'Yes', 14, 3, 3, 80, 1, 21, 3, 3, 21, 8, 1, 6),
#  (405, 28, 'No', 'Travel_Rarely', 1300, 'Research & Development', 17, 2, 'Medical', 1, 536, 3, 'Male', 79, 3, 2, 'Laboratory Technician', 1, 'Divorced', 4558, 13535, 1, 'Y', 'No', 12, 3, 4, 80, 1, 10, 2, 3, 10, 0, 1, 8),
#  (410, 42, 'No', 'Travel_Frequently', 532, 'Research & Development', 29, 2, 'Life Sciences', 1, 547, 1, 'Female', 92, 3, 2, 'Research Scientist', 3, 'Divorced', 4556, 12932, 2, 'Y', 'No', 11, 3, 2, 80, 1, 19, 3, 3, 5, 4, 0, 2),
#  (413, 46, 'No', 'Travel_Rarely', 1485, 'Research & Development', 18, 3, 'Medical', 1, 550, 3, 'Female', 87, 3, 2, 'Manufacturing Director', 3, 'Divorced', 4810, 26314, 2, 'Y', 'No', 14, 3, 3, 80, 1, 19, 5, 2, 10, 7, 0, 8),
#  (416, 34, 'Yes', 'Travel_Frequently', 296, 'Sales', 6, 2, 'Marketing', 1, 555, 4, 'Female', 33, 1, 1, 'Sales Representative', 3, 'Divorced', 2351, 12253, 0, 'Y', 'No', 16, 3, 4, 80, 1, 3, 3, 2, 2, 2, 1, 0),
#  (419, 26, 'No', 'Travel_Rarely', 1349, 'Research & Development', 23, 3, 'Life Sciences', 1, 560, 1, 'Female', 90, 3, 1, 'Research Scientist', 4, 'Divorced', 2886, 3032, 1, 'Y', 'No', 22, 4, 2, 80, 2, 3, 3, 1, 3, 2, 0, 2),
#  (425, 57, 'No', 'Travel_Rarely', 210, 'Sales', 29, 3, 'Marketing', 1, 568, 1, 'Male', 56, 2, 4, 'Manager', 4, 'Divorced', 14118, 22102, 3, 'Y', 'No', 12, 3, 3, 80, 1, 32, 3, 2, 1, 0, 0, 0),
#  (429, 47, 'No', 'Travel_Rarely', 983, 'Research & Development', 2, 2, 'Medical', 1, 574, 1, 'Female', 65, 3, 2, 'Manufacturing Director', 4, 'Divorced', 5070, 7389, 5, 'Y', 'No', 13, 3, 3, 80, 3, 20, 2, 3, 5, 0, 0, 4),
#  (433, 34, 'No', 'Travel_Rarely', 1303, 'Research & Development', 2, 4, 'Life Sciences', 1, 579, 4, 'Male', 62, 2, 1, 'Research Scientist', 3, 'Divorced', 2768, 8416, 3, 'Y', 'No', 12, 3, 3, 80, 1, 14, 3, 3, 7, 3, 5, 7),
#  (435, 31, 'No', 'Travel_Rarely', 1274, 'Research & Development', 9, 1, 'Life Sciences', 1, 581, 3, 'Male', 33, 3, 3, 'Manufacturing Director', 2, 'Divorced', 10648, 14394, 1, 'Y', 'No', 25, 4, 4, 80, 1, 13, 6, 4, 13, 8, 0, 8),
#  (437, 33, 'Yes', 'Travel_Rarely', 587, 'Research & Development', 10, 1, 'Medical', 1, 584, 1, 'Male', 38, 1, 1, 'Laboratory Technician', 4, 'Divorced', 3408, 6705, 7, 'Y', 'No', 13, 3, 1, 80, 3, 8, 2, 3, 4, 3, 1, 3),
#  (441, 34, 'Yes', 'Travel_Frequently', 988, 'Human Resources', 23, 3, 'Human Resources', 1, 590, 2, 'Female', 43, 3, 3, 'Human Resources', 1, 'Divorced', 9950, 11533, 9, 'Y', 'Yes', 15, 3, 3, 80, 3, 11, 2, 3, 3, 2, 0, 2),
#  (454, 26, 'Yes', 'Travel_Frequently', 426, 'Human Resources', 17, 4, 'Life Sciences', 1, 608, 2, 'Female', 58, 3, 1, 'Human Resources', 3, 'Divorced', 2741, 22808, 0, 'Y', 'Yes', 11, 3, 2, 80, 1, 8, 2, 2, 7, 7, 1, 0),
#  (455, 29, 'No', 'Travel_Rarely', 232, 'Research & Development', 19, 3, 'Technical Degree', 1, 611, 4, 'Male', 34, 3, 2, 'Manufacturing Director', 4, 'Divorced', 4262, 22645, 4, 'Y', 'No', 12, 3, 2, 80, 2, 8, 2, 4, 3, 2, 1, 2),
#  (456, 33, 'No', 'Travel_Rarely', 922, 'Research & Development', 1, 5, 'Medical', 1, 612, 1, 'Female', 95, 4, 4, 'Research Director', 3, 'Divorced', 16184, 22578, 4, 'Y', 'No', 19, 3, 3, 80, 1, 10, 2, 3, 6, 1, 0, 5),
#  (457, 31, 'No', 'Travel_Rarely', 688, 'Sales', 7, 3, 'Life Sciences', 1, 613, 3, 'Male', 44, 2, 3, 'Manager', 4, 'Divorced', 11557, 25291, 9, 'Y', 'No', 21, 4, 3, 80, 1, 10, 3, 2, 5, 4, 0, 1),
#  (459, 40, 'No', 'Non-Travel', 1094, 'Sales', 28, 3, 'Other', 1, 615, 3, 'Male', 58, 1, 3, 'Sales Executive', 1, 'Divorced', 10932, 11373, 3, 'Y', 'No', 15, 3, 3, 80, 1, 20, 2, 3, 1, 0, 0, 1),
#  (461, 26, 'No', 'Travel_Rarely', 775, 'Sales', 29, 2, 'Medical', 1, 618, 1, 'Male', 45, 3, 2, 'Sales Executive', 3, 'Divorced', 4306, 4267, 5, 'Y', 'No', 12, 3, 1, 80, 2, 8, 5, 3, 0, 0, 0, 0),
#  (468, 37, 'No', 'Non-Travel', 142, 'Sales', 9, 4, 'Medical', 1, 626, 1, 'Male', 69, 3, 3, 'Sales Executive', 2, 'Divorced', 8834, 24666, 1, 'Y', 'No', 13, 3, 4, 80, 1, 9, 6, 3, 9, 5, 7, 7),
#  (469, 52, 'No', 'Travel_Rarely', 956, 'Research & Development', 6, 2, 'Technical Degree', 1, 630, 4, 'Male', 78, 3, 2, 'Research Scientist', 1, 'Divorced', 5577, 22087, 3, 'Y', 'Yes', 12, 3, 2, 80, 2, 18, 3, 3, 10, 9, 6, 9),
#  (474, 49, 'No', 'Travel_Rarely', 1245, 'Research & Development', 18, 4, 'Life Sciences', 1, 638, 4, 'Male', 58, 2, 5, 'Research Director', 3, 'Divorced', 19502, 2125, 1, 'Y', 'Yes', 17, 3, 3, 80, 1, 31, 5, 3, 31, 9, 0, 9),
#  (483, 31, 'Yes', 'Travel_Rarely', 1365, 'Sales', 13, 4, 'Medical', 1, 650, 2, 'Male', 46, 3, 2, 'Sales Executive', 1, 'Divorced', 4233, 11512, 2, 'Y', 'No', 17, 3, 3, 80, 0, 9, 2, 1, 3, 1, 1, 2),
#  (485, 31, 'No', 'Travel_Rarely', 525, 'Sales', 6, 4, 'Medical', 1, 653, 1, 'Male', 66, 4, 2, 'Sales Executive', 4, 'Divorced', 5460, 6219, 4, 'Y', 'No', 22, 4, 4, 80, 2, 13, 4, 4, 7, 7, 5, 7),
#  (486, 27, 'No', 'Travel_Rarely', 798, 'Research & Development', 6, 4, 'Medical', 1, 655, 1, 'Female', 66, 2, 1, 'Research Scientist', 3, 'Divorced', 2187, 5013, 0, 'Y', 'No', 12, 3, 3, 80, 2, 6, 5, 2, 5, 3, 0, 3),
#  (490, 43, 'No', 'Travel_Rarely', 782, 'Research & Development', 6, 4, 'Other', 1, 661, 2, 'Male', 50, 2, 4, 'Research Director', 4, 'Divorced', 16627, 2671, 4, 'Y', 'Yes', 14, 3, 3, 80, 1, 21, 3, 2, 1, 0, 0, 0),
#  (492, 43, 'No', 'Travel_Frequently', 1001, 'Research & Development', 9, 5, 'Medical', 1, 663, 4, 'Male', 72, 3, 2, 'Laboratory Technician', 3, 'Divorced', 5679, 19627, 3, 'Y', 'Yes', 13, 3, 2, 80, 1, 10, 3, 3, 8, 7, 4, 7),
#  (495, 34, 'No', 'Travel_Rarely', 204, 'Sales', 14, 3, 'Technical Degree', 1, 666, 3, 'Female', 31, 3, 1, 'Sales Representative', 3, 'Divorced', 2579, 2912, 1, 'Y', 'Yes', 18, 3, 4, 80, 2, 8, 3, 3, 8, 2, 0, 6),
#  (496, 27, 'Yes', 'Travel_Rarely', 1420, 'Sales', 2, 1, 'Marketing', 1, 667, 3, 'Male', 85, 3, 1, 'Sales Representative', 1, 'Divorced', 3041, 16346, 0, 'Y', 'No', 11, 3, 2, 80, 1, 5, 3, 3, 4, 3, 0, 2),
#  (500, 33, 'No', 'Travel_Rarely', 1216, 'Sales', 8, 4, 'Marketing', 1, 677, 3, 'Male', 39, 3, 2, 'Sales Executive', 3, 'Divorced', 7104, 20431, 0, 'Y', 'No', 12, 3, 4, 80, 0, 6, 3, 3, 5, 0, 1, 2),
#  (502, 30, 'No', 'Travel_Frequently', 160, 'Research & Development', 3, 3, 'Medical', 1, 680, 3, 'Female', 71, 3, 1, 'Research Scientist', 3, 'Divorced', 2083, 22653, 1, 'Y', 'No', 20, 4, 3, 80, 1, 1, 2, 3, 1, 0, 0, 0),
#  (510, 33, 'No', 'Travel_Frequently', 1296, 'Research & Development', 6, 3, 'Life Sciences', 1, 692, 3, 'Male', 30, 3, 2, 'Healthcare Representative', 4, 'Divorced', 7725, 5335, 3, 'Y', 'No', 23, 4, 3, 80, 1, 15, 2, 1, 13, 11, 4, 7),
#  (512, 36, 'No', 'Travel_Rarely', 913, 'Research & Development', 9, 2, 'Medical', 1, 699, 2, 'Male', 48, 2, 2, 'Manufacturing Director', 2, 'Divorced', 8847, 13934, 2, 'Y', 'Yes', 11, 3, 3, 80, 1, 13, 2, 3, 3, 2, 0, 2),
#  (520, 29, 'No', 'Travel_Frequently', 806, 'Research & Development', 1, 4, 'Life Sciences', 1, 710, 2, 'Male', 76, 1, 1, 'Research Scientist', 4, 'Divorced', 2720, 18959, 1, 'Y', 'No', 18, 3, 4, 80, 1, 10, 5, 3, 10, 7, 2, 8),
#  (522, 27, 'No', 'Travel_Frequently', 1410, 'Sales', 3, 1, 'Medical', 1, 714, 4, 'Female', 71, 4, 2, 'Sales Executive', 4, 'Divorced', 4647, 16673, 1, 'Y', 'Yes', 20, 4, 2, 80, 2, 6, 3, 3, 6, 5, 0, 4),
#  (536, 41, 'No', 'Travel_Rarely', 427, 'Human Resources', 10, 4, 'Human Resources', 1, 731, 2, 'Male', 73, 2, 5, 'Manager', 4, 'Divorced', 19141, 8861, 3, 'Y', 'No', 15, 3, 2, 80, 3, 23, 2, 2, 21, 6, 12, 6),
#  (538, 27, 'No', 'Travel_Frequently', 294, 'Research & Development', 10, 2, 'Life Sciences', 1, 733, 4, 'Male', 32, 3, 3, 'Manufacturing Director', 1, 'Divorced', 8793, 4809, 1, 'Y', 'No', 21, 4, 3, 80, 2, 9, 4, 2, 9, 7, 1, 7),
#  (545, 47, 'No', 'Travel_Frequently', 217, 'Sales', 3, 3, 'Medical', 1, 746, 4, 'Female', 49, 3, 4, 'Sales Executive', 3, 'Divorced', 13770, 10225, 9, 'Y', 'Yes', 12, 3, 4, 80, 2, 28, 2, 2, 22, 2, 11, 13),
#  (546, 30, 'No', 'Travel_Rarely', 501, 'Sales', 27, 5, 'Marketing', 1, 747, 3, 'Male', 99, 3, 2, 'Sales Executive', 4, 'Divorced', 5304, 25275, 7, 'Y', 'No', 23, 4, 4, 80, 1, 10, 2, 2, 8, 7, 7, 7),
#  (548, 42, 'Yes', 'Travel_Frequently', 933, 'Research & Development', 19, 3, 'Medical', 1, 752, 3, 'Male', 57, 4, 1, 'Research Scientist', 3, 'Divorced', 2759, 20366, 6, 'Y', 'Yes', 12, 3, 4, 80, 0, 7, 2, 3, 2, 2, 2, 2),
#  (556, 29, 'No', 'Travel_Rarely', 1090, 'Sales', 10, 3, 'Marketing', 1, 766, 4, 'Male', 83, 3, 1, 'Sales Representative', 2, 'Divorced', 2297, 17967, 1, 'Y', 'No', 14, 3, 4, 80, 2, 2, 2, 3, 2, 2, 2, 2),
#  (558, 35, 'No', 'Non-Travel', 1225, 'Research & Development', 2, 4, 'Life Sciences', 1, 771, 4, 'Female', 61, 3, 2, 'Healthcare Representative', 1, 'Divorced', 5093, 4761, 2, 'Y', 'No', 11, 3, 1, 80, 1, 16, 2, 4, 1, 0, 0, 0),
#  (561, 34, 'No', 'Travel_Rarely', 167, 'Research & Development', 8, 5, 'Life Sciences', 1, 775, 2, 'Female', 32, 3, 2, 'Manufacturing Director', 1, 'Divorced', 5121, 4187, 3, 'Y', 'No', 14, 3, 3, 80, 1, 7, 3, 3, 0, 0, 0, 0),
#  (572, 26, 'No', 'Travel_Frequently', 575, 'Research & Development', 1, 2, 'Life Sciences', 1, 792, 1, 'Female', 71, 1, 1, 'Laboratory Technician', 4, 'Divorced', 4364, 5288, 3, 'Y', 'No', 14, 3, 1, 80, 1, 5, 2, 3, 2, 2, 2, 0),
#  (576, 54, 'No', 'Travel_Rarely', 376, 'Research & Development', 19, 4, 'Medical', 1, 799, 4, 'Female', 95, 3, 2, 'Manufacturing Director', 1, 'Divorced', 5485, 22670, 9, 'Y', 'Yes', 11, 3, 2, 80, 2, 9, 4, 3, 5, 3, 1, 4),
#  (578, 37, 'No', 'Travel_Rarely', 571, 'Research & Development', 10, 1, 'Life Sciences', 1, 802, 4, 'Female', 82, 3, 1, 'Research Scientist', 1, 'Divorced', 2782, 19905, 0, 'Y', 'Yes', 13, 3, 2, 80, 2, 6, 3, 2, 5, 3, 4, 3),
#  (585, 42, 'No', 'Travel_Frequently', 570, 'Research & Development', 8, 3, 'Life Sciences', 1, 809, 2, 'Male', 66, 3, 5, 'Manager', 4, 'Divorced', 18430, 16225, 1, 'Y', 'No', 13, 3, 2, 80, 1, 24, 4, 2, 24, 7, 14, 9),
#  (587, 24, 'No', 'Non-Travel', 1092, 'Research & Development', 9, 3, 'Life Sciences', 1, 812, 3, 'Male', 60, 2, 1, 'Laboratory Technician', 2, 'Divorced', 2694, 26551, 1, 'Y', 'No', 11, 3, 3, 80, 3, 1, 4, 3, 1, 0, 0, 0),
#  (606, 38, 'No', 'Travel_Frequently', 471, 'Research & Development', 12, 3, 'Life Sciences', 1, 837, 1, 'Male', 45, 2, 2, 'Healthcare Representative', 1, 'Divorced', 6288, 4284, 2, 'Y', 'No', 15, 3, 3, 80, 1, 13, 3, 2, 4, 3, 1, 2),
#  (611, 27, 'No', 'Travel_Rarely', 269, 'Research & Development', 5, 1, 'Technical Degree', 1, 844, 3, 'Male', 42, 2, 3, 'Research Director', 4, 'Divorced', 12808, 8842, 1, 'Y', 'Yes', 16, 3, 2, 80, 1, 9, 3, 3, 9, 8, 0, 8),
#  (620, 33, 'No', 'Travel_Rarely', 586, 'Sales', 1, 3, 'Medical', 1, 855, 1, 'Male', 48, 4, 2, 'Sales Executive', 1, 'Divorced', 4037, 21816, 1, 'Y', 'No', 22, 4, 1, 80, 1, 9, 5, 3, 9, 8, 0, 8),
#  (623, 32, 'No', 'Travel_Rarely', 117, 'Sales', 13, 4, 'Life Sciences', 1, 859, 2, 'Male', 73, 3, 2, 'Sales Executive', 4, 'Divorced', 4403, 9250, 2, 'Y', 'No', 11, 3, 3, 80, 1, 8, 3, 2, 5, 2, 0, 3),
#  (624, 30, 'No', 'Travel_Frequently', 1012, 'Research & Development', 5, 4, 'Life Sciences', 1, 861, 2, 'Male', 75, 2, 1, 'Research Scientist', 4, 'Divorced', 3761, 2373, 9, 'Y', 'No', 12, 3, 2, 80, 1, 10, 3, 2, 5, 4, 0, 3),
#  (626, 45, 'No', 'Travel_Rarely', 930, 'Sales', 9, 3, 'Marketing', 1, 864, 4, 'Male', 74, 3, 3, 'Sales Executive', 1, 'Divorced', 10761, 19239, 4, 'Y', 'Yes', 12, 3, 3, 80, 1, 18, 2, 3, 5, 4, 0, 2),
#  (629, 37, 'No', 'Travel_Rarely', 342, 'Sales', 16, 4, 'Marketing', 1, 868, 4, 'Male', 66, 2, 2, 'Sales Executive', 3, 'Divorced', 6334, 24558, 4, 'Y', 'No', 19, 3, 4, 80, 2, 9, 2, 3, 1, 0, 0, 0),
#  (630, 28, 'No', 'Travel_Rarely', 1169, 'Human Resources', 8, 2, 'Medical', 1, 869, 2, 'Male', 63, 2, 1, 'Human Resources', 4, 'Divorced', 4936, 23965, 1, 'Y', 'No', 13, 3, 4, 80, 1, 6, 6, 3, 5, 1, 0, 4),
#  (637, 35, 'Yes', 'Travel_Frequently', 130, 'Research & Development', 25, 4, 'Life Sciences', 1, 881, 4, 'Female', 96, 3, 1, 'Research Scientist', 2, 'Divorced', 2022, 16612, 1, 'Y', 'Yes', 19, 3, 1, 80, 1, 10, 3, 2, 10, 2, 7, 8),
#  (638, 32, 'No', 'Non-Travel', 300, 'Research & Development', 1, 3, 'Life Sciences', 1, 882, 4, 'Male', 61, 3, 1, 'Laboratory Technician', 4, 'Divorced', 2314, 9148, 0, 'Y', 'No', 12, 3, 2, 80, 1, 4, 2, 3, 3, 0, 0, 2),
#  (646, 29, 'Yes', 'Travel_Rarely', 341, 'Sales', 1, 3, 'Medical', 1, 896, 2, 'Female', 48, 2, 1, 'Sales Representative', 3, 'Divorced', 2800, 23522, 6, 'Y', 'Yes', 19, 3, 3, 80, 3, 5, 3, 3, 3, 2, 0, 2),
#  (654, 50, 'No', 'Non-Travel', 881, 'Research & Development', 2, 4, 'Life Sciences', 1, 905, 1, 'Male', 98, 3, 4, 'Manager', 1, 'Divorced', 17924, 4544, 1, 'Y', 'No', 11, 3, 4, 80, 1, 31, 3, 3, 31, 6, 14, 7),
#  (656, 33, 'No', 'Travel_Rarely', 1075, 'Human Resources', 3, 2, 'Human Resources', 1, 910, 4, 'Male', 57, 3, 1, 'Human Resources', 2, 'Divorced', 2277, 22650, 3, 'Y', 'Yes', 11, 3, 3, 80, 1, 7, 4, 4, 4, 3, 0, 3),
#  (658, 29, 'No', 'Travel_Rarely', 1086, 'Research & Development', 7, 1, 'Medical', 1, 912, 1, 'Female', 62, 2, 1, 'Laboratory Technician', 4, 'Divorced', 2532, 6054, 6, 'Y', 'No', 14, 3, 3, 80, 3, 8, 5, 3, 4, 3, 0, 3),
#  (661, 58, 'Yes', 'Travel_Frequently', 781, 'Research & Development', 2, 1, 'Life Sciences', 1, 918, 4, 'Male', 57, 2, 1, 'Laboratory Technician', 4, 'Divorced', 2380, 13384, 9, 'Y', 'Yes', 14, 3, 4, 80, 1, 3, 3, 2, 1, 0, 0, 0),
#  (662, 43, 'No', 'Travel_Rarely', 177, 'Research & Development', 8, 3, 'Life Sciences', 1, 920, 1, 'Female', 55, 3, 2, 'Manufacturing Director', 2, 'Divorced', 4765, 23814, 4, 'Y', 'No', 21, 4, 3, 80, 1, 4, 2, 4, 1, 0, 0, 0),
#  (668, 41, 'Yes', 'Travel_Rarely', 1085, 'Research & Development', 2, 4, 'Life Sciences', 1, 927, 2, 'Female', 57, 1, 1, 'Laboratory Technician', 4, 'Divorced', 2778, 17725, 4, 'Y', 'Yes', 13, 3, 3, 80, 1, 10, 1, 2, 7, 7, 1, 0),
#  (669, 28, 'No', 'Travel_Rarely', 995, 'Research & Development', 9, 3, 'Medical', 1, 930, 3, 'Female', 77, 3, 1, 'Research Scientist', 3, 'Divorced', 2377, 9834, 5, 'Y', 'No', 18, 3, 2, 80, 1, 6, 2, 3, 2, 2, 2, 2),
#  (672, 34, 'No', 'Travel_Rarely', 546, 'Research & Development', 10, 3, 'Life Sciences', 1, 934, 2, 'Male', 83, 3, 1, 'Laboratory Technician', 2, 'Divorced', 2008, 6896, 1, 'Y', 'No', 14, 3, 2, 80, 2, 1, 3, 3, 1, 0, 1, 0),
#  (675, 58, 'No', 'Travel_Rarely', 1272, 'Research & Development', 5, 3, 'Technical Degree', 1, 940, 3, 'Female', 37, 2, 3, 'Healthcare Representative', 2, 'Divorced', 10552, 9255, 2, 'Y', 'Yes', 13, 3, 4, 80, 1, 24, 3, 3, 6, 0, 0, 4),
#  (685, 40, 'No', 'Travel_Rarely', 658, 'Sales', 10, 4, 'Marketing', 1, 954, 1, 'Male', 67, 2, 3, 'Sales Executive', 2, 'Divorced', 9705, 20652, 2, 'Y', 'No', 12, 3, 2, 80, 1, 11, 2, 2, 1, 0, 0, 0),
#  (692, 40, 'No', 'Travel_Frequently', 1469, 'Research & Development', 9, 4, 'Medical', 1, 964, 4, 'Male', 35, 3, 1, 'Research Scientist', 2, 'Divorced', 3617, 25063, 8, 'Y', 'Yes', 14, 3, 4, 80, 1, 3, 2, 3, 1, 1, 0, 0),
#  (702, 53, 'No', 'Travel_Rarely', 1376, 'Sales', 2, 2, 'Medical', 1, 981, 3, 'Male', 45, 3, 4, 'Manager', 3, 'Divorced', 14852, 13938, 6, 'Y', 'No', 13, 3, 3, 80, 1, 22, 3, 4, 17, 13, 15, 2),
#  (703, 30, 'No', 'Travel_Rarely', 231, 'Sales', 8, 2, 'Other', 1, 982, 3, 'Male', 62, 3, 3, 'Sales Executive', 3, 'Divorced', 7264, 9977, 5, 'Y', 'No', 11, 3, 1, 80, 1, 10, 2, 4, 8, 4, 7, 7),
#  (705, 35, 'No', 'Travel_Rarely', 882, 'Sales', 3, 4, 'Life Sciences', 1, 984, 4, 'Male', 92, 3, 3, 'Sales Executive', 4, 'Divorced', 7823, 6812, 6, 'Y', 'No', 13, 3, 2, 80, 1, 12, 2, 3, 10, 9, 0, 8),
#  (708, 47, 'No', 'Travel_Frequently', 1379, 'Research & Development', 16, 4, 'Medical', 1, 987, 3, 'Male', 64, 4, 2, 'Manufacturing Director', 3, 'Divorced', 5067, 6759, 1, 'Y', 'Yes', 19, 3, 3, 80, 0, 20, 3, 4, 19, 10, 2, 7),
#  (709, 36, 'No', 'Non-Travel', 1229, 'Sales', 8, 4, 'Technical Degree', 1, 990, 1, 'Male', 84, 3, 2, 'Sales Executive', 4, 'Divorced', 5079, 25952, 4, 'Y', 'No', 13, 3, 4, 80, 2, 12, 3, 3, 7, 7, 0, 7),
#  (714, 45, 'No', 'Travel_Rarely', 974, 'Research & Development', 1, 4, 'Medical', 1, 996, 4, 'Female', 91, 3, 1, 'Laboratory Technician', 4, 'Divorced', 2270, 11005, 3, 'Y', 'No', 14, 3, 4, 80, 2, 8, 2, 3, 5, 3, 0, 2),
#  (715, 50, 'No', 'Travel_Rarely', 1126, 'Research & Development', 1, 2, 'Medical', 1, 997, 4, 'Male', 66, 3, 4, 'Research Director', 4, 'Divorced', 17399, 6615, 9, 'Y', 'No', 22, 4, 3, 80, 1, 32, 1, 2, 5, 4, 1, 3),
#  (717, 41, 'No', 'Travel_Frequently', 840, 'Research & Development', 9, 3, 'Medical', 1, 999, 1, 'Male', 64, 3, 5, 'Research Director', 3, 'Divorced', 19419, 3735, 2, 'Y', 'No', 17, 3, 2, 80, 1, 21, 2, 4, 18, 16, 0, 11),
#  (724, 46, 'No', 'Travel_Rarely', 566, 'Research & Development', 7, 2, 'Medical', 1, 1007, 4, 'Male', 75, 3, 3, 'Manufacturing Director', 3, 'Divorced', 10845, 24208, 6, 'Y', 'No', 13, 3, 2, 80, 1, 13, 3, 3, 8, 7, 0, 7),
#  (725, 24, 'No', 'Travel_Rarely', 1206, 'Research & Development', 17, 1, 'Medical', 1, 1009, 4, 'Female', 41, 2, 2, 'Manufacturing Director', 3, 'Divorced', 4377, 24117, 1, 'Y', 'No', 15, 3, 2, 80, 2, 5, 6, 3, 4, 2, 3, 2),
#  (726, 35, 'Yes', 'Travel_Rarely', 622, 'Research & Development', 14, 4, 'Other', 1, 1010, 3, 'Male', 39, 2, 1, 'Laboratory Technician', 2, 'Divorced', 3743, 10074, 1, 'Y', 'Yes', 24, 4, 4, 80, 1, 5, 2, 1, 4, 2, 0, 2),
#  (730, 35, 'No', 'Travel_Rarely', 583, 'Research & Development', 25, 4, 'Medical', 1, 1014, 3, 'Female', 57, 3, 3, 'Healthcare Representative', 3, 'Divorced', 10388, 6975, 1, 'Y', 'Yes', 11, 3, 3, 80, 1, 16, 3, 2, 16, 10, 10, 1),
#  (741, 35, 'No', 'Travel_Rarely', 802, 'Research & Development', 10, 3, 'Other', 1, 1028, 2, 'Male', 45, 3, 1, 'Laboratory Technician', 4, 'Divorced', 3917, 9541, 1, 'Y', 'No', 20, 4, 1, 80, 1, 3, 4, 2, 3, 2, 1, 2),
#  (747, 41, 'No', 'Non-Travel', 247, 'Research & Development', 7, 1, 'Life Sciences', 1, 1035, 2, 'Female', 55, 1, 5, 'Research Director', 3, 'Divorced', 19973, 20284, 1, 'Y', 'No', 22, 4, 2, 80, 2, 21, 3, 3, 21, 16, 5, 10),
#  (758, 34, 'No', 'Travel_Rarely', 216, 'Sales', 1, 4, 'Marketing', 1, 1047, 2, 'Male', 75, 4, 2, 'Sales Executive', 4, 'Divorced', 9725, 12278, 0, 'Y', 'No', 11, 3, 4, 80, 1, 16, 2, 2, 15, 1, 0, 9),
#  (762, 36, 'Yes', 'Travel_Rarely', 660, 'Research & Development', 15, 3, 'Other', 1, 1052, 1, 'Male', 81, 3, 2, 'Laboratory Technician', 3, 'Divorced', 4834, 7858, 7, 'Y', 'No', 14, 3, 2, 80, 1, 9, 3, 2, 1, 0, 0, 0),
#  (770, 26, 'No', 'Travel_Frequently', 921, 'Research & Development', 1, 1, 'Medical', 1, 1068, 1, 'Female', 66, 2, 1, 'Research Scientist', 3, 'Divorced', 2007, 25265, 1, 'Y', 'No', 13, 3, 3, 80, 2, 5, 5, 3, 5, 3, 1, 3),
#  (771, 46, 'No', 'Travel_Rarely', 430, 'Research & Development', 1, 4, 'Medical', 1, 1069, 4, 'Male', 40, 3, 5, 'Research Director', 4, 'Divorced', 19627, 21445, 9, 'Y', 'No', 17, 3, 4, 80, 2, 23, 0, 3, 2, 2, 2, 2),
#  (776, 43, 'No', 'Travel_Rarely', 415, 'Sales', 25, 3, 'Medical', 1, 1076, 3, 'Male', 79, 2, 3, 'Sales Executive', 4, 'Divorced', 10798, 5268, 5, 'Y', 'No', 13, 3, 3, 80, 1, 18, 5, 3, 1, 0, 0, 0),
#  (779, 46, 'No', 'Travel_Rarely', 1003, 'Research & Development', 8, 4, 'Life Sciences', 1, 1080, 4, 'Female', 74, 2, 2, 'Research Scientist', 1, 'Divorced', 4615, 21029, 8, 'Y', 'Yes', 23, 4, 1, 80, 3, 19, 2, 3, 16, 13, 1, 7),
#  (791, 33, 'No', 'Travel_Rarely', 654, 'Research & Development', 5, 3, 'Life Sciences', 1, 1099, 4, 'Male', 34, 2, 3, 'Healthcare Representative', 4, 'Divorced', 7119, 21214, 4, 'Y', 'No', 15, 3, 3, 80, 1, 9, 2, 3, 3, 2, 1, 2),
#  (794, 28, 'No', 'Travel_Rarely', 895, 'Research & Development', 15, 2, 'Life Sciences', 1, 1102, 1, 'Male', 50, 3, 1, 'Laboratory Technician', 3, 'Divorced', 2207, 22482, 1, 'Y', 'No', 16, 3, 4, 80, 1, 4, 5, 2, 4, 2, 2, 2),
#  (796, 37, 'No', 'Travel_Rarely', 309, 'Sales', 10, 4, 'Life Sciences', 1, 1105, 4, 'Female', 88, 2, 2, 'Sales Executive', 4, 'Divorced', 6694, 24223, 2, 'Y', 'Yes', 14, 3, 3, 80, 3, 8, 5, 3, 1, 0, 0, 0),
#  (798, 26, 'Yes', 'Travel_Rarely', 1330, 'Research & Development', 21, 3, 'Medical', 1, 1107, 1, 'Male', 37, 3, 1, 'Laboratory Technician', 3, 'Divorced', 2377, 19373, 1, 'Y', 'No', 20, 4, 3, 80, 1, 1, 0, 2, 1, 1, 0, 0),
#  (801, 28, 'Yes', 'Travel_Frequently', 1009, 'Research & Development', 1, 3, 'Medical', 1, 1111, 1, 'Male', 45, 2, 1, 'Laboratory Technician', 2, 'Divorced', 2596, 7160, 1, 'Y', 'No', 15, 3, 1, 80, 2, 1, 2, 3, 1, 0, 0, 0),
#  (808, 38, 'No', 'Travel_Rarely', 770, 'Sales', 10, 4, 'Marketing', 1, 1119, 3, 'Male', 73, 2, 3, 'Sales Executive', 3, 'Divorced', 8740, 5569, 0, 'Y', 'Yes', 14, 3, 2, 80, 2, 9, 2, 3, 8, 7, 2, 7),
#  (809, 29, 'No', 'Travel_Rarely', 1107, 'Research & Development', 28, 4, 'Life Sciences', 1, 1120, 3, 'Female', 93, 3, 1, 'Research Scientist', 4, 'Divorced', 2514, 26968, 4, 'Y', 'No', 22, 4, 1, 80, 1, 11, 1, 3, 7, 5, 1, 7),
#  (810, 28, 'No', 'Travel_Rarely', 950, 'Research & Development', 3, 3, 'Medical', 1, 1121, 4, 'Female', 93, 3, 3, 'Manufacturing Director', 2, 'Divorced', 7655, 8039, 0, 'Y', 'No', 17, 3, 2, 80, 3, 10, 3, 2, 9, 7, 1, 7),
#  (814, 39, 'Yes', 'Travel_Frequently', 203, 'Research & Development', 2, 3, 'Life Sciences', 1, 1127, 1, 'Male', 84, 3, 4, 'Healthcare Representative', 4, 'Divorced', 12169, 13547, 7, 'Y', 'No', 11, 3, 4, 80, 3, 21, 4, 3, 18, 7, 11, 5),
#  (821, 35, 'No', 'Travel_Frequently', 1182, 'Sales', 11, 2, 'Marketing', 1, 1137, 4, 'Male', 54, 3, 2, 'Sales Executive', 4, 'Divorced', 4968, 18500, 1, 'Y', 'No', 11, 3, 4, 80, 1, 5, 3, 3, 5, 2, 0, 2),
#  (824, 29, 'No', 'Travel_Frequently', 490, 'Research & Development', 10, 3, 'Life Sciences', 1, 1143, 4, 'Female', 61, 3, 1, 'Research Scientist', 2, 'Divorced', 3291, 17940, 0, 'Y', 'No', 14, 3, 4, 80, 2, 8, 2, 2, 7, 5, 1, 1),
#  (828, 28, 'No', 'Travel_Frequently', 773, 'Research & Development', 6, 3, 'Life Sciences', 1, 1154, 3, 'Male', 39, 2, 1, 'Research Scientist', 3, 'Divorced', 2703, 22088, 1, 'Y', 'Yes', 14, 3, 4, 80, 1, 3, 2, 3, 3, 1, 0, 2),
#  (833, 37, 'No', 'Travel_Rarely', 367, 'Research & Development', 25, 2, 'Medical', 1, 1161, 3, 'Female', 52, 2, 2, 'Healthcare Representative', 4, 'Divorced', 5731, 17171, 7, 'Y', 'No', 13, 3, 3, 80, 2, 9, 2, 3, 6, 2, 1, 3),
#  (847, 35, 'No', 'Travel_Rarely', 819, 'Research & Development', 2, 3, 'Life Sciences', 1, 1182, 3, 'Male', 44, 2, 3, 'Manufacturing Director', 2, 'Divorced', 10274, 19588, 2, 'Y', 'No', 18, 3, 2, 80, 1, 15, 2, 4, 7, 7, 6, 4),
#  (851, 32, 'No', 'Non-Travel', 862, 'Sales', 2, 1, 'Life Sciences', 1, 1190, 3, 'Female', 76, 3, 1, 'Sales Representative', 1, 'Divorced', 2827, 14947, 1, 'Y', 'No', 12, 3, 3, 80, 3, 1, 3, 3, 1, 0, 0, 0),
#  (852, 56, 'No', 'Travel_Rarely', 718, 'Research & Development', 4, 4, 'Technical Degree', 1, 1191, 4, 'Female', 92, 3, 5, 'Manager', 1, 'Divorced', 19943, 18575, 4, 'Y', 'No', 13, 3, 4, 80, 1, 28, 2, 3, 5, 2, 4, 2),
#  (859, 53, 'No', 'Travel_Rarely', 1223, 'Research & Development', 7, 2, 'Medical', 1, 1201, 4, 'Female', 50, 3, 5, 'Manager', 3, 'Divorced', 18606, 18640, 3, 'Y', 'No', 18, 3, 2, 80, 1, 26, 6, 3, 7, 7, 4, 7),
#  (865, 41, 'Yes', 'Non-Travel', 906, 'Research & Development', 5, 2, 'Life Sciences', 1, 1210, 1, 'Male', 95, 2, 1, 'Research Scientist', 1, 'Divorced', 2107, 20293, 6, 'Y', 'No', 17, 3, 1, 80, 1, 5, 2, 1, 1, 0, 0, 0),
#  (866, 30, 'No', 'Travel_Rarely', 1329, 'Sales', 29, 4, 'Life Sciences', 1, 1211, 3, 'Male', 61, 3, 2, 'Sales Executive', 1, 'Divorced', 4115, 13192, 8, 'Y', 'No', 19, 3, 3, 80, 3, 8, 3, 3, 4, 3, 0, 3),
#  (874, 36, 'No', 'Travel_Rarely', 917, 'Research & Development', 6, 4, 'Life Sciences', 1, 1221, 3, 'Male', 60, 1, 1, 'Laboratory Technician', 3, 'Divorced', 2741, 6865, 1, 'Y', 'No', 14, 3, 3, 80, 1, 7, 4, 3, 7, 7, 1, 7),
#  (875, 30, 'No', 'Travel_Rarely', 853, 'Research & Development', 7, 4, 'Life Sciences', 1, 1224, 3, 'Male', 49, 3, 2, 'Laboratory Technician', 3, 'Divorced', 3491, 11309, 1, 'Y', 'No', 13, 3, 1, 80, 3, 10, 4, 2, 10, 7, 8, 9),
#  (878, 46, 'No', 'Travel_Rarely', 150, 'Research & Development', 2, 4, 'Technical Degree', 1, 1228, 4, 'Male', 60, 3, 2, 'Manufacturing Director', 4, 'Divorced', 7379, 17433, 2, 'Y', 'No', 11, 3, 3, 80, 1, 12, 3, 2, 6, 3, 1, 4),
#  (880, 60, 'No', 'Travel_Rarely', 696, 'Sales', 7, 4, 'Marketing', 1, 1233, 2, 'Male', 52, 4, 2, 'Sales Executive', 4, 'Divorced', 5220, 10893, 0, 'Y', 'Yes', 18, 3, 2, 80, 1, 12, 3, 3, 11, 7, 1, 9),
#  (883, 36, 'No', 'Travel_Rarely', 363, 'Research & Development', 1, 3, 'Technical Degree', 1, 1237, 3, 'Female', 77, 1, 3, 'Manufacturing Director', 1, 'Divorced', 10252, 4235, 2, 'Y', 'Yes', 21, 4, 3, 80, 1, 17, 2, 3, 7, 7, 7, 7),
#  (885, 40, 'No', 'Travel_Rarely', 107, 'Sales', 10, 3, 'Technical Degree', 1, 1239, 2, 'Female', 84, 2, 2, 'Sales Executive', 2, 'Divorced', 6852, 11591, 7, 'Y', 'No', 12, 3, 2, 80, 1, 7, 2, 4, 5, 1, 1, 3),
#  (891, 54, 'No', 'Travel_Frequently', 966, 'Research & Development', 1, 4, 'Life Sciences', 1, 1245, 4, 'Female', 53, 3, 3, 'Manufacturing Director', 3, 'Divorced', 10502, 9659, 7, 'Y', 'No', 17, 3, 1, 80, 1, 33, 2, 1, 5, 4, 1, 4),
#  (894, 29, 'No', 'Travel_Rarely', 1010, 'Research & Development', 1, 3, 'Life Sciences', 1, 1249, 1, 'Female', 97, 3, 1, 'Research Scientist', 4, 'Divorced', 3760, 5598, 1, 'Y', 'No', 15, 3, 1, 80, 3, 3, 5, 3, 3, 2, 1, 2),
#  (903, 27, 'No', 'Travel_Rarely', 1167, 'Research & Development', 4, 2, 'Life Sciences', 1, 1259, 1, 'Male', 76, 3, 1, 'Research Scientist', 3, 'Divorced', 2517, 3208, 1, 'Y', 'No', 11, 3, 2, 80, 3, 5, 2, 3, 5, 3, 0, 3),
#  (904, 29, 'No', 'Travel_Rarely', 1329, 'Research & Development', 7, 3, 'Life Sciences', 1, 1260, 3, 'Male', 82, 3, 2, 'Healthcare Representative', 4, 'Divorced', 6623, 4204, 1, 'Y', 'Yes', 11, 3, 2, 80, 2, 6, 2, 3, 6, 0, 1, 0),
#  (906, 29, 'No', 'Travel_Rarely', 694, 'Research & Development', 1, 3, 'Life Sciences', 1, 1264, 4, 'Female', 87, 2, 4, 'Research Director', 4, 'Divorced', 16124, 3423, 3, 'Y', 'No', 14, 3, 2, 80, 2, 9, 2, 2, 7, 7, 1, 7),
#  (909, 33, 'No', 'Travel_Rarely', 536, 'Sales', 10, 5, 'Marketing', 1, 1268, 4, 'Male', 82, 4, 3, 'Sales Executive', 3, 'Divorced', 8380, 21708, 0, 'Y', 'Yes', 14, 3, 4, 80, 2, 10, 3, 3, 9, 8, 0, 8),
#  (915, 55, 'No', 'Non-Travel', 177, 'Research & Development', 8, 1, 'Medical', 1, 1278, 4, 'Male', 37, 2, 4, 'Healthcare Representative', 2, 'Divorced', 13577, 25592, 1, 'Y', 'Yes', 15, 3, 4, 80, 1, 34, 3, 3, 33, 9, 15, 0),
#  (919, 51, 'No', 'Travel_Frequently', 237, 'Sales', 9, 3, 'Life Sciences', 1, 1282, 4, 'Male', 83, 3, 5, 'Manager', 2, 'Divorced', 19847, 19196, 4, 'Y', 'Yes', 24, 4, 1, 80, 1, 31, 5, 2, 29, 10, 11, 10),
#  (921, 34, 'No', 'Travel_Frequently', 135, 'Research & Development', 19, 3, 'Medical', 1, 1285, 3, 'Female', 46, 3, 2, 'Laboratory Technician', 2, 'Divorced', 4444, 22534, 4, 'Y', 'No', 13, 3, 3, 80, 2, 15, 2, 4, 11, 8, 5, 10),
#  (923, 44, 'No', 'Travel_Rarely', 1199, 'Research & Development', 4, 2, 'Life Sciences', 1, 1288, 3, 'Male', 92, 4, 5, 'Manager', 1, 'Divorced', 19190, 17477, 1, 'Y', 'No', 14, 3, 4, 80, 2, 26, 4, 2, 25, 9, 14, 13),
#  (933, 29, 'Yes', 'Travel_Rarely', 806, 'Research & Development', 7, 3, 'Technical Degree', 1, 1299, 2, 'Female', 39, 3, 1, 'Laboratory Technician', 3, 'Divorced', 3339, 17285, 3, 'Y', 'Yes', 13, 3, 1, 80, 2, 10, 2, 3, 7, 7, 7, 7),
#  (938, 39, 'No', 'Travel_Rarely', 412, 'Research & Development', 13, 4, 'Medical', 1, 1307, 3, 'Female', 94, 2, 4, 'Manager', 2, 'Divorced', 17123, 17334, 6, 'Y', 'Yes', 13, 3, 4, 80, 2, 21, 4, 3, 19, 9, 15, 2),
#  (939, 58, 'No', 'Travel_Rarely', 848, 'Research & Development', 23, 4, 'Life Sciences', 1, 1308, 1, 'Male', 88, 3, 1, 'Research Scientist', 3, 'Divorced', 2372, 26076, 1, 'Y', 'No', 12, 3, 4, 80, 2, 2, 3, 3, 2, 2, 2, 2),
#  (951, 31, 'No', 'Non-Travel', 587, 'Sales', 2, 4, 'Life Sciences', 1, 1324, 4, 'Female', 57, 3, 3, 'Sales Executive', 3, 'Divorced', 9852, 8935, 1, 'Y', 'Yes', 19, 3, 1, 80, 1, 10, 5, 2, 10, 8, 9, 6),
#  (958, 40, 'No', 'Non-Travel', 458, 'Research & Development', 16, 2, 'Life Sciences', 1, 1340, 3, 'Male', 74, 3, 1, 'Research Scientist', 3, 'Divorced', 3544, 8532, 9, 'Y', 'No', 16, 3, 2, 80, 1, 6, 0, 3, 4, 2, 0, 0),
# ...
#  (2611, 44, 'No', 'Travel_Rarely', 1313, 'Research & Development', 7, 3, 'Medical', 1, 1608, 2, 'Female', 31, 3, 5, 'Research Director', 4, 'Divorced', 19049, 3549, 0, 'Y', 'Yes', 14, 3, 4, 80, 1, 23, 4, 2, 22, 7, 1, 10),
#  (2617, 34, 'No', 'Travel_Frequently', 426, 'Research & Development', 10, 4, 'Life Sciences', 1, 1615, 3, 'Male', 42, 4, 2, 'Manufacturing Director', 4, 'Divorced', 4724, 17000, 1, 'Y', 'No', 13, 3, 1, 80, 1, 9, 3, 3, 9, 7, 7, 2),
#  (2620, 27, 'No', 'Travel_Rarely', 1302, 'Research & Development', 19, 3, 'Other', 1, 1619, 4, 'Male', 67, 2, 1, 'Laboratory Technician', 1, 'Divorced', 4066, 16290, 1, 'Y', 'No', 11, 3, 1, 80, 2, 7, 3, 3, 7, 7, 0, 7),
#  (2622, 28, 'No', 'Travel_Rarely', 580, 'Research & Development', 27, 3, 'Medical', 1, 1622, 2, 'Female', 39, 1, 2, 'Manufacturing Director', 1, 'Divorced', 4877, 20460, 0, 'Y', 'No', 21, 4, 2, 80, 1, 6, 5, 2, 5, 3, 0, 0),
#  (2626, 39, 'No', 'Travel_Rarely', 170, 'Research & Development', 3, 2, 'Medical', 1, 1627, 3, 'Male', 76, 2, 2, 'Laboratory Technician', 3, 'Divorced', 3069, 10302, 0, 'Y', 'No', 15, 3, 4, 80, 1, 11, 3, 3, 10, 8, 0, 7),
#  (2631, 45, 'No', 'Travel_Rarely', 1329, 'Research & Development', 2, 2, 'Other', 1, 1635, 4, 'Female', 59, 2, 2, 'Manufacturing Director', 4, 'Divorced', 5770, 5388, 1, 'Y', 'No', 19, 3, 1, 80, 2, 10, 3, 3, 10, 7, 3, 9),
#  (2638, 35, 'Yes', 'Travel_Rarely', 763, 'Sales', 15, 2, 'Medical', 1, 1645, 1, 'Male', 59, 1, 2, 'Sales Executive', 4, 'Divorced', 5440, 22098, 6, 'Y', 'Yes', 14, 3, 4, 80, 2, 7, 2, 2, 2, 2, 2, 2),
#  (2645, 25, 'No', 'Travel_Frequently', 772, 'Research & Development', 2, 1, 'Life Sciences', 1, 1653, 4, 'Male', 77, 4, 2, 'Manufacturing Director', 3, 'Divorced', 5206, 4973, 1, 'Y', 'No', 17, 3, 3, 80, 2, 7, 6, 3, 7, 7, 0, 7),
#  (2648, 50, 'No', 'Travel_Rarely', 813, 'Research & Development', 17, 5, 'Life Sciences', 1, 1656, 4, 'Female', 50, 2, 3, 'Research Director', 1, 'Divorced', 13269, 21981, 5, 'Y', 'No', 15, 3, 3, 80, 3, 19, 3, 3, 14, 11, 1, 11),
#  (2650, 34, 'No', 'Travel_Rarely', 1130, 'Research & Development', 3, 3, 'Life Sciences', 1, 1658, 4, 'Female', 66, 3, 2, 'Research Scientist', 2, 'Divorced', 5433, 19332, 1, 'Y', 'No', 12, 3, 3, 80, 1, 11, 2, 3, 11, 8, 7, 9),
#  (2654, 36, 'No', 'Travel_Rarely', 1040, 'Research & Development', 3, 2, 'Life Sciences', 1, 1664, 4, 'Male', 79, 4, 2, 'Healthcare Representative', 1, 'Divorced', 6842, 26308, 6, 'Y', 'No', 20, 4, 1, 80, 1, 13, 3, 3, 5, 4, 0, 4),
#  (2659, 29, 'No', 'Travel_Rarely', 991, 'Sales', 5, 3, 'Medical', 1, 1669, 1, 'Male', 43, 2, 2, 'Sales Executive', 2, 'Divorced', 4187, 3356, 1, 'Y', 'Yes', 13, 3, 2, 80, 1, 10, 3, 2, 10, 0, 0, 9),
#  (2660, 33, 'No', 'Travel_Rarely', 392, 'Sales', 2, 4, 'Medical', 1, 1670, 4, 'Male', 93, 3, 2, 'Sales Executive', 4, 'Divorced', 5505, 3921, 1, 'Y', 'No', 14, 3, 3, 80, 2, 6, 5, 3, 6, 2, 0, 4),
#  (2661, 32, 'No', 'Travel_Rarely', 977, 'Research & Development', 2, 3, 'Medical', 1, 1671, 4, 'Male', 45, 3, 2, 'Research Scientist', 2, 'Divorced', 5470, 25518, 0, 'Y', 'No', 13, 3, 3, 80, 2, 10, 4, 2, 9, 5, 1, 6),
#  (2663, 49, 'No', 'Travel_Rarely', 464, 'Research & Development', 16, 3, 'Medical', 1, 1674, 4, 'Female', 74, 3, 1, 'Laboratory Technician', 1, 'Divorced', 2587, 24941, 4, 'Y', 'Yes', 16, 3, 2, 80, 1, 17, 2, 2, 2, 2, 2, 2),
#  (2665, 47, 'No', 'Travel_Rarely', 1225, 'Sales', 2, 4, 'Life Sciences', 1, 1676, 2, 'Female', 47, 4, 4, 'Manager', 2, 'Divorced', 15972, 21086, 6, 'Y', 'No', 14, 3, 3, 80, 3, 29, 2, 3, 3, 2, 1, 2),
#  (2669, 33, 'No', 'Non-Travel', 530, 'Sales', 16, 3, 'Life Sciences', 1, 1681, 3, 'Female', 36, 3, 2, 'Sales Executive', 4, 'Divorced', 5368, 16130, 1, 'Y', 'Yes', 25, 4, 3, 80, 1, 7, 2, 3, 6, 5, 1, 2),
#  (2671, 44, 'No', 'Travel_Rarely', 528, 'Human Resources', 1, 3, 'Life Sciences', 1, 1683, 3, 'Female', 44, 3, 1, 'Human Resources', 4, 'Divorced', 3195, 4167, 4, 'Y', 'Yes', 18, 3, 1, 80, 3, 8, 2, 3, 2, 2, 2, 2),
#  (2678, 55, 'No', 'Travel_Rarely', 1441, 'Research & Development', 22, 3, 'Technical Degree', 1, 1694, 1, 'Male', 94, 2, 1, 'Research Scientist', 2, 'Divorced', 3537, 23737, 5, 'Y', 'No', 12, 3, 4, 80, 1, 8, 1, 3, 4, 2, 1, 2),
#  (2680, 60, 'No', 'Travel_Rarely', 370, 'Research & Development', 1, 4, 'Medical', 1, 1697, 3, 'Male', 92, 1, 3, 'Healthcare Representative', 4, 'Divorced', 10883, 20467, 3, 'Y', 'No', 20, 4, 3, 80, 1, 19, 2, 4, 1, 0, 0, 0),
#  (2682, 37, 'No', 'Travel_Frequently', 1278, 'Sales', 1, 4, 'Medical', 1, 1700, 3, 'Male', 31, 1, 2, 'Sales Executive', 4, 'Divorced', 9525, 7677, 1, 'Y', 'No', 14, 3, 3, 80, 2, 6, 2, 2, 6, 3, 1, 3),
#  (2684, 23, 'Yes', 'Travel_Rarely', 427, 'Sales', 7, 3, 'Life Sciences', 1, 1702, 3, 'Male', 99, 3, 1, 'Sales Representative', 4, 'Divorced', 2275, 25103, 1, 'Y', 'Yes', 21, 4, 2, 80, 1, 3, 2, 3, 3, 2, 0, 2),
#  (2701, 24, 'No', 'Travel_Rarely', 506, 'Research & Development', 29, 1, 'Medical', 1, 1725, 2, 'Male', 91, 3, 1, 'Laboratory Technician', 1, 'Divorced', 3907, 3622, 1, 'Y', 'No', 13, 3, 2, 80, 3, 6, 2, 4, 6, 2, 1, 2),
#  (2706, 46, 'No', 'Travel_Rarely', 1277, 'Sales', 2, 3, 'Life Sciences', 1, 1732, 3, 'Male', 74, 3, 3, 'Sales Executive', 4, 'Divorced', 10368, 5596, 4, 'Y', 'Yes', 12, 3, 2, 80, 1, 13, 5, 2, 10, 6, 0, 3),
#  (2707, 36, 'Yes', 'Travel_Rarely', 1456, 'Sales', 13, 5, 'Marketing', 1, 1733, 2, 'Male', 96, 2, 2, 'Sales Executive', 1, 'Divorced', 6134, 8658, 5, 'Y', 'Yes', 13, 3, 2, 80, 3, 16, 3, 3, 2, 2, 2, 2),
#  (2717, 30, 'Yes', 'Travel_Frequently', 600, 'Human Resources', 8, 3, 'Human Resources', 1, 1747, 3, 'Female', 66, 2, 1, 'Human Resources', 4, 'Divorced', 2180, 9732, 6, 'Y', 'No', 11, 3, 3, 80, 1, 6, 0, 2, 4, 2, 1, 2),
#  (2722, 30, 'No', 'Travel_Rarely', 979, 'Sales', 15, 2, 'Marketing', 1, 1754, 3, 'Male', 94, 2, 3, 'Sales Executive', 1, 'Divorced', 7140, 3088, 2, 'Y', 'No', 11, 3, 1, 80, 1, 12, 2, 3, 7, 7, 1, 7),
#  (2729, 29, 'No', 'Travel_Rarely', 590, 'Research & Development', 4, 3, 'Technical Degree', 1, 1762, 4, 'Female', 91, 2, 1, 'Research Scientist', 1, 'Divorced', 2109, 10007, 1, 'Y', 'No', 13, 3, 3, 80, 1, 1, 2, 3, 1, 0, 0, 0),
#  (2734, 42, 'No', 'Travel_Rarely', 855, 'Research & Development', 12, 3, 'Medical', 1, 1768, 2, 'Male', 57, 3, 1, 'Laboratory Technician', 2, 'Divorced', 2766, 8952, 8, 'Y', 'No', 22, 4, 2, 80, 3, 7, 6, 2, 5, 3, 0, 4),
#  (2736, 33, 'No', 'Non-Travel', 775, 'Research & Development', 4, 3, 'Technical Degree', 1, 1771, 4, 'Male', 90, 3, 2, 'Research Scientist', 2, 'Divorced', 3055, 6194, 5, 'Y', 'No', 15, 3, 4, 80, 2, 11, 2, 2, 9, 8, 1, 7),
#  (2737, 41, 'No', 'Travel_Rarely', 548, 'Research & Development', 9, 4, 'Life Sciences', 1, 1772, 3, 'Male', 94, 3, 1, 'Laboratory Technician', 1, 'Divorced', 2289, 20520, 1, 'Y', 'No', 20, 4, 2, 80, 2, 5, 2, 3, 5, 3, 0, 4),
#  (2738, 34, 'No', 'Non-Travel', 1375, 'Sales', 10, 3, 'Life Sciences', 1, 1774, 4, 'Male', 87, 3, 2, 'Sales Executive', 3, 'Divorced', 4001, 12313, 1, 'Y', 'Yes', 14, 3, 3, 80, 1, 15, 3, 3, 15, 14, 0, 7),
#  (2748, 46, 'No', 'Travel_Rarely', 734, 'Research & Development', 2, 4, 'Medical', 1, 1789, 3, 'Male', 46, 3, 5, 'Research Director', 4, 'Divorced', 19328, 14218, 7, 'Y', 'Yes', 17, 3, 3, 80, 1, 24, 3, 3, 2, 1, 2, 2),
#  (2750, 44, 'Yes', 'Travel_Frequently', 429, 'Research & Development', 1, 2, 'Medical', 1, 1792, 3, 'Male', 99, 3, 1, 'Research Scientist', 2, 'Divorced', 2342, 11092, 1, 'Y', 'Yes', 12, 3, 3, 80, 3, 6, 2, 2, 5, 3, 2, 3),
#  (2751, 37, 'No', 'Travel_Rarely', 1239, 'Human Resources', 8, 2, 'Other', 1, 1794, 3, 'Male', 89, 3, 2, 'Human Resources', 2, 'Divorced', 4071, 12832, 2, 'Y', 'No', 13, 3, 3, 80, 0, 19, 4, 2, 10, 0, 4, 7),
#  (2759, 35, 'No', 'Non-Travel', 1180, 'Research & Development', 2, 2, 'Medical', 1, 1804, 2, 'Male', 90, 3, 2, 'Manufacturing Director', 4, 'Divorced', 5762, 24442, 2, 'Y', 'No', 14, 3, 3, 80, 1, 15, 6, 3, 7, 7, 1, 7),
#  (2760, 38, 'No', 'Non-Travel', 1336, 'Human Resources', 2, 3, 'Human Resources', 1, 1805, 1, 'Male', 100, 3, 1, 'Human Resources', 2, 'Divorced', 2592, 7129, 5, 'Y', 'No', 13, 3, 4, 80, 3, 13, 3, 3, 11, 10, 3, 8),
#  (2763, 39, 'No', 'Travel_Frequently', 766, 'Sales', 20, 3, 'Life Sciences', 1, 1812, 3, 'Male', 83, 3, 2, 'Sales Executive', 4, 'Divorced', 4127, 19188, 2, 'Y', 'No', 18, 3, 4, 80, 1, 7, 6, 3, 2, 1, 2, 2),
#  (2766, 41, 'No', 'Travel_Rarely', 796, 'Sales', 4, 1, 'Marketing', 1, 1815, 3, 'Female', 81, 3, 3, 'Sales Executive', 3, 'Divorced', 10447, 26458, 0, 'Y', 'Yes', 13, 3, 4, 80, 1, 23, 3, 4, 22, 14, 13, 5),
#  (2770, 40, 'No', 'Travel_Rarely', 1194, 'Research & Development', 1, 3, 'Life Sciences', 1, 1822, 3, 'Female', 52, 3, 2, 'Healthcare Representative', 4, 'Divorced', 6513, 9060, 4, 'Y', 'No', 17, 3, 4, 80, 1, 12, 3, 3, 5, 3, 0, 3),
#  (2772, 58, 'No', 'Non-Travel', 350, 'Sales', 2, 3, 'Medical', 1, 1824, 2, 'Male', 52, 3, 4, 'Manager', 2, 'Divorced', 16291, 22577, 4, 'Y', 'No', 22, 4, 4, 80, 1, 37, 0, 2, 16, 9, 14, 14),
#  (2774, 47, 'No', 'Travel_Rarely', 1001, 'Research & Development', 4, 3, 'Life Sciences', 1, 1827, 3, 'Female', 92, 2, 3, 'Manufacturing Director', 2, 'Divorced', 10333, 19271, 8, 'Y', 'Yes', 12, 3, 3, 80, 1, 28, 4, 3, 22, 11, 14, 10),
#  (2775, 40, 'No', 'Travel_Rarely', 750, 'Research & Development', 12, 3, 'Life Sciences', 1, 1829, 2, 'Female', 47, 3, 2, 'Healthcare Representative', 1, 'Divorced', 4448, 10748, 2, 'Y', 'No', 12, 3, 2, 80, 1, 15, 3, 3, 7, 4, 7, 7),
#  (2784, 29, 'Yes', 'Travel_Rarely', 350, 'Human Resources', 13, 3, 'Human Resources', 1, 1844, 1, 'Male', 56, 2, 1, 'Human Resources', 1, 'Divorced', 2335, 3157, 4, 'Y', 'Yes', 15, 3, 4, 80, 3, 4, 3, 3, 2, 2, 2, 0),
#  (2793, 46, 'No', 'Travel_Rarely', 706, 'Research & Development', 2, 2, 'Life Sciences', 1, 1857, 4, 'Male', 82, 3, 3, 'Manufacturing Director', 4, 'Divorced', 8578, 19989, 3, 'Y', 'No', 14, 3, 3, 80, 1, 12, 4, 2, 9, 8, 4, 7),
#  (2794, 28, 'No', 'Non-Travel', 280, 'Human Resources', 1, 2, 'Life Sciences', 1, 1858, 3, 'Male', 43, 3, 1, 'Human Resources', 4, 'Divorced', 2706, 10494, 1, 'Y', 'No', 15, 3, 2, 80, 1, 3, 2, 3, 3, 2, 2, 2),
#  (2795, 29, 'No', 'Travel_Rarely', 726, 'Research & Development', 29, 1, 'Life Sciences', 1, 1859, 4, 'Male', 93, 1, 2, 'Healthcare Representative', 3, 'Divorced', 6384, 21143, 8, 'Y', 'No', 17, 3, 4, 80, 2, 11, 3, 3, 7, 0, 1, 6),
#  (2798, 46, 'No', 'Travel_Rarely', 1319, 'Sales', 3, 3, 'Technical Degree', 1, 1863, 1, 'Female', 45, 4, 4, 'Sales Executive', 1, 'Divorced', 13225, 7739, 2, 'Y', 'No', 12, 3, 4, 80, 1, 25, 5, 3, 19, 17, 2, 8),
#  (2806, 39, 'No', 'Travel_Rarely', 835, 'Research & Development', 19, 4, 'Other', 1, 1871, 4, 'Male', 41, 3, 2, 'Research Scientist', 4, 'Divorced', 3902, 5141, 8, 'Y', 'No', 14, 3, 2, 80, 3, 7, 2, 3, 2, 2, 2, 2),
#  (2812, 31, 'No', 'Travel_Rarely', 311, 'Research & Development', 20, 3, 'Life Sciences', 1, 1881, 2, 'Male', 89, 3, 2, 'Laboratory Technician', 3, 'Divorced', 4197, 18624, 1, 'Y', 'No', 11, 3, 1, 80, 1, 10, 2, 3, 10, 8, 0, 2),
#  (2819, 40, 'No', 'Travel_Rarely', 1137, 'Research & Development', 1, 4, 'Life Sciences', 1, 1892, 1, 'Male', 98, 3, 4, 'Manager', 1, 'Divorced', 16823, 18991, 2, 'Y', 'No', 11, 3, 1, 80, 1, 22, 3, 3, 19, 7, 11, 16),
#  (2822, 48, 'No', 'Travel_Frequently', 117, 'Research & Development', 22, 3, 'Medical', 1, 1900, 4, 'Female', 58, 3, 4, 'Manager', 4, 'Divorced', 17174, 2437, 3, 'Y', 'No', 11, 3, 2, 80, 1, 24, 3, 3, 22, 17, 4, 7),
#  (2829, 31, 'No', 'Travel_Rarely', 1079, 'Sales', 10, 2, 'Medical', 1, 1912, 3, 'Female', 86, 3, 2, 'Sales Executive', 4, 'Divorced', 6583, 20115, 2, 'Y', 'Yes', 11, 3, 4, 80, 1, 8, 2, 3, 5, 2, 1, 4),
#  (2831, 31, 'No', 'Travel_Rarely', 471, 'Research & Development', 4, 3, 'Medical', 1, 1916, 1, 'Female', 62, 4, 1, 'Laboratory Technician', 3, 'Divorced', 3978, 16031, 8, 'Y', 'No', 12, 3, 2, 80, 1, 4, 0, 2, 2, 2, 2, 2),
#  (2844, 38, 'No', 'Travel_Frequently', 1394, 'Research & Development', 8, 3, 'Medical', 1, 1937, 4, 'Female', 58, 2, 2, 'Research Scientist', 2, 'Divorced', 2133, 18115, 1, 'Y', 'Yes', 16, 3, 3, 80, 1, 20, 3, 3, 20, 11, 0, 7),
#  (2847, 38, 'No', 'Travel_Rarely', 1206, 'Research & Development', 9, 2, 'Life Sciences', 1, 1940, 2, 'Male', 71, 3, 1, 'Research Scientist', 4, 'Divorced', 4771, 14293, 2, 'Y', 'No', 19, 3, 4, 80, 2, 10, 0, 4, 5, 2, 0, 3),
#  (2849, 42, 'No', 'Travel_Rarely', 419, 'Sales', 12, 4, 'Marketing', 1, 1943, 2, 'Male', 77, 3, 2, 'Sales Executive', 4, 'Divorced', 5087, 2900, 3, 'Y', 'Yes', 12, 3, 3, 80, 2, 14, 4, 3, 0, 0, 0, 0),
#  (2853, 31, 'No', 'Non-Travel', 976, 'Research & Development', 3, 2, 'Medical', 1, 1948, 3, 'Male', 48, 3, 1, 'Research Scientist', 1, 'Divorced', 3065, 3995, 1, 'Y', 'Yes', 13, 3, 4, 80, 1, 4, 3, 4, 4, 2, 2, 3),
#  (2856, 34, 'No', 'Travel_Rarely', 1239, 'Sales', 13, 4, 'Medical', 1, 1951, 4, 'Male', 39, 3, 3, 'Sales Executive', 3, 'Divorced', 8628, 22914, 1, 'Y', 'No', 18, 3, 3, 80, 1, 9, 2, 2, 8, 7, 1, 1),
#  (2859, 32, 'No', 'Non-Travel', 1146, 'Research & Development', 15, 4, 'Medical', 1, 1955, 3, 'Female', 34, 3, 2, 'Healthcare Representative', 4, 'Divorced', 6667, 16542, 5, 'Y', 'No', 18, 3, 2, 80, 1, 9, 6, 3, 5, 1, 1, 2),
#  (2861, 28, 'Yes', 'Travel_Rarely', 1404, 'Research & Development', 17, 3, 'Technical Degree', 1, 1960, 3, 'Male', 32, 2, 1, 'Laboratory Technician', 4, 'Divorced', 2367, 18779, 5, 'Y', 'No', 12, 3, 1, 80, 1, 6, 2, 2, 4, 1, 0, 3),
#  (2869, 33, 'No', 'Travel_Frequently', 1303, 'Research & Development', 7, 2, 'Life Sciences', 1, 1970, 4, 'Male', 36, 3, 2, 'Healthcare Representative', 3, 'Divorced', 5968, 18079, 1, 'Y', 'No', 20, 4, 3, 80, 3, 9, 2, 3, 9, 7, 2, 8),
#  (2873, 31, 'No', 'Travel_Rarely', 1276, 'Research & Development', 2, 1, 'Medical', 1, 1974, 4, 'Female', 59, 1, 1, 'Laboratory Technician', 4, 'Divorced', 1129, 17536, 1, 'Y', 'Yes', 11, 3, 3, 80, 3, 1, 4, 3, 1, 0, 0, 0),
#  (2884, 25, 'No', 'Travel_Rarely', 977, 'Research & Development', 2, 1, 'Other', 1, 1992, 4, 'Male', 57, 3, 1, 'Laboratory Technician', 3, 'Divorced', 3977, 7298, 6, 'Y', 'Yes', 19, 3, 3, 80, 1, 7, 2, 2, 2, 2, 0, 2),
#  (2886, 33, 'No', 'Non-Travel', 1313, 'Research & Development', 1, 2, 'Medical', 1, 1994, 2, 'Male', 59, 2, 1, 'Laboratory Technician', 3, 'Divorced', 2008, 20439, 1, 'Y', 'No', 12, 3, 3, 80, 3, 1, 2, 2, 1, 1, 0, 0),
#  (2890, 42, 'No', 'Travel_Rarely', 557, 'Research & Development', 18, 4, 'Life Sciences', 1, 1998, 4, 'Male', 35, 3, 2, 'Research Scientist', 1, 'Divorced', 5410, 11189, 6, 'Y', 'Yes', 17, 3, 3, 80, 1, 9, 3, 2, 4, 3, 1, 2),
#  (2904, 25, 'No', 'Travel_Rarely', 1382, 'Sales', 8, 2, 'Other', 1, 2018, 1, 'Female', 85, 3, 2, 'Sales Executive', 3, 'Divorced', 4907, 13684, 0, 'Y', 'Yes', 22, 4, 2, 80, 1, 6, 3, 2, 5, 3, 0, 4),
#  (2905, 52, 'No', 'Non-Travel', 585, 'Sales', 29, 4, 'Life Sciences', 1, 2019, 1, 'Male', 40, 3, 1, 'Sales Representative', 4, 'Divorced', 3482, 19788, 2, 'Y', 'No', 15, 3, 2, 80, 2, 16, 3, 2, 9, 8, 0, 0),
#  (2911, 36, 'No', 'Travel_Frequently', 688, 'Research & Development', 4, 2, 'Life Sciences', 1, 2025, 4, 'Female', 97, 3, 2, 'Manufacturing Director', 2, 'Divorced', 5131, 9192, 7, 'Y', 'No', 13, 3, 2, 80, 3, 18, 3, 3, 4, 2, 0, 2),
#  (2912, 56, 'No', 'Non-Travel', 667, 'Research & Development', 1, 4, 'Life Sciences', 1, 2026, 3, 'Male', 57, 3, 2, 'Healthcare Representative', 3, 'Divorced', 6306, 26236, 1, 'Y', 'No', 21, 4, 1, 80, 1, 13, 2, 2, 13, 12, 1, 9),
#  (2918, 36, 'No', 'Non-Travel', 301, 'Sales', 15, 4, 'Marketing', 1, 2036, 4, 'Male', 88, 1, 2, 'Sales Executive', 4, 'Divorced', 5406, 10436, 1, 'Y', 'No', 24, 4, 1, 80, 1, 15, 4, 2, 15, 12, 11, 11),
#  (2919, 41, 'No', 'Travel_Rarely', 930, 'Sales', 3, 3, 'Life Sciences', 1, 2037, 3, 'Male', 57, 2, 2, 'Sales Executive', 2, 'Divorced', 8938, 12227, 2, 'Y', 'No', 11, 3, 3, 80, 1, 14, 5, 3, 5, 4, 0, 4),
#  (2923, 50, 'Yes', 'Travel_Frequently', 878, 'Sales', 1, 4, 'Life Sciences', 1, 2044, 2, 'Male', 94, 3, 2, 'Sales Executive', 3, 'Divorced', 6728, 14255, 7, 'Y', 'No', 12, 3, 4, 80, 2, 12, 3, 3, 6, 3, 0, 1),
#  (2932, 50, 'Yes', 'Travel_Rarely', 410, 'Sales', 28, 3, 'Marketing', 1, 2055, 4, 'Male', 39, 2, 3, 'Sales Executive', 1, 'Divorced', 10854, 16586, 4, 'Y', 'Yes', 13, 3, 2, 80, 1, 20, 3, 3, 3, 2, 2, 0)]

# %%
# %%sql
#
# SELECT SUM(MonthlyIncome) AS total_monthly_income
#     FROM attrition_records
# WHERE LOWER(MaritalStatus) LIKE "%divorce%";
# Out:
#    postgresql://postgres:***@localhost/myDB
#  * sqlite:///db/attr_data.db
# Done.
# [(4438232,)]

# %%
# %%sql
#
# SELECT SUM(MonthlyIncome) total_monthly_income
#     FROM attrition_records
# WHERE LOWER(MaritalStatus) = "divorced";
# Out:
#    postgresql://postgres:***@localhost/myDB
#  * sqlite:///db/attr_data.db
# Done.
# [(4438232,)]

# %% [markdown]
# ### GROUP BY
#
# #### SYNTAX:
#
# ```sql
# SELECT * FROM table_name
# GROUP BY col_1;
# ```

# %%
# Select the unique departments

# %% [raw]
# A, B, C, A, A, B, C
#
# {
#     A: 3,
#     B: 2,
#     C: 2
# }

# %%
# %%sql
#
# SELECT Department
#     FROM attrition_records
# GROUP BY Department;
# Out:
#    postgresql://postgres:***@localhost/myDB
#  * sqlite:///db/attr_data.db
# Done.
# [('Human Resources',), ('Research & Development',), ('Sales',)]

# %%
# %%sql
#
# SELECT DISTINCT(Department)
# FROM attrition_records;
# Out:
#    postgresql://postgres:***@localhost/myDB
#  * sqlite:///db/attr_data.db
# Done.
# [('Sales',), ('Research & Development',), ('Human Resources',)]

# %%
# Select employees earning more than the average monthly_income

# %%
# %%sql
#
# SELECT Age, MonthlyIncome, Department
#     FROM attrition_records
# LIMIT 5;
# Out:
#    postgresql://postgres:***@localhost/myDB
#  * sqlite:///db/attr_data.db
# Done.
# [(41, 5993, 'Sales'),
#  (49, 5130, 'Research & Development'),
#  (37, 2090, 'Research & Development'),
#  (33, 2909, 'Research & Development'),
#  (27, 3468, 'Research & Development')]

# %% [markdown]
# Step 1
#
# * Calculate the avg montly_income

# %%
# %%sql
#
# SELECT ROUND(AVG(MonthlyIncome), 2) avg_monthly_income
#     FROM attrition_records;
# Out:
#    postgresql://postgres:***@localhost/myDB
#  * sqlite:///db/attr_data.db
# Done.
# [(6502.93,)]

# %% [markdown]
# Step 2
#
# * Determine the employees using the result from step 1. (note: use a sub-query)

# %%
# %%sql
#
# SELECT id, Age, Department, MonthlyIncome
#     FROM attrition_records
#     WHERE MonthlyIncome > (SELECT ROUND(AVG(MonthlyIncome), 2) avg_monthly_income
#                         FROM attrition_records)
# LIMIT 10;
# Out:
#    postgresql://postgres:***@localhost/myDB
#  * sqlite:///db/attr_data.db
# Done.
# [(9, 38, 'Research & Development', 9526),
#  (16, 29, 'Research & Development', 9980),
#  (19, 53, 'Sales', 15427),
#  (23, 34, 'Research & Development', 11994),
#  (26, 53, 'Research & Development', 19094),
#  (28, 42, 'Sales', 6825),
#  (29, 44, 'Research & Development', 10248),
#  (30, 46, 'Sales', 18947),
#  (44, 27, 'Sales', 8726),
#  (46, 41, 'Research & Development', 19545)]

# %%
# %%sql
#
# SELECT COUNT(id) num_employees
#     FROM attrition_records
#     WHERE MonthlyIncome > (SELECT ROUND(AVG(MonthlyIncome), 2) avg_monthly_income
#                         FROM attrition_records)
# ;
# Out:
#    postgresql://postgres:***@localhost/myDB
#  * sqlite:///db/attr_data.db
# Done.
# [(986,)]

# %% [markdown]
# ### HAVING
#
# #### SYNTAX:
#
# ```sql
# SELECT * FROM table_name
# GROUP BY col_name
# HAVING condition;
# ```
#
# #### NOTE:
#
# * `HAVING` clause **must** appear after the `GROUP BY` clause.

# %%
# Select all the age groups that have StockOptionLevel of more than 1

# %%
# %%sql
#
# SELECT id, Age, Gender, Department, JobRole, StockOptionLevel
#     FROM attrition_records
#     GROUP BY Age
#     HAVING StockOptionLevel > 1
# ;
# Out:
#    postgresql://postgres:***@localhost/myDB
#  * sqlite:///db/attr_data.db
# Done.
# [(18, 22, 'Male', 'Research & Development', 'Laboratory Technician', 2),
#  (10, 36, 'Male', 'Research & Development', 'Healthcare Representative', 2),
#  (36, 43, 'Female', 'Research & Development', 'Research Scientist', 2),
#  (88, 51, 'Male', 'Research & Development', 'Laboratory Technician', 2),
#  (66, 55, 'Female', 'Research & Development', 'Manager', 3),
#  (7, 59, 'Female', 'Research & Development', 'Laboratory Technician', 3)]

# %% [markdown]
# ### Sub-Queries
#
# * AKA **Inner-queries**, **Nested queries**
#
# ### Types of Sub-Queries
#
# 1. **Scalar**: It returns a single value.
# 2. **Multi-row**: It returns multiple rows (and/or columns).
# 3. **Correlated**: The inner-query depends on the outer-query.

# %% [markdown]
# ### Scalar Sub-Query
#
# * Who is/are the oldest employee(s)?

# %%
# %%sql
#
# SELECT ROUND(MAX(Age), 2) AS max_age
#     FROM attrition_records
# Out:
#    postgresql://postgres:***@localhost/myDB
#  * sqlite:///db/attr_data.db
# Done.
# [(60.0,)]

# %%
# %%sql
#
# SELECT *
#     FROM attrition_records
# WHERE Age = (SELECT ROUND(MAX(Age), 2) AS max_age
#                 FROM attrition_records);
# Out:
#    postgresql://postgres:***@localhost/myDB
#  * sqlite:///db/attr_data.db
# Done.
# [(412, 60, 'No', 'Travel_Rarely', 422, 'Research & Development', 7, 3, 'Life Sciences', 1, 549, 1, 'Female', 41, 3, 5, 'Manager', 1, 'Married', 19566, 3854, 5, 'Y', 'No', 11, 3, 4, 80, 0, 33, 5, 1, 29, 8, 11, 10),
#  (428, 60, 'No', 'Travel_Frequently', 1499, 'Sales', 28, 3, 'Marketing', 1, 573, 3, 'Female', 80, 2, 3, 'Sales Executive', 1, 'Married', 10266, 2845, 4, 'Y', 'No', 19, 3, 4, 80, 0, 22, 5, 4, 18, 13, 13, 11),
#  (537, 60, 'No', 'Travel_Rarely', 1179, 'Sales', 16, 4, 'Marketing', 1, 732, 1, 'Male', 84, 3, 2, 'Sales Executive', 1, 'Single', 5405, 11924, 8, 'Y', 'No', 14, 3, 4, 80, 0, 10, 1, 3, 2, 2, 2, 2),
#  (880, 60, 'No', 'Travel_Rarely', 696, 'Sales', 7, 4, 'Marketing', 1, 1233, 2, 'Male', 52, 4, 2, 'Sales Executive', 4, 'Divorced', 5220, 10893, 0, 'Y', 'Yes', 18, 3, 2, 80, 1, 12, 3, 3, 11, 7, 1, 9),
#  (1210, 60, 'No', 'Travel_Rarely', 370, 'Research & Development', 1, 4, 'Medical', 1, 1697, 3, 'Male', 92, 1, 3, 'Healthcare Representative', 4, 'Divorced', 10883, 20467, 3, 'Y', 'No', 20, 4, 3, 80, 1, 19, 2, 4, 1, 0, 0, 0),
#  (1882, 60, 'No', 'Travel_Rarely', 422, 'Research & Development', 7, 3, 'Life Sciences', 1, 549, 1, 'Female', 41, 3, 5, 'Manager', 1, 'Married', 19566, 3854, 5, 'Y', 'No', 11, 3, 4, 80, 0, 33, 5, 1, 29, 8, 11, 10),
#  (1898, 60, 'No', 'Travel_Frequently', 1499, 'Sales', 28, 3, 'Marketing', 1, 573, 3, 'Female', 80, 2, 3, 'Sales Executive', 1, 'Married', 10266, 2845, 4, 'Y', 'No', 19, 3, 4, 80, 0, 22, 5, 4, 18, 13, 13, 11),
#  (2007, 60, 'No', 'Travel_Rarely', 1179, 'Sales', 16, 4, 'Marketing', 1, 732, 1, 'Male', 84, 3, 2, 'Sales Executive', 1, 'Single', 5405, 11924, 8, 'Y', 'No', 14, 3, 4, 80, 0, 10, 1, 3, 2, 2, 2, 2),
#  (2350, 60, 'No', 'Travel_Rarely', 696, 'Sales', 7, 4, 'Marketing', 1, 1233, 2, 'Male', 52, 4, 2, 'Sales Executive', 4, 'Divorced', 5220, 10893, 0, 'Y', 'Yes', 18, 3, 2, 80, 1, 12, 3, 3, 11, 7, 1, 9),
#  (2680, 60, 'No', 'Travel_Rarely', 370, 'Research & Development', 1, 4, 'Medical', 1, 1697, 3, 'Male', 92, 1, 3, 'Healthcare Representative', 4, 'Divorced', 10883, 20467, 3, 'Y', 'No', 20, 4, 3, 80, 1, 19, 2, 4, 1, 0, 0, 0)]

# %% [markdown]
# <br>
#
# ### Multi-row Sub-query

# %%
# Select all the employees earning more than the average monthly_income in their department

# %% [raw]
# Data science: 20K
# Frontend: 25K
# UI/UX: 30K

# %% [markdown]
# ### Steps:
#
# 1. Calculate the average monthly_income for each department.
# 2. For each department, select all the employees earning more than average monthly_income.

# %%
# %%sql
#
# SELECT Department, ROUND(AVG(MonthlyIncome)) avg_monthly_income
#     FROM attrition_records
# GROUP BY Department;
# Out:
#    postgresql://postgres:***@localhost/myDB
#  * sqlite:///db/attr_data.db
# Done.
# [('Human Resources', 6655.0),
#  ('Research & Development', 6281.0),
#  ('Sales', 6959.0)]

# %%
# %%sql
#
# SELECT ROUND(AVG(MonthlyIncome)) avg_monthly_income
#                         FROM attrition_records
#                         GROUP BY Department
# Out:
#    postgresql://postgres:***@localhost/myDB
#  * sqlite:///db/attr_data.db
# Done.
# [(6655.0,), (6281.0,), (6959.0,)]

# %% [markdown]
# ### Another Method For Solving The Question
#
# ### * Using correlated Queries.

# %% [raw]
# table_a and table_b
#
# # Select all the employees earning more than the average monthly_income in their department

# %%
# %%sql
#
# SELECT id, Age, JobRole, Department, MonthlyIncome
#     FROM attrition_records AS a
# WHERE MonthlyIncome > (SELECT ROUND(AVG(MonthlyIncome)) avg_monthly_income
#                         FROM attrition_records b
#                         WHERE b.Department = a.Department)
# ORDER BY a.Department;
# Out:
#    postgresql://postgres:***@localhost/myDB
#  * sqlite:///db/attr_data.db
# Done.
# [(106, 59, 'Manager', 'Human Resources', 18844),
#  (113, 54, 'Manager', 'Human Resources', 17328),
#  (441, 34, 'Human Resources', 'Human Resources', 9950),
#  (478, 50, 'Manager', 'Human Resources', 18200),
#  (511, 54, 'Human Resources', 'Human Resources', 10725),
#  (536, 41, 'Manager', 'Human Resources', 19141),
#  (539, 41, 'Manager', 'Human Resources', 19189),
#  (790, 44, 'Human Resources', 'Human Resources', 10482),
#  (957, 56, 'Manager', 'Human Resources', 19717),
#  (963, 51, 'Manager', 'Human Resources', 14026),
#  (1000, 42, 'Manager', 'Human Resources', 16799),
#  (1006, 29, 'Human Resources', 'Human Resources', 7988),
#  (1097, 40, 'Manager', 'Human Resources', 16437),
#  (1155, 47, 'Manager', 'Human Resources', 19658),
#  (1244, 45, 'Human Resources', 'Human Resources', 9756),
#  (1402, 55, 'Manager', 'Human Resources', 19636),
#  (1451, 35, 'Human Resources', 'Human Resources', 8837),
#  (1576, 59, 'Manager', 'Human Resources', 18844),
#  (1583, 54, 'Manager', 'Human Resources', 17328),
#  (1911, 34, 'Human Resources', 'Human Resources', 9950),
#  (1948, 50, 'Manager', 'Human Resources', 18200),
#  (1981, 54, 'Human Resources', 'Human Resources', 10725),
#  (2006, 41, 'Manager', 'Human Resources', 19141),
#  (2009, 41, 'Manager', 'Human Resources', 19189),
#  (2260, 44, 'Human Resources', 'Human Resources', 10482),
#  (2427, 56, 'Manager', 'Human Resources', 19717),
#  (2433, 51, 'Manager', 'Human Resources', 14026),
#  (2470, 42, 'Manager', 'Human Resources', 16799),
#  (2476, 29, 'Human Resources', 'Human Resources', 7988),
#  (2567, 40, 'Manager', 'Human Resources', 16437),
#  (2625, 47, 'Manager', 'Human Resources', 19658),
#  (2714, 45, 'Human Resources', 'Human Resources', 9756),
#  (2872, 55, 'Manager', 'Human Resources', 19636),
#  (2921, 35, 'Human Resources', 'Human Resources', 8837),
#  (9, 38, 'Manufacturing Director', 'Research & Development', 9526),
#  (16, 29, 'Manufacturing Director', 'Research & Development', 9980),
#  (23, 34, 'Research Director', 'Research & Development', 11994),
#  (26, 53, 'Manager', 'Research & Development', 19094),
#  (29, 44, 'Healthcare Representative', 'Research & Development', 10248),
#  (32, 44, 'Healthcare Representative', 'Research & Development', 6465),
#  (46, 41, 'Research Director', 'Research & Development', 19545),
#  (54, 35, 'Healthcare Representative', 'Research & Development', 9884),
#  (56, 33, 'Research Director', 'Research & Development', 13458),
#  (63, 50, 'Research Director', 'Research & Development', 18740),
#  (65, 36, 'Healthcare Representative', 'Research & Development', 10096),
#  (66, 55, 'Manager', 'Research & Development', 14756),
#  (67, 36, 'Manufacturing Director', 'Research & Development', 6499),
#  (68, 45, 'Research Scientist', 'Research & Development', 9724),
#  (78, 45, 'Research Director', 'Research & Development', 13245),
#  (79, 37, 'Research Director', 'Research & Development', 13664),
#  (86, 56, 'Manufacturing Director', 'Research & Development', 7260),
#  (91, 40, 'Healthcare Representative', 'Research & Development', 13503),
#  (94, 46, 'Healthcare Representative', 'Research & Development', 10673),
#  (96, 54, 'Research Director', 'Research & Development', 13549),
#  (107, 50, 'Research Director', 'Research & Development', 18172),
#  (111, 51, 'Healthcare Representative', 'Research & Development', 7484),
#  (117, 34, 'Manager', 'Research & Development', 11631),
#  (124, 51, 'Research Director', 'Research & Development', 19537),
#  (127, 58, 'Healthcare Representative', 'Research & Development', 10312),
#  (130, 49, 'Manufacturing Director', 'Research & Development', 6567),
#  (137, 51, 'Manufacturing Director', 'Research & Development', 10650),
#  (148, 41, 'Manager', 'Research & Development', 17181),
#  (164, 57, 'Healthcare Representative', 'Research & Development', 9439),
#  (166, 50, 'Manager', 'Research & Development', 19926),
#  (187, 40, 'Manager', 'Research & Development', 19033),
#  (188, 55, 'Research Director', 'Research & Development', 18722),
#  (189, 34, 'Manufacturing Director', 'Research & Development', 9547),
#  (190, 51, 'Healthcare Representative', 'Research & Development', 13734),
#  (191, 52, 'Manager', 'Research & Development', 19999),
#  (195, 45, 'Manager', 'Research & Development', 16792),
#  (199, 38, 'Manufacturing Director', 'Research & Development', 6553),
#  (202, 49, 'Manufacturing Director', 'Research & Development', 6804),
#  (205, 38, 'Healthcare Representative', 'Research & Development', 6673),
#  (210, 46, 'Healthcare Representative', 'Research & Development', 9396),
#  (212, 30, 'Manufacturing Director', 'Research & Development', 8474),
#  (214, 51, 'Research Director', 'Research & Development', 12490),
#  (223, 37, 'Research Director', 'Research & Development', 12185),
#  (232, 42, 'Manager', 'Research & Development', 19232),
#  (245, 45, 'Manager', 'Research & Development', 19202),
#  (246, 31, 'Research Director', 'Research & Development', 13675),
#  (250, 45, 'Manufacturing Director', 'Research & Development', 6434),
#  (251, 37, 'Manufacturing Director', 'Research & Development', 10048),
#  (252, 39, 'Healthcare Representative', 'Research & Development', 10938),
#  (254, 42, 'Research Scientist', 'Research & Development', 6545),
#  (258, 40, 'Research Director', 'Research & Development', 19436),
#  (269, 45, 'Healthcare Representative', 'Research & Development', 13496),
#  (271, 55, 'Manager', 'Research & Development', 19045),
#  (272, 47, 'Manager', 'Research & Development', 11849),
#  (276, 37, 'Research Director', 'Research & Development', 13603),
#  (277, 35, 'Manager', 'Research & Development', 11996),
#  (279, 26, 'Manufacturing Director', 'Research & Development', 6397),
#  (280, 50, 'Research Director', 'Research & Development', 19144),
#  (281, 53, 'Research Director', 'Research & Development', 17584),
#  (291, 49, 'Research Director', 'Research & Development', 18665),
#  (305, 39, 'Healthcare Representative', 'Research & Development', 9613),
#  (308, 38, 'Research Director', 'Research & Development', 12061),
#  (314, 33, 'Manager', 'Research & Development', 11878),
#  (315, 39, 'Manager', 'Research & Development', 17068),
#  (317, 49, 'Healthcare Representative', 'Research & Development', 13964),
#  (326, 31, 'Manufacturing Director', 'Research & Development', 8943),
#  (327, 39, 'Manager', 'Research & Development', 19272),
#  (330, 47, 'Research Director', 'Research & Development', 18300),
#  (334, 43, 'Healthcare Representative', 'Research & Development', 9985),
#  (341, 37, 'Manufacturing Director', 'Research & Development', 6347),
#  (342, 38, 'Research Director', 'Research & Development', 11510),
#  (343, 31, 'Manufacturing Director', 'Research & Development', 7143),
#  (345, 35, 'Manufacturing Director', 'Research & Development', 8095),
#  (349, 42, 'Research Director', 'Research & Development', 15992),
#  (357, 42, 'Healthcare Representative', 'Research & Development', 6781),
#  (361, 57, 'Healthcare Representative', 'Research & Development', 6755),
#  (368, 50, 'Healthcare Representative', 'Research & Development', 10496),
#  (373, 35, 'Healthcare Representative', 'Research & Development', 6540),
#  (376, 49, 'Healthcare Representative', 'Research & Development', 10965),
#  (380, 55, 'Manager', 'Research & Development', 16659),
#  (391, 43, 'Research Director', 'Research & Development', 14336),
#  (393, 54, 'Research Director', 'Research & Development', 19406),
#  (401, 39, 'Manager', 'Research & Development', 19197),
#  (407, 52, 'Manufacturing Director', 'Research & Development', 7969),
#  (409, 52, 'Manager', 'Research & Development', 16555),
#  (412, 60, 'Manager', 'Research & Development', 19566),
#  (421, 29, 'Research Director', 'Research & Development', 11935),
#  (426, 50, 'Manager', 'Research & Development', 17046),
#  (430, 46, 'Research Director', 'Research & Development', 17861),
#  (435, 31, 'Manufacturing Director', 'Research & Development', 10648),
#  (436, 33, 'Manager', 'Research & Development', 13610),
#  (439, 35, 'Healthcare Representative', 'Research & Development', 7632),
#  (440, 31, 'Healthcare Representative', 'Research & Development', 9824),
#  (449, 40, 'Manufacturing Director', 'Research & Development', 13237),
#  (452, 42, 'Manufacturing Director', 'Research & Development', 7406),
#  (456, 33, 'Research Director', 'Research & Development', 16184),
#  (460, 41, 'Healthcare Representative', 'Research & Development', 6811),
#  (465, 37, 'Manufacturing Director', 'Research & Development', 7491),
#  (466, 46, 'Healthcare Representative', 'Research & Development', 10527),
#  (472, 38, 'Healthcare Representative', 'Research & Development', 9824),
#  (473, 37, 'Manufacturing Director', 'Research & Development', 6447),
#  (474, 49, 'Research Director', 'Research & Development', 19502),
#  (490, 43, 'Research Director', 'Research & Development', 16627),
#  (493, 48, 'Manager', 'Research & Development', 15402),
#  (498, 44, 'Manager', 'Research & Development', 19513),
#  (501, 32, 'Research Scientist', 'Research & Development', 6322),
#  (507, 37, 'Manufacturing Director', 'Research & Development', 9434),
#  (509, 35, 'Research Scientist', 'Research & Development', 6646),
#  (510, 33, 'Healthcare Representative', 'Research & Development', 7725),
#  (512, 36, 'Manufacturing Director', 'Research & Development', 8847),
#  (525, 34, 'Healthcare Representative', 'Research & Development', 8621),
#  (530, 38, 'Healthcare Representative', 'Research & Development', 7625),
#  (531, 27, 'Manufacturing Director', 'Research & Development', 7412),
#  (532, 32, 'Research Director', 'Research & Development', 11159),
#  (535, 53, 'Research Director', 'Research & Development', 14814),
#  (538, 27, 'Manufacturing Director', 'Research & Development', 8793),
#  (542, 36, 'Research Director', 'Research & Development', 11713),
#  (543, 38, 'Manufacturing Director', 'Research & Development', 7861),
#  (553, 56, 'Healthcare Representative', 'Research & Development', 11103),
#  (555, 27, 'Healthcare Representative', 'Research & Development', 6811),
#  (569, 55, 'Manager', 'Research & Development', 19859),
#  (585, 42, 'Manager', 'Research & Development', 18430),
#  (589, 50, 'Research Director', 'Research & Development', 17639),
#  (591, 33, 'Research Director', 'Research & Development', 11691),
#  (593, 47, 'Manager', 'Research & Development', 16752),
#  (596, 58, 'Research Director', 'Research & Development', 19246),
#  (603, 30, 'Manufacturing Director', 'Research & Development', 6877),
#  (606, 38, 'Healthcare Representative', 'Research & Development', 6288),
#  (610, 43, 'Research Director', 'Research & Development', 17159),
#  (611, 27, 'Research Director', 'Research & Development', 12808),
#  (612, 35, 'Manufacturing Director', 'Research & Development', 10221),
#  (628, 52, 'Manufacturing Director', 'Research & Development', 13826),
#  (636, 35, 'Manufacturing Director', 'Research & Development', 10685),
#  (648, 35, 'Manufacturing Director', 'Research & Development', 10903),
#  (650, 53, 'Research Director', 'Research & Development', 14275),
#  (654, 50, 'Manager', 'Research & Development', 17924),
#  (665, 36, 'Healthcare Representative', 'Research & Development', 6586),
#  (675, 58, 'Healthcare Representative', 'Research & Development', 10552),
#  (678, 49, 'Laboratory Technician', 'Research & Development', 7403),
#  (682, 38, 'Research Director', 'Research & Development', 13582),
#  (693, 32, 'Manufacturing Director', 'Research & Development', 6725),
#  (695, 33, 'Healthcare Representative', 'Research & Development', 6949),
#  (700, 52, 'Manager', 'Research & Development', 17099),
#  (715, 50, 'Research Director', 'Research & Development', 17399),
#  (717, 41, 'Research Director', 'Research & Development', 19419),
#  (722, 50, 'Manufacturing Director', 'Research & Development', 13973),
#  (724, 46, 'Manufacturing Director', 'Research & Development', 10845),
#  (729, 54, 'Manufacturing Director', 'Research & Development', 10739),
#  (730, 35, 'Healthcare Representative', 'Research & Development', 10388),
#  (731, 30, 'Research Director', 'Research & Development', 11416),
#  (737, 48, 'Healthcare Representative', 'Research & Development', 10999),
#  (739, 39, 'Manufacturing Director', 'Research & Development', 12742),
#  (744, 59, 'Manufacturing Director', 'Research & Development', 13726),
#  (746, 55, 'Healthcare Representative', 'Research & Development', 6385),
#  (747, 41, 'Research Director', 'Research & Development', 19973),
#  (754, 39, 'Manufacturing Director', 'Research & Development', 10880),
#  (767, 50, 'Research Director', 'Research & Development', 19237),
#  (771, 46, 'Research Director', 'Research & Development', 19627),
#  (774, 36, 'Manufacturing Director', 'Research & Development', 8858),
#  (775, 55, 'Manager', 'Research & Development', 16756),
#  (781, 28, 'Healthcare Representative', 'Research & Development', 8722),
#  (783, 30, 'Manufacturing Director', 'Research & Development', 9957),
#  (785, 38, 'Healthcare Representative', 'Research & Development', 8823),
#  (786, 40, 'Healthcare Representative', 'Research & Development', 10322),
#  (788, 55, 'Manufacturing Director', 'Research & Development', 10976),
#  (791, 33, 'Healthcare Representative', 'Research & Development', 7119),
#  (795, 34, 'Healthcare Representative', 'Research & Development', 7756),
#  (800, 42, 'Manager', 'Research & Development', 17665),
#  (805, 48, 'Manager', 'Research & Development', 16885),
#  (807, 52, 'Healthcare Representative', 'Research & Development', 10445),
#  (810, 28, 'Manufacturing Director', 'Research & Development', 7655),
#  (813, 43, 'Manufacturing Director', 'Research & Development', 10820),
#  (814, 39, 'Healthcare Representative', 'Research & Development', 12169),
#  (815, 40, 'Research Director', 'Research & Development', 19626),
#  (817, 39, 'Laboratory Technician', 'Research & Development', 6782),
#  (818, 36, 'Manufacturing Director', 'Research & Development', 7779),
#  (838, 40, 'Research Director', 'Research & Development', 13499),
#  (847, 35, 'Manufacturing Director', 'Research & Development', 10274),
#  (852, 56, 'Manager', 'Research & Development', 19943),
#  (856, 37, 'Manufacturing Director', 'Research & Development', 6474),
#  (859, 53, 'Manager', 'Research & Development', 18606),
#  (868, 50, 'Manager', 'Research & Development', 17856),
#  (870, 46, 'Research Director', 'Research & Development', 19081),
#  (878, 46, 'Manufacturing Director', 'Research & Development', 7379),
#  (883, 36, 'Manufacturing Director', 'Research & Development', 10252),
#  (888, 42, 'Research Director', 'Research & Development', 13191),
#  (891, 54, 'Manufacturing Director', 'Research & Development', 10502),
#  (895, 54, 'Research Director', 'Research & Development', 17779),
#  (896, 31, 'Healthcare Representative', 'Research & Development', 6833),
#  (897, 31, 'Healthcare Representative', 'Research & Development', 6812),
#  (899, 43, 'Research Director', 'Research & Development', 19740),
#  (900, 49, 'Manager', 'Research & Development', 18711),
#  (904, 29, 'Healthcare Representative', 'Research & Development', 6623),
#  (905, 48, 'Research Director', 'Research & Development', 18265),
#  (906, 29, 'Research Director', 'Research & Development', 16124),
#  (915, 55, 'Healthcare Representative', 'Research & Development', 13577),
#  (920, 59, 'Manufacturing Director', 'Research & Development', 10512),
#  (923, 44, 'Manager', 'Research & Development', 19190),
#  (929, 44, 'Healthcare Representative', 'Research & Development', 7978),
#  (937, 45, 'Manager', 'Research & Development', 18061),
#  (938, 39, 'Manager', 'Research & Development', 17123),
#  (943, 36, 'Healthcare Representative', 'Research & Development', 7094),
#  (945, 28, 'Laboratory Technician', 'Research & Development', 6674),
#  (946, 50, 'Research Director', 'Research & Development', 16880),
#  (949, 30, 'Manager', 'Research & Development', 11916),
#  (955, 42, 'Manager', 'Research & Development', 17861),
#  (956, 55, 'Manager', 'Research & Development', 19187),
#  (959, 34, 'Healthcare Representative', 'Research & Development', 8500),
#  (967, 58, 'Manufacturing Director', 'Research & Development', 10008),
#  (970, 48, 'Manufacturing Director', 'Research & Development', 7898),
#  (972, 51, 'Manufacturing Director', 'Research & Development', 13142),
#  (977, 56, 'Manufacturing Director', 'Research & Development', 13402),
#  (979, 40, 'Healthcare Representative', 'Research & Development', 6377),
#  (984, 34, 'Healthcare Representative', 'Research & Development', 6687),
#  (993, 39, 'Healthcare Representative', 'Research & Development', 10920),
#  (995, 52, 'Manufacturing Director', 'Research & Development', 13247),
#  (1003, 35, 'Manufacturing Director', 'Research & Development', 9362),
#  (1008, 29, 'Healthcare Representative', 'Research & Development', 7553),
#  (1009, 54, 'Research Director', 'Research & Development', 17328),
#  (1010, 58, 'Research Director', 'Research & Development', 19701),
#  (1011, 55, 'Research Director', 'Research & Development', 14732),
#  (1015, 31, 'Research Director', 'Research & Development', 16422),
#  (1025, 47, 'Research Director', 'Research & Development', 17169),
#  (1034, 31, 'Manufacturing Director', 'Research & Development', 7446),
#  (1035, 45, 'Healthcare Representative', 'Research & Development', 10851),
#  (1038, 45, 'Manufacturing Director', 'Research & Development', 9380),
#  (1041, 40, 'Research Director', 'Research & Development', 13757),
#  (1044, 53, 'Research Director', 'Research & Development', 16598),
#  (1045, 49, 'Healthcare Representative', 'Research & Development', 6651),
#  (1055, 49, 'Healthcare Representative', 'Research & Development', 10466),
#  (1056, 34, 'Research Director', 'Research & Development', 17007),
#  (1063, 44, 'Manufacturing Director', 'Research & Development', 10209),
#  (1074, 28, 'Manufacturing Director', 'Research & Development', 6549),
#  (1075, 33, 'Healthcare Representative', 'Research & Development', 6388),
#  (1076, 32, 'Manager', 'Research & Development', 11244),
#  (1077, 54, 'Manager', 'Research & Development', 16032),
#  (1079, 44, 'Research Director', 'Research & Development', 16328),
#  (1080, 39, 'Manufacturing Director', 'Research & Development', 8376),
#  (1082, 35, 'Healthcare Representative', 'Research & Development', 8606),
#  (1087, 50, 'Research Director', 'Research & Development', 14411),
#  (1091, 29, 'Healthcare Representative', 'Research & Development', 9715),
#  (1094, 42, 'Healthcare Representative', 'Research & Development', 10124),
#  (1100, 45, 'Healthcare Representative', 'Research & Development', 7441),
#  (1112, 53, 'Manufacturing Director', 'Research & Development', 10169),
#  (1126, 29, 'Healthcare Representative', 'Research & Development', 8853),
#  (1130, 42, 'Manager', 'Research & Development', 19613),
#  (1139, 50, 'Healthcare Representative', 'Research & Development', 11245),
#  (1141, 44, 'Research Director', 'Research & Development', 19049),
#  (1157, 40, 'Manufacturing Director', 'Research & Development', 10435),
#  (1162, 38, 'Manufacturing Director', 'Research & Development', 7756),
#  (1165, 40, 'Manufacturing Director', 'Research & Development', 7945),
#  (1167, 48, 'Manager', 'Research & Development', 15202),
#  (1174, 36, 'Healthcare Representative', 'Research & Development', 8008),
#  (1177, 49, 'Research Director', 'Research & Development', 16413),
#  (1178, 50, 'Research Director', 'Research & Development', 13269),
#  (1182, 49, 'Healthcare Representative', 'Research & Development', 13966),
#  (1184, 36, 'Healthcare Representative', 'Research & Development', 6842),
#  (1185, 54, 'Manager', 'Research & Development', 17426),
#  (1186, 43, 'Research Director', 'Research & Development', 17603),
#  (1196, 49, 'Manager', 'Research & Development', 15379),
#  (1204, 53, 'Healthcare Representative', 'Research & Development', 7005),
#  (1210, 60, 'Healthcare Representative', 'Research & Development', 10883),
#  (1215, 44, 'Healthcare Representative', 'Research & Development', 7879),
#  (1222, 45, 'Healthcare Representative', 'Research & Development', 10748),
#  (1226, 45, 'Research Director', 'Research & Development', 16704),
#  (1230, 40, 'Manufacturing Director', 'Research & Development', 6516),
#  (1233, 35, 'Manufacturing Director', 'Research & Development', 6883),
#  (1241, 39, 'Laboratory Technician', 'Research & Development', 6472),
#  (1251, 29, 'Healthcare Representative', 'Research & Development', 6294),
#  (1265, 55, 'Research Director', 'Research & Development', 19038),
#  (1269, 53, 'Manufacturing Director', 'Research & Development', 12965),
#  (1276, 51, 'Manager', 'Research & Development', 13116),
#  (1278, 46, 'Research Director', 'Research & Development', 19328),
#  (1279, 36, 'Healthcare Representative', 'Research & Development', 8321),
#  (1285, 39, 'Research Director', 'Research & Development', 13464),
#  (1295, 41, 'Healthcare Representative', 'Research & Development', 6870),
#  (1297, 30, 'Manufacturing Director', 'Research & Development', 9667),
#  (1299, 46, 'Healthcare Representative', 'Research & Development', 8926),
#  (1300, 40, 'Healthcare Representative', 'Research & Development', 6513),
#  (1304, 47, 'Manufacturing Director', 'Research & Development', 10333),
#  (1306, 54, 'Research Scientist', 'Research & Development', 6854),
#  (1311, 58, 'Research Director', 'Research & Development', 15787),
#  (1316, 36, 'Research Scientist', 'Research & Development', 6962),
#  (1323, 46, 'Manufacturing Director', 'Research & Development', 8578),
#  (1325, 29, 'Healthcare Representative', 'Research & Development', 6384),
#  (1331, 43, 'Manager', 'Research & Development', 19392),
#  (1332, 48, 'Research Director', 'Research & Development', 19665),
#  (1349, 40, 'Manager', 'Research & Development', 16823),
#  (1352, 48, 'Manager', 'Research & Development', 17174),
#  (1358, 42, 'Research Director', 'Research & Development', 13348),
#  (1378, 49, 'Research Director', 'Research & Development', 19161),
#  (1389, 32, 'Healthcare Representative', 'Research & Development', 6667),
#  (1395, 32, 'Manufacturing Director', 'Research & Development', 9679),
#  (1400, 43, 'Healthcare Representative', 'Research & Development', 7510),
#  (1406, 31, 'Research Director', 'Research & Development', 11031),
#  (1410, 40, 'Laboratory Technician', 'Research & Development', 6323),
#  (1415, 47, 'Healthcare Representative', 'Research & Development', 8633),
#  (1422, 47, 'Research Director', 'Research & Development', 11957),
#  (1431, 38, 'Research Director', 'Research & Development', 13206),
#  (1433, 37, 'Research Director', 'Research & Development', 13744),
#  (1438, 39, 'Manager', 'Research & Development', 19431),
#  (1442, 56, 'Healthcare Representative', 'Research & Development', 6306),
#  (1444, 42, 'Manager', 'Research & Development', 18880),
#  (1446, 41, 'Manufacturing Director', 'Research & Development', 13570),
#  (1464, 31, 'Manufacturing Director', 'Research & Development', 9936),
#  (1467, 39, 'Healthcare Representative', 'Research & Development', 9991),
#  (1479, 38, 'Manufacturing Director', 'Research & Development', 9526),
#  (1486, 29, 'Manufacturing Director', 'Research & Development', 9980),
#  (1493, 34, 'Research Director', 'Research & Development', 11994),
#  (1496, 53, 'Manager', 'Research & Development', 19094),
#  (1499, 44, 'Healthcare Representative', 'Research & Development', 10248),
#  (1502, 44, 'Healthcare Representative', 'Research & Development', 6465),
#  (1516, 41, 'Research Director', 'Research & Development', 19545),
#  (1524, 35, 'Healthcare Representative', 'Research & Development', 9884),
#  (1526, 33, 'Research Director', 'Research & Development', 13458),
#  (1533, 50, 'Research Director', 'Research & Development', 18740),
#  (1535, 36, 'Healthcare Representative', 'Research & Development', 10096),
#  (1536, 55, 'Manager', 'Research & Development', 14756),
#  (1537, 36, 'Manufacturing Director', 'Research & Development', 6499),
#  (1538, 45, 'Research Scientist', 'Research & Development', 9724),
#  (1548, 45, 'Research Director', 'Research & Development', 13245),
#  (1549, 37, 'Research Director', 'Research & Development', 13664),
#  (1556, 56, 'Manufacturing Director', 'Research & Development', 7260),
#  (1561, 40, 'Healthcare Representative', 'Research & Development', 13503),
#  (1564, 46, 'Healthcare Representative', 'Research & Development', 10673),
#  (1566, 54, 'Research Director', 'Research & Development', 13549),
#  (1577, 50, 'Research Director', 'Research & Development', 18172),
#  (1581, 51, 'Healthcare Representative', 'Research & Development', 7484),
#  (1587, 34, 'Manager', 'Research & Development', 11631),
#  (1594, 51, 'Research Director', 'Research & Development', 19537),
#  (1597, 58, 'Healthcare Representative', 'Research & Development', 10312),
#  (1600, 49, 'Manufacturing Director', 'Research & Development', 6567),
#  (1607, 51, 'Manufacturing Director', 'Research & Development', 10650),
#  (1618, 41, 'Manager', 'Research & Development', 17181),
#  (1634, 57, 'Healthcare Representative', 'Research & Development', 9439),
#  (1636, 50, 'Manager', 'Research & Development', 19926),
#  (1657, 40, 'Manager', 'Research & Development', 19033),
#  (1658, 55, 'Research Director', 'Research & Development', 18722),
#  (1659, 34, 'Manufacturing Director', 'Research & Development', 9547),
#  (1660, 51, 'Healthcare Representative', 'Research & Development', 13734),
#  (1661, 52, 'Manager', 'Research & Development', 19999),
#  (1665, 45, 'Manager', 'Research & Development', 16792),
#  (1669, 38, 'Manufacturing Director', 'Research & Development', 6553),
#  (1672, 49, 'Manufacturing Director', 'Research & Development', 6804),
#  (1675, 38, 'Healthcare Representative', 'Research & Development', 6673),
#  (1680, 46, 'Healthcare Representative', 'Research & Development', 9396),
#  (1682, 30, 'Manufacturing Director', 'Research & Development', 8474),
#  (1684, 51, 'Research Director', 'Research & Development', 12490),
#  (1693, 37, 'Research Director', 'Research & Development', 12185),
#  (1702, 42, 'Manager', 'Research & Development', 19232),
#  (1715, 45, 'Manager', 'Research & Development', 19202),
#  (1716, 31, 'Research Director', 'Research & Development', 13675),
#  (1720, 45, 'Manufacturing Director', 'Research & Development', 6434),
#  (1721, 37, 'Manufacturing Director', 'Research & Development', 10048),
#  (1722, 39, 'Healthcare Representative', 'Research & Development', 10938),
#  (1724, 42, 'Research Scientist', 'Research & Development', 6545),
#  (1728, 40, 'Research Director', 'Research & Development', 19436),
#  (1739, 45, 'Healthcare Representative', 'Research & Development', 13496),
#  (1741, 55, 'Manager', 'Research & Development', 19045),
#  (1742, 47, 'Manager', 'Research & Development', 11849),
#  (1746, 37, 'Research Director', 'Research & Development', 13603),
#  (1747, 35, 'Manager', 'Research & Development', 11996),
#  (1749, 26, 'Manufacturing Director', 'Research & Development', 6397),
#  (1750, 50, 'Research Director', 'Research & Development', 19144),
#  (1751, 53, 'Research Director', 'Research & Development', 17584),
#  (1761, 49, 'Research Director', 'Research & Development', 18665),
#  (1775, 39, 'Healthcare Representative', 'Research & Development', 9613),
#  (1778, 38, 'Research Director', 'Research & Development', 12061),
#  (1784, 33, 'Manager', 'Research & Development', 11878),
#  (1785, 39, 'Manager', 'Research & Development', 17068),
#  (1787, 49, 'Healthcare Representative', 'Research & Development', 13964),
#  (1796, 31, 'Manufacturing Director', 'Research & Development', 8943),
#  (1797, 39, 'Manager', 'Research & Development', 19272),
#  (1800, 47, 'Research Director', 'Research & Development', 18300),
#  (1804, 43, 'Healthcare Representative', 'Research & Development', 9985),
#  (1811, 37, 'Manufacturing Director', 'Research & Development', 6347),
#  (1812, 38, 'Research Director', 'Research & Development', 11510),
#  (1813, 31, 'Manufacturing Director', 'Research & Development', 7143),
#  (1815, 35, 'Manufacturing Director', 'Research & Development', 8095),
#  (1819, 42, 'Research Director', 'Research & Development', 15992),
#  (1827, 42, 'Healthcare Representative', 'Research & Development', 6781),
#  (1831, 57, 'Healthcare Representative', 'Research & Development', 6755),
#  (1838, 50, 'Healthcare Representative', 'Research & Development', 10496),
#  (1843, 35, 'Healthcare Representative', 'Research & Development', 6540),
#  (1846, 49, 'Healthcare Representative', 'Research & Development', 10965),
#  (1850, 55, 'Manager', 'Research & Development', 16659),
#  (1861, 43, 'Research Director', 'Research & Development', 14336),
#  (1863, 54, 'Research Director', 'Research & Development', 19406),
#  (1871, 39, 'Manager', 'Research & Development', 19197),
#  (1877, 52, 'Manufacturing Director', 'Research & Development', 7969),
#  (1879, 52, 'Manager', 'Research & Development', 16555),
#  (1882, 60, 'Manager', 'Research & Development', 19566),
#  (1891, 29, 'Research Director', 'Research & Development', 11935),
#  (1896, 50, 'Manager', 'Research & Development', 17046),
#  (1900, 46, 'Research Director', 'Research & Development', 17861),
#  (1905, 31, 'Manufacturing Director', 'Research & Development', 10648),
#  (1906, 33, 'Manager', 'Research & Development', 13610),
#  (1909, 35, 'Healthcare Representative', 'Research & Development', 7632),
#  (1910, 31, 'Healthcare Representative', 'Research & Development', 9824),
#  (1919, 40, 'Manufacturing Director', 'Research & Development', 13237),
#  (1922, 42, 'Manufacturing Director', 'Research & Development', 7406),
#  (1926, 33, 'Research Director', 'Research & Development', 16184),
#  (1930, 41, 'Healthcare Representative', 'Research & Development', 6811),
#  (1935, 37, 'Manufacturing Director', 'Research & Development', 7491),
#  (1936, 46, 'Healthcare Representative', 'Research & Development', 10527),
#  (1942, 38, 'Healthcare Representative', 'Research & Development', 9824),
#  (1943, 37, 'Manufacturing Director', 'Research & Development', 6447),
#  (1944, 49, 'Research Director', 'Research & Development', 19502),
#  (1960, 43, 'Research Director', 'Research & Development', 16627),
#  (1963, 48, 'Manager', 'Research & Development', 15402),
#  (1968, 44, 'Manager', 'Research & Development', 19513),
#  (1971, 32, 'Research Scientist', 'Research & Development', 6322),
#  (1977, 37, 'Manufacturing Director', 'Research & Development', 9434),
#  (1979, 35, 'Research Scientist', 'Research & Development', 6646),
#  (1980, 33, 'Healthcare Representative', 'Research & Development', 7725),
#  (1982, 36, 'Manufacturing Director', 'Research & Development', 8847),
#  (1995, 34, 'Healthcare Representative', 'Research & Development', 8621),
#  (2000, 38, 'Healthcare Representative', 'Research & Development', 7625),
#  (2001, 27, 'Manufacturing Director', 'Research & Development', 7412),
#  (2002, 32, 'Research Director', 'Research & Development', 11159),
#  (2005, 53, 'Research Director', 'Research & Development', 14814),
#  (2008, 27, 'Manufacturing Director', 'Research & Development', 8793),
#  (2012, 36, 'Research Director', 'Research & Development', 11713),
#  (2013, 38, 'Manufacturing Director', 'Research & Development', 7861),
#  (2023, 56, 'Healthcare Representative', 'Research & Development', 11103),
#  (2025, 27, 'Healthcare Representative', 'Research & Development', 6811),
#  (2039, 55, 'Manager', 'Research & Development', 19859),
#  (2055, 42, 'Manager', 'Research & Development', 18430),
#  (2059, 50, 'Research Director', 'Research & Development', 17639),
#  (2061, 33, 'Research Director', 'Research & Development', 11691),
#  (2063, 47, 'Manager', 'Research & Development', 16752),
#  (2066, 58, 'Research Director', 'Research & Development', 19246),
#  (2073, 30, 'Manufacturing Director', 'Research & Development', 6877),
#  (2076, 38, 'Healthcare Representative', 'Research & Development', 6288),
#  (2080, 43, 'Research Director', 'Research & Development', 17159),
#  (2081, 27, 'Research Director', 'Research & Development', 12808),
#  (2082, 35, 'Manufacturing Director', 'Research & Development', 10221),
#  (2098, 52, 'Manufacturing Director', 'Research & Development', 13826),
#  (2106, 35, 'Manufacturing Director', 'Research & Development', 10685),
#  (2118, 35, 'Manufacturing Director', 'Research & Development', 10903),
#  (2120, 53, 'Research Director', 'Research & Development', 14275),
#  (2124, 50, 'Manager', 'Research & Development', 17924),
#  (2135, 36, 'Healthcare Representative', 'Research & Development', 6586),
#  (2145, 58, 'Healthcare Representative', 'Research & Development', 10552),
#  (2148, 49, 'Laboratory Technician', 'Research & Development', 7403),
#  (2152, 38, 'Research Director', 'Research & Development', 13582),
#  (2163, 32, 'Manufacturing Director', 'Research & Development', 6725),
#  (2165, 33, 'Healthcare Representative', 'Research & Development', 6949),
#  (2170, 52, 'Manager', 'Research & Development', 17099),
#  (2185, 50, 'Research Director', 'Research & Development', 17399),
#  (2187, 41, 'Research Director', 'Research & Development', 19419),
#  (2192, 50, 'Manufacturing Director', 'Research & Development', 13973),
#  (2194, 46, 'Manufacturing Director', 'Research & Development', 10845),
#  (2199, 54, 'Manufacturing Director', 'Research & Development', 10739),
#  (2200, 35, 'Healthcare Representative', 'Research & Development', 10388),
#  (2201, 30, 'Research Director', 'Research & Development', 11416),
#  (2207, 48, 'Healthcare Representative', 'Research & Development', 10999),
#  (2209, 39, 'Manufacturing Director', 'Research & Development', 12742),
#  (2214, 59, 'Manufacturing Director', 'Research & Development', 13726),
#  (2216, 55, 'Healthcare Representative', 'Research & Development', 6385),
#  (2217, 41, 'Research Director', 'Research & Development', 19973),
#  (2224, 39, 'Manufacturing Director', 'Research & Development', 10880),
#  (2237, 50, 'Research Director', 'Research & Development', 19237),
#  (2241, 46, 'Research Director', 'Research & Development', 19627),
#  (2244, 36, 'Manufacturing Director', 'Research & Development', 8858),
#  (2245, 55, 'Manager', 'Research & Development', 16756),
#  (2251, 28, 'Healthcare Representative', 'Research & Development', 8722),
#  (2253, 30, 'Manufacturing Director', 'Research & Development', 9957),
#  (2255, 38, 'Healthcare Representative', 'Research & Development', 8823),
#  (2256, 40, 'Healthcare Representative', 'Research & Development', 10322),
#  (2258, 55, 'Manufacturing Director', 'Research & Development', 10976),
#  (2261, 33, 'Healthcare Representative', 'Research & Development', 7119),
#  (2265, 34, 'Healthcare Representative', 'Research & Development', 7756),
#  (2270, 42, 'Manager', 'Research & Development', 17665),
#  (2275, 48, 'Manager', 'Research & Development', 16885),
#  (2277, 52, 'Healthcare Representative', 'Research & Development', 10445),
#  (2280, 28, 'Manufacturing Director', 'Research & Development', 7655),
#  (2283, 43, 'Manufacturing Director', 'Research & Development', 10820),
#  (2284, 39, 'Healthcare Representative', 'Research & Development', 12169),
#  (2285, 40, 'Research Director', 'Research & Development', 19626),
#  (2287, 39, 'Laboratory Technician', 'Research & Development', 6782),
#  (2288, 36, 'Manufacturing Director', 'Research & Development', 7779),
#  (2308, 40, 'Research Director', 'Research & Development', 13499),
#  (2317, 35, 'Manufacturing Director', 'Research & Development', 10274),
#  (2322, 56, 'Manager', 'Research & Development', 19943),
#  (2326, 37, 'Manufacturing Director', 'Research & Development', 6474),
#  (2329, 53, 'Manager', 'Research & Development', 18606),
#  (2338, 50, 'Manager', 'Research & Development', 17856),
#  (2340, 46, 'Research Director', 'Research & Development', 19081),
#  (2348, 46, 'Manufacturing Director', 'Research & Development', 7379),
#  (2353, 36, 'Manufacturing Director', 'Research & Development', 10252),
#  (2358, 42, 'Research Director', 'Research & Development', 13191),
#  (2361, 54, 'Manufacturing Director', 'Research & Development', 10502),
#  (2365, 54, 'Research Director', 'Research & Development', 17779),
#  (2366, 31, 'Healthcare Representative', 'Research & Development', 6833),
#  (2367, 31, 'Healthcare Representative', 'Research & Development', 6812),
#  (2369, 43, 'Research Director', 'Research & Development', 19740),
#  (2370, 49, 'Manager', 'Research & Development', 18711),
#  (2374, 29, 'Healthcare Representative', 'Research & Development', 6623),
#  (2375, 48, 'Research Director', 'Research & Development', 18265),
#  (2376, 29, 'Research Director', 'Research & Development', 16124),
#  (2385, 55, 'Healthcare Representative', 'Research & Development', 13577),
#  (2390, 59, 'Manufacturing Director', 'Research & Development', 10512),
#  (2393, 44, 'Manager', 'Research & Development', 19190),
#  (2399, 44, 'Healthcare Representative', 'Research & Development', 7978),
#  (2407, 45, 'Manager', 'Research & Development', 18061),
#  (2408, 39, 'Manager', 'Research & Development', 17123),
#  (2413, 36, 'Healthcare Representative', 'Research & Development', 7094),
#  (2415, 28, 'Laboratory Technician', 'Research & Development', 6674),
#  (2416, 50, 'Research Director', 'Research & Development', 16880),
#  (2419, 30, 'Manager', 'Research & Development', 11916),
#  (2425, 42, 'Manager', 'Research & Development', 17861),
#  (2426, 55, 'Manager', 'Research & Development', 19187),
#  (2429, 34, 'Healthcare Representative', 'Research & Development', 8500),
#  (2437, 58, 'Manufacturing Director', 'Research & Development', 10008),
#  (2440, 48, 'Manufacturing Director', 'Research & Development', 7898),
#  (2442, 51, 'Manufacturing Director', 'Research & Development', 13142),
#  (2447, 56, 'Manufacturing Director', 'Research & Development', 13402),
#  (2449, 40, 'Healthcare Representative', 'Research & Development', 6377),
#  (2454, 34, 'Healthcare Representative', 'Research & Development', 6687),
#  (2463, 39, 'Healthcare Representative', 'Research & Development', 10920),
#  (2465, 52, 'Manufacturing Director', 'Research & Development', 13247),
#  (2473, 35, 'Manufacturing Director', 'Research & Development', 9362),
#  (2478, 29, 'Healthcare Representative', 'Research & Development', 7553),
#  (2479, 54, 'Research Director', 'Research & Development', 17328),
#  (2480, 58, 'Research Director', 'Research & Development', 19701),
#  (2481, 55, 'Research Director', 'Research & Development', 14732),
#  (2485, 31, 'Research Director', 'Research & Development', 16422),
#  (2495, 47, 'Research Director', 'Research & Development', 17169),
#  (2504, 31, 'Manufacturing Director', 'Research & Development', 7446),
#  (2505, 45, 'Healthcare Representative', 'Research & Development', 10851),
#  (2508, 45, 'Manufacturing Director', 'Research & Development', 9380),
#  (2511, 40, 'Research Director', 'Research & Development', 13757),
#  (2514, 53, 'Research Director', 'Research & Development', 16598),
#  (2515, 49, 'Healthcare Representative', 'Research & Development', 6651),
#  (2525, 49, 'Healthcare Representative', 'Research & Development', 10466),
#  (2526, 34, 'Research Director', 'Research & Development', 17007),
#  (2533, 44, 'Manufacturing Director', 'Research & Development', 10209),
#  (2544, 28, 'Manufacturing Director', 'Research & Development', 6549),
#  (2545, 33, 'Healthcare Representative', 'Research & Development', 6388),
#  (2546, 32, 'Manager', 'Research & Development', 11244),
#  (2547, 54, 'Manager', 'Research & Development', 16032),
#  (2549, 44, 'Research Director', 'Research & Development', 16328),
#  (2550, 39, 'Manufacturing Director', 'Research & Development', 8376),
#  (2552, 35, 'Healthcare Representative', 'Research & Development', 8606),
#  (2557, 50, 'Research Director', 'Research & Development', 14411),
#  (2561, 29, 'Healthcare Representative', 'Research & Development', 9715),
#  (2564, 42, 'Healthcare Representative', 'Research & Development', 10124),
#  (2570, 45, 'Healthcare Representative', 'Research & Development', 7441),
#  (2582, 53, 'Manufacturing Director', 'Research & Development', 10169),
#  (2596, 29, 'Healthcare Representative', 'Research & Development', 8853),
#  (2600, 42, 'Manager', 'Research & Development', 19613),
#  (2609, 50, 'Healthcare Representative', 'Research & Development', 11245),
#  (2611, 44, 'Research Director', 'Research & Development', 19049),
#  (2627, 40, 'Manufacturing Director', 'Research & Development', 10435),
#  (2632, 38, 'Manufacturing Director', 'Research & Development', 7756),
#  (2635, 40, 'Manufacturing Director', 'Research & Development', 7945),
#  (2637, 48, 'Manager', 'Research & Development', 15202),
#  (2644, 36, 'Healthcare Representative', 'Research & Development', 8008),
#  (2647, 49, 'Research Director', 'Research & Development', 16413),
#  (2648, 50, 'Research Director', 'Research & Development', 13269),
#  (2652, 49, 'Healthcare Representative', 'Research & Development', 13966),
#  (2654, 36, 'Healthcare Representative', 'Research & Development', 6842),
#  (2655, 54, 'Manager', 'Research & Development', 17426),
#  (2656, 43, 'Research Director', 'Research & Development', 17603),
#  (2666, 49, 'Manager', 'Research & Development', 15379),
#  (2674, 53, 'Healthcare Representative', 'Research & Development', 7005),
#  (2680, 60, 'Healthcare Representative', 'Research & Development', 10883),
#  (2685, 44, 'Healthcare Representative', 'Research & Development', 7879),
#  (2692, 45, 'Healthcare Representative', 'Research & Development', 10748),
#  (2696, 45, 'Research Director', 'Research & Development', 16704),
#  (2700, 40, 'Manufacturing Director', 'Research & Development', 6516),
#  (2703, 35, 'Manufacturing Director', 'Research & Development', 6883),
#  (2711, 39, 'Laboratory Technician', 'Research & Development', 6472),
#  (2721, 29, 'Healthcare Representative', 'Research & Development', 6294),
#  (2735, 55, 'Research Director', 'Research & Development', 19038),
#  (2739, 53, 'Manufacturing Director', 'Research & Development', 12965),
#  (2746, 51, 'Manager', 'Research & Development', 13116),
#  (2748, 46, 'Research Director', 'Research & Development', 19328),
#  (2749, 36, 'Healthcare Representative', 'Research & Development', 8321),
#  (2755, 39, 'Research Director', 'Research & Development', 13464),
#  (2765, 41, 'Healthcare Representative', 'Research & Development', 6870),
#  (2767, 30, 'Manufacturing Director', 'Research & Development', 9667),
#  (2769, 46, 'Healthcare Representative', 'Research & Development', 8926),
#  (2770, 40, 'Healthcare Representative', 'Research & Development', 6513),
#  (2774, 47, 'Manufacturing Director', 'Research & Development', 10333),
#  (2776, 54, 'Research Scientist', 'Research & Development', 6854),
#  (2781, 58, 'Research Director', 'Research & Development', 15787),
#  (2786, 36, 'Research Scientist', 'Research & Development', 6962),
#  (2793, 46, 'Manufacturing Director', 'Research & Development', 8578),
#  (2795, 29, 'Healthcare Representative', 'Research & Development', 6384),
#  (2801, 43, 'Manager', 'Research & Development', 19392),
#  (2802, 48, 'Research Director', 'Research & Development', 19665),
#  (2819, 40, 'Manager', 'Research & Development', 16823),
#  (2822, 48, 'Manager', 'Research & Development', 17174),
#  (2828, 42, 'Research Director', 'Research & Development', 13348),
#  (2848, 49, 'Research Director', 'Research & Development', 19161),
#  (2859, 32, 'Healthcare Representative', 'Research & Development', 6667),
#  (2865, 32, 'Manufacturing Director', 'Research & Development', 9679),
#  (2870, 43, 'Healthcare Representative', 'Research & Development', 7510),
#  (2876, 31, 'Research Director', 'Research & Development', 11031),
#  (2880, 40, 'Laboratory Technician', 'Research & Development', 6323),
#  (2885, 47, 'Healthcare Representative', 'Research & Development', 8633),
#  (2892, 47, 'Research Director', 'Research & Development', 11957),
#  (2901, 38, 'Research Director', 'Research & Development', 13206),
#  (2903, 37, 'Research Director', 'Research & Development', 13744),
#  (2908, 39, 'Manager', 'Research & Development', 19431),
#  (2912, 56, 'Healthcare Representative', 'Research & Development', 6306),
#  (2914, 42, 'Manager', 'Research & Development', 18880),
#  (2916, 41, 'Manufacturing Director', 'Research & Development', 13570),
#  (2934, 31, 'Manufacturing Director', 'Research & Development', 9936),
#  (2937, 39, 'Healthcare Representative', 'Research & Development', 9991),
#  (19, 53, 'Manager', 'Sales', 15427),
#  (30, 46, 'Manager', 'Sales', 18947),
#  (44, 27, 'Sales Executive', 'Sales', 8726),
#  (57, 35, 'Sales Executive', 'Sales', 9069),
#  (64, 59, 'Sales Executive', 'Sales', 7637),
#  (83, 55, 'Sales Executive', 'Sales', 10239),
#  (90, 46, 'Sales Executive', 'Sales', 9619),
#  (99, 58, 'Sales Executive', 'Sales', 13872),
#  (116, 37, 'Sales Executive', 'Sales', 7428),
#  (118, 36, 'Sales Executive', 'Sales', 9738),
#  (120, 43, 'Manager', 'Sales', 16959),
#  (132, 50, 'Sales Executive', 'Sales', 9208),
#  (134, 41, 'Sales Executive', 'Sales', 8189),
#  (139, 25, 'Sales Executive', 'Sales', 8639),
#  (152, 35, 'Sales Executive', 'Sales', 7295),
#  (155, 32, 'Sales Executive', 'Sales', 8998),
#  (159, 40, 'Sales Executive', 'Sales', 10855),
#  (168, 30, 'Sales Executive', 'Sales', 9419),
#  (169, 38, 'Sales Executive', 'Sales', 8686),
#  (179, 46, 'Sales Executive', 'Sales', 10453),
#  (206, 29, 'Sales Executive', 'Sales', 7639),
#  (211, 32, 'Sales Executive', 'Sales', 10400),
#  (213, 27, 'Sales Executive', 'Sales', 9981),
#  (216, 41, 'Manager', 'Sales', 13591),
#  (219, 45, 'Sales Executive', 'Sales', 8865),
#  (224, 38, 'Sales Executive', 'Sales', 10609),
#  (228, 29, 'Sales Executive', 'Sales', 7918),
#  (229, 35, 'Sales Executive', 'Sales', 8789),
#  (234, 50, 'Manager', 'Sales', 19517),
#  (236, 43, 'Manager', 'Sales', 16064),
#  (238, 52, 'Manager', 'Sales', 19068),
#  (264, 46, 'Manager', 'Sales', 16872),
#  (296, 42, 'Sales Executive', 'Sales', 13525),
#  (298, 35, 'Sales Executive', 'Sales', 8020),
#  (301, 41, 'Manager', 'Sales', 16015),
#  (322, 31, 'Sales Executive', 'Sales', 7547),
#  (336, 40, 'Sales Executive', 'Sales', 7457),
#  (344, 29, 'Sales Executive', 'Sales', 8268),
#  (353, 48, 'Manager', 'Sales', 12504),
#  (360, 36, 'Sales Executive', 'Sales', 9699),
#  (367, 41, 'Sales Executive', 'Sales', 9355),
#  (385, 36, 'Sales Executive', 'Sales', 7596),
#  (402, 56, 'Sales Executive', 'Sales', 13212),
#  (404, 41, 'Sales Executive', 'Sales', 8392),
#  (418, 40, 'Manager', 'Sales', 18041),
#  (424, 30, 'Sales Executive', 'Sales', 8412),
#  (425, 57, 'Manager', 'Sales', 14118),
#  (428, 60, 'Sales Executive', 'Sales', 10266),
#  (434, 46, 'Sales Executive', 'Sales', 9071),
#  (443, 36, 'Sales Executive', 'Sales', 9980),
#  (446, 55, 'Manager', 'Sales', 16835),
#  (457, 31, 'Manager', 'Sales', 11557),
#  (459, 40, 'Sales Executive', 'Sales', 10932),
#  (467, 41, 'Manager', 'Sales', 16595),
#  (468, 37, 'Sales Executive', 'Sales', 8834),
#  (487, 37, 'Sales Executive', 'Sales', 9602),
#  (500, 33, 'Sales Executive', 'Sales', 7104),
#  (503, 53, 'Sales Executive', 'Sales', 8381),
#  (521, 48, 'Sales Executive', 'Sales', 8120),
#  (534, 40, 'Sales Executive', 'Sales', 10475),
#  (545, 47, 'Sales Executive', 'Sales', 13770),
#  (562, 52, 'Manager', 'Sales', 16856),
#  (570, 36, 'Sales Executive', 'Sales', 7587),
#  (608, 49, 'Sales Executive', 'Sales', 7654),
#  (617, 51, 'Manager', 'Sales', 16307),
#  (625, 53, 'Sales Executive', 'Sales', 10934),
#  (626, 45, 'Sales Executive', 'Sales', 10761),
#  (647, 53, 'Sales Executive', 'Sales', 11836),
#  (653, 37, 'Sales Executive', 'Sales', 7642),
#  (685, 40, 'Sales Executive', 'Sales', 9705),
#  (694, 36, 'Sales Executive', 'Sales', 10325),
#  (696, 37, 'Sales Executive', 'Sales', 10609),
#  (702, 53, 'Manager', 'Sales', 14852),
#  (703, 30, 'Sales Executive', 'Sales', 7264),
#  (705, 35, 'Sales Executive', 'Sales', 7823),
#  (706, 39, 'Sales Executive', 'Sales', 7880),
#  (707, 40, 'Sales Executive', 'Sales', 13194),
#  (711, 33, 'Manager', 'Sales', 17444),
#  (742, 42, 'Manager', 'Sales', 18303),
#  (750, 52, 'Manager', 'Sales', 19845),
#  (751, 44, 'Sales Executive', 'Sales', 13320),
#  (756, 45, 'Manager', 'Sales', 17650),
#  (758, 34, 'Sales Executive', 'Sales', 9725),
#  (759, 59, 'Manager', 'Sales', 11904),
#  (761, 53, 'Sales Executive', 'Sales', 7525),
#  (769, 40, 'Sales Executive', 'Sales', 8396),
#  (772, 54, 'Sales Executive', 'Sales', 10686),
#  (776, 43, 'Sales Executive', 'Sales', 10798),
#  (792, 35, 'Sales Executive', 'Sales', 9582),
#  (808, 38, 'Sales Executive', 'Sales', 8740),
#  (811, 46, 'Manager', 'Sales', 17465),
#  (812, 38, 'Sales Executive', 'Sales', 7351),
#  (822, 49, 'Sales Executive', 'Sales', 13120),
#  (830, 33, 'Sales Executive', 'Sales', 8224),
#  (837, 29, 'Sales Executive', 'Sales', 7336),
#  (839, 42, 'Sales Executive', 'Sales', 13758),
#  (862, 46, 'Manager', 'Sales', 17048),
#  (871, 35, 'Sales Executive', 'Sales', 8966),
#  (889, 35, 'Sales Executive', 'Sales', 10377),
#  (908, 44, 'Manager', 'Sales', 18213),
#  (909, 33, 'Sales Executive', 'Sales', 8380),
#  (914, 45, 'Manager', 'Sales', 18824),
#  (917, 46, 'Manager', 'Sales', 18789),
#  (919, 51, 'Manager', 'Sales', 19847),
#  (927, 43, 'Sales Executive', 'Sales', 10231),
#  (947, 40, 'Sales Executive', 'Sales', 9094),
#  (948, 52, 'Sales Executive', 'Sales', 8446),
#  (951, 31, 'Sales Executive', 'Sales', 9852),
#  (976, 55, 'Sales Executive', 'Sales', 13695),
#  (988, 51, 'Sales Executive', 'Sales', 10596),
#  (991, 33, 'Sales Executive', 'Sales', 9998),
#  (1012, 36, 'Sales Executive', 'Sales', 9278),
#  (1027, 32, 'Sales Executive', 'Sales', 9204),
#  (1031, 31, 'Sales Executive', 'Sales', 10793),
#  (1032, 46, 'Sales Executive', 'Sales', 10096),
#  (1042, 28, 'Sales Executive', 'Sales', 8463),
#  (1064, 29, 'Sales Executive', 'Sales', 8620),
#  (1081, 46, 'Manager', 'Sales', 16606),
#  (1085, 34, 'Sales Executive', 'Sales', 7083),
#  (1107, 30, 'Sales Executive', 'Sales', 9714),
#  (1110, 30, 'Sales Executive', 'Sales', 9250),
#  (1117, 55, 'Manager', 'Sales', 19586),
#  (1120, 38, 'Sales Executive', 'Sales', 9924),
#  (1125, 39, 'Sales Executive', 'Sales', 8237),
#  (1127, 50, 'Manager', 'Sales', 19331),
#  (1136, 46, 'Manager', 'Sales', 17567),
#  (1163, 35, 'Sales Executive', 'Sales', 10306),
#  (1195, 47, 'Manager', 'Sales', 15972),
#  (1197, 41, 'Sales Executive', 'Sales', 7082),
#  (1212, 37, 'Sales Executive', 'Sales', 9525),
#  (1217, 43, 'Sales Executive', 'Sales', 7847),
#  (1219, 41, 'Sales Executive', 'Sales', 9241),
#  (1224, 47, 'Sales Executive', 'Sales', 12936),
#  (1236, 46, 'Sales Executive', 'Sales', 10368),
#  (1242, 32, 'Sales Executive', 'Sales', 9610),
#  (1243, 40, 'Manager', 'Sales', 19833),
#  (1248, 31, 'Sales Executive', 'Sales', 8346),
#  (1252, 30, 'Sales Executive', 'Sales', 7140),
#  (1256, 33, 'Sales Executive', 'Sales', 8564),
#  (1258, 31, 'Sales Executive', 'Sales', 8161),
#  (1286, 46, 'Sales Executive', 'Sales', 7991),
#  (1296, 41, 'Sales Executive', 'Sales', 10447),
#  (1302, 58, 'Manager', 'Sales', 16291),
#  (1307, 31, 'Sales Executive', 'Sales', 9637),
#  (1327, 32, 'Sales Executive', 'Sales', 9907),
#  (1328, 46, 'Sales Executive', 'Sales', 13225),
#  (1334, 46, 'Sales Executive', 'Sales', 7314),
#  (1343, 34, 'Sales Executive', 'Sales', 9713),
#  (1360, 34, 'Sales Executive', 'Sales', 8103),
#  (1370, 28, 'Sales Executive', 'Sales', 9854),
#  (1375, 58, 'Manager', 'Sales', 17875),
#  (1385, 34, 'Sales Executive', 'Sales', 9888),
#  (1386, 34, 'Sales Executive', 'Sales', 8628),
#  (1397, 53, 'Sales Executive', 'Sales', 10448),
#  (1404, 39, 'Sales Executive', 'Sales', 13341),
#  (1432, 32, 'Sales Executive', 'Sales', 10422),
#  (1440, 36, 'Sales Executive', 'Sales', 7644),
#  (1449, 41, 'Sales Executive', 'Sales', 8938),
#  (1462, 50, 'Sales Executive', 'Sales', 10854),
#  (1463, 39, 'Sales Executive', 'Sales', 12031),
#  (1489, 53, 'Manager', 'Sales', 15427),
#  (1500, 46, 'Manager', 'Sales', 18947),
#  (1514, 27, 'Sales Executive', 'Sales', 8726),
#  (1527, 35, 'Sales Executive', 'Sales', 9069),
#  (1534, 59, 'Sales Executive', 'Sales', 7637),
#  (1553, 55, 'Sales Executive', 'Sales', 10239),
#  (1560, 46, 'Sales Executive', 'Sales', 9619),
#  (1569, 58, 'Sales Executive', 'Sales', 13872),
#  (1586, 37, 'Sales Executive', 'Sales', 7428),
#  (1588, 36, 'Sales Executive', 'Sales', 9738),
#  (1590, 43, 'Manager', 'Sales', 16959),
#  (1602, 50, 'Sales Executive', 'Sales', 9208),
#  (1604, 41, 'Sales Executive', 'Sales', 8189),
#  (1609, 25, 'Sales Executive', 'Sales', 8639),
#  (1622, 35, 'Sales Executive', 'Sales', 7295),
#  (1625, 32, 'Sales Executive', 'Sales', 8998),
#  (1629, 40, 'Sales Executive', 'Sales', 10855),
#  (1638, 30, 'Sales Executive', 'Sales', 9419),
#  (1639, 38, 'Sales Executive', 'Sales', 8686),
#  (1649, 46, 'Sales Executive', 'Sales', 10453),
#  (1676, 29, 'Sales Executive', 'Sales', 7639),
#  (1681, 32, 'Sales Executive', 'Sales', 10400),
#  (1683, 27, 'Sales Executive', 'Sales', 9981),
#  (1686, 41, 'Manager', 'Sales', 13591),
#  (1689, 45, 'Sales Executive', 'Sales', 8865),
#  (1694, 38, 'Sales Executive', 'Sales', 10609),
#  (1698, 29, 'Sales Executive', 'Sales', 7918),
#  (1699, 35, 'Sales Executive', 'Sales', 8789),
#  (1704, 50, 'Manager', 'Sales', 19517),
#  (1706, 43, 'Manager', 'Sales', 16064),
#  (1708, 52, 'Manager', 'Sales', 19068),
#  (1734, 46, 'Manager', 'Sales', 16872),
#  (1766, 42, 'Sales Executive', 'Sales', 13525),
#  (1768, 35, 'Sales Executive', 'Sales', 8020),
#  (1771, 41, 'Manager', 'Sales', 16015),
#  (1792, 31, 'Sales Executive', 'Sales', 7547),
#  (1806, 40, 'Sales Executive', 'Sales', 7457),
#  (1814, 29, 'Sales Executive', 'Sales', 8268),
#  (1823, 48, 'Manager', 'Sales', 12504),
#  (1830, 36, 'Sales Executive', 'Sales', 9699),
#  (1837, 41, 'Sales Executive', 'Sales', 9355),
#  (1855, 36, 'Sales Executive', 'Sales', 7596),
#  (1872, 56, 'Sales Executive', 'Sales', 13212),
#  (1874, 41, 'Sales Executive', 'Sales', 8392),
#  (1888, 40, 'Manager', 'Sales', 18041),
#  (1894, 30, 'Sales Executive', 'Sales', 8412),
#  (1895, 57, 'Manager', 'Sales', 14118),
#  (1898, 60, 'Sales Executive', 'Sales', 10266),
#  (1904, 46, 'Sales Executive', 'Sales', 9071),
#  (1913, 36, 'Sales Executive', 'Sales', 9980),
#  (1916, 55, 'Manager', 'Sales', 16835),
#  (1927, 31, 'Manager', 'Sales', 11557),
#  (1929, 40, 'Sales Executive', 'Sales', 10932),
#  (1937, 41, 'Manager', 'Sales', 16595),
#  (1938, 37, 'Sales Executive', 'Sales', 8834),
#  (1957, 37, 'Sales Executive', 'Sales', 9602),
#  (1970, 33, 'Sales Executive', 'Sales', 7104),
#  (1973, 53, 'Sales Executive', 'Sales', 8381),
#  (1991, 48, 'Sales Executive', 'Sales', 8120),
#  (2004, 40, 'Sales Executive', 'Sales', 10475),
#  (2015, 47, 'Sales Executive', 'Sales', 13770),
#  (2032, 52, 'Manager', 'Sales', 16856),
#  (2040, 36, 'Sales Executive', 'Sales', 7587),
#  (2078, 49, 'Sales Executive', 'Sales', 7654),
#  (2087, 51, 'Manager', 'Sales', 16307),
#  (2095, 53, 'Sales Executive', 'Sales', 10934),
#  (2096, 45, 'Sales Executive', 'Sales', 10761),
#  (2117, 53, 'Sales Executive', 'Sales', 11836),
#  (2123, 37, 'Sales Executive', 'Sales', 7642),
#  (2155, 40, 'Sales Executive', 'Sales', 9705),
#  (2164, 36, 'Sales Executive', 'Sales', 10325),
#  (2166, 37, 'Sales Executive', 'Sales', 10609),
#  (2172, 53, 'Manager', 'Sales', 14852),
#  (2173, 30, 'Sales Executive', 'Sales', 7264),
#  (2175, 35, 'Sales Executive', 'Sales', 7823),
#  (2176, 39, 'Sales Executive', 'Sales', 7880),
#  (2177, 40, 'Sales Executive', 'Sales', 13194),
#  (2181, 33, 'Manager', 'Sales', 17444),
#  (2212, 42, 'Manager', 'Sales', 18303),
#  (2220, 52, 'Manager', 'Sales', 19845),
#  (2221, 44, 'Sales Executive', 'Sales', 13320),
#  (2226, 45, 'Manager', 'Sales', 17650),
#  (2228, 34, 'Sales Executive', 'Sales', 9725),
#  (2229, 59, 'Manager', 'Sales', 11904),
#  (2231, 53, 'Sales Executive', 'Sales', 7525),
#  (2239, 40, 'Sales Executive', 'Sales', 8396),
#  (2242, 54, 'Sales Executive', 'Sales', 10686),
#  (2246, 43, 'Sales Executive', 'Sales', 10798),
#  (2262, 35, 'Sales Executive', 'Sales', 9582),
#  (2278, 38, 'Sales Executive', 'Sales', 8740),
#  (2281, 46, 'Manager', 'Sales', 17465),
#  (2282, 38, 'Sales Executive', 'Sales', 7351),
#  (2292, 49, 'Sales Executive', 'Sales', 13120),
#  (2300, 33, 'Sales Executive', 'Sales', 8224),
#  (2307, 29, 'Sales Executive', 'Sales', 7336),
#  (2309, 42, 'Sales Executive', 'Sales', 13758),
#  (2332, 46, 'Manager', 'Sales', 17048),
#  (2341, 35, 'Sales Executive', 'Sales', 8966),
#  (2359, 35, 'Sales Executive', 'Sales', 10377),
#  (2378, 44, 'Manager', 'Sales', 18213),
#  (2379, 33, 'Sales Executive', 'Sales', 8380),
#  (2384, 45, 'Manager', 'Sales', 18824),
#  (2387, 46, 'Manager', 'Sales', 18789),
#  (2389, 51, 'Manager', 'Sales', 19847),
#  (2397, 43, 'Sales Executive', 'Sales', 10231),
#  (2417, 40, 'Sales Executive', 'Sales', 9094),
#  (2418, 52, 'Sales Executive', 'Sales', 8446),
#  (2421, 31, 'Sales Executive', 'Sales', 9852),
#  (2446, 55, 'Sales Executive', 'Sales', 13695),
#  (2458, 51, 'Sales Executive', 'Sales', 10596),
#  (2461, 33, 'Sales Executive', 'Sales', 9998),
#  (2482, 36, 'Sales Executive', 'Sales', 9278),
#  (2497, 32, 'Sales Executive', 'Sales', 9204),
#  (2501, 31, 'Sales Executive', 'Sales', 10793),
#  (2502, 46, 'Sales Executive', 'Sales', 10096),
#  (2512, 28, 'Sales Executive', 'Sales', 8463),
#  (2534, 29, 'Sales Executive', 'Sales', 8620),
#  (2551, 46, 'Manager', 'Sales', 16606),
#  (2555, 34, 'Sales Executive', 'Sales', 7083),
#  (2577, 30, 'Sales Executive', 'Sales', 9714),
#  (2580, 30, 'Sales Executive', 'Sales', 9250),
#  (2587, 55, 'Manager', 'Sales', 19586),
#  (2590, 38, 'Sales Executive', 'Sales', 9924),
#  (2595, 39, 'Sales Executive', 'Sales', 8237),
#  (2597, 50, 'Manager', 'Sales', 19331),
#  (2606, 46, 'Manager', 'Sales', 17567),
#  (2633, 35, 'Sales Executive', 'Sales', 10306),
#  (2665, 47, 'Manager', 'Sales', 15972),
#  (2667, 41, 'Sales Executive', 'Sales', 7082),
#  (2682, 37, 'Sales Executive', 'Sales', 9525),
#  (2687, 43, 'Sales Executive', 'Sales', 7847),
#  (2689, 41, 'Sales Executive', 'Sales', 9241),
#  (2694, 47, 'Sales Executive', 'Sales', 12936),
#  (2706, 46, 'Sales Executive', 'Sales', 10368),
#  (2712, 32, 'Sales Executive', 'Sales', 9610),
#  (2713, 40, 'Manager', 'Sales', 19833),
#  (2718, 31, 'Sales Executive', 'Sales', 8346),
#  (2722, 30, 'Sales Executive', 'Sales', 7140),
#  (2726, 33, 'Sales Executive', 'Sales', 8564),
#  (2728, 31, 'Sales Executive', 'Sales', 8161),
#  (2756, 46, 'Sales Executive', 'Sales', 7991),
#  (2766, 41, 'Sales Executive', 'Sales', 10447),
#  (2772, 58, 'Manager', 'Sales', 16291),
#  (2777, 31, 'Sales Executive', 'Sales', 9637),
#  (2797, 32, 'Sales Executive', 'Sales', 9907),
#  (2798, 46, 'Sales Executive', 'Sales', 13225),
#  (2804, 46, 'Sales Executive', 'Sales', 7314),
#  (2813, 34, 'Sales Executive', 'Sales', 9713),
#  (2830, 34, 'Sales Executive', 'Sales', 8103),
#  (2840, 28, 'Sales Executive', 'Sales', 9854),
#  (2845, 58, 'Manager', 'Sales', 17875),
#  (2855, 34, 'Sales Executive', 'Sales', 9888),
#  (2856, 34, 'Sales Executive', 'Sales', 8628),
#  (2867, 53, 'Sales Executive', 'Sales', 10448),
#  (2874, 39, 'Sales Executive', 'Sales', 13341),
#  (2902, 32, 'Sales Executive', 'Sales', 10422),
#  (2910, 36, 'Sales Executive', 'Sales', 7644),
#  (2919, 41, 'Sales Executive', 'Sales', 8938),
#  (2932, 50, 'Sales Executive', 'Sales', 10854),
#  (2933, 39, 'Sales Executive', 'Sales', 12031)]

# %%
# %%sql
#
# SELECT COUNT(id) total_num
#     FROM attrition_records AS a
# WHERE MonthlyIncome > (SELECT ROUND(AVG(MonthlyIncome)) avg_monthly_income
#                         FROM attrition_records b
#                         WHERE b.Department = a.Department)
# ORDER BY a.Department;
# Out:
#    postgresql://postgres:***@localhost/myDB
#  * sqlite:///db/attr_data.db
# Done.
# [(966,)]

# %%
# Select the highest earners in each departments

# %%
# %%sql
#
# SELECT Department, MAX(MonthlyIncome)
#     FROM attrition_records
#     GROUP BY Department;
# Out:
#    postgresql://postgres:***@localhost/myDB
#  * sqlite:///db/attr_data.db
# Done.
# [('Human Resources', 19717),
#  ('Research & Development', 19999),
#  ('Sales', 19847)]

# %%
# %%sql
#
# SELECT id, Age, Gender, JobRole, Department, MonthlyIncome
#     FROM attrition_records
# WHERE (Department, MonthlyIncome) IN (SELECT Department, MAX(MonthlyIncome)
#                                         FROM attrition_records
#                                         GROUP BY Department)
# ORDER BY Department;
# Out:
#    postgresql://postgres:***@localhost/myDB
#  * sqlite:///db/attr_data.db
# Done.
# [(957, 56, 'Male', 'Manager', 'Human Resources', 19717),
#  (2427, 56, 'Male', 'Manager', 'Human Resources', 19717),
#  (191, 52, 'Male', 'Manager', 'Research & Development', 19999),
#  (1661, 52, 'Male', 'Manager', 'Research & Development', 19999),
#  (919, 51, 'Male', 'Manager', 'Sales', 19847),
#  (2389, 51, 'Male', 'Manager', 'Sales', 19847)]

# %%
# Verify

# %%
# %%sql
#
# SELECT id, Age, Department, MonthlyIncome
#     FROM attrition_records
# WHERE Department = "Human Resources"
# ORDER BY MonthlyIncome DESC
# LIMIT 3;
# Out:
#    postgresql://postgres:***@localhost/myDB
#  * sqlite:///db/attr_data.db
# Done.
# [(957, 56, 'Human Resources', 19717),
#  (2427, 56, 'Human Resources', 19717),
#  (1155, 47, 'Human Resources', 19658)]

# %%
# Practice Qs: Verify the other results (departments)

# %%
# %%sql
#
# SELECT id, Age, Department, MonthlyIncome
#     FROM attrition_records
# WHERE Department = "Sales"
# ORDER BY MonthlyIncome DESC
# LIMIT 3;
# Out:
#    postgresql://postgres:***@localhost/myDB
#  * sqlite:///db/attr_data.db
# Done.
# [(919, 51, 'Sales', 19847),
#  (2389, 51, 'Sales', 19847),
#  (750, 52, 'Sales', 19845)]

# %% [markdown]
# ### Practice Qs (Advanced!)
#
# * Find the department(s) that has/have total monthly_income greater than the average total monthly_income across all the departments.

# %% [raw]
# 1. Calculate the total monthly_income for each department
# 2. Calculate the average total monthly_income across all departments
# 3. Compare steps 1 and 2

# %%
# %%sql
#
# SELECT id, Age, Department, MonthlyIncome
# FROM attrition_records
# LIMIT 3;
# Out:
#    postgresql://postgres:***@localhost/myDB
#  * sqlite:///db/attr_data.db
# Done.
# [(1, 41, 'Sales', 5993),
#  (2, 49, 'Research & Development', 5130),
#  (3, 37, 'Research & Development', 2090)]

# %%
# %%sql
#
# SELECT Department, SUM(MonthlyIncome) total_monthly_income
# FROM attrition_records
# GROUP BY Department
# ORDER BY Department DESC;
# Out:
#    postgresql://postgres:***@localhost/myDB
#  * sqlite:///db/attr_data.db
# Done.
# [('Sales', 6207582),
#  ('Research & Development', 12072568),
#  ('Human Resources', 838468)]

# %%
# %%sql
#
# SELECT AVG(total_monthly_income) avg_total_monthly_income
#     FROM (SELECT Department, SUM(MonthlyIncome) total_monthly_income
#                 FROM attrition_records
#                 GROUP BY Department
#                 ORDER BY Department DESC) AS temp;
# Out:
#    postgresql://postgres:***@localhost/myDB
#  * sqlite:///db/attr_data.db
# Done.
# [(6372872.666666667,)]

# %%
# %%sql
#
# SELECT ROUND(AVG(total_monthly_income),2) avg_total_monthly_income
#     FROM (SELECT Department, SUM(MonthlyIncome) total_monthly_income
#                 FROM attrition_records
#                 GROUP BY Department
#                 ORDER BY Department DESC) AS temp;
# Out:
#    postgresql://postgres:***@localhost/myDB
#  * sqlite:///db/attr_data.db
# Done.
# [(6372872.67,)]

# %%
# %%sql
#
# SELECT Department, SUM(MonthlyIncome) total_monthly_income
# FROM attrition_records
# GROUP BY Department
# HAVING total_monthly_income > (SELECT ROUND(AVG(total_monthly_income),2) avg_total_monthly_income
#                                 FROM (SELECT Department, SUM(MonthlyIncome) total_monthly_income
#                                             FROM attrition_records
#                                             GROUP BY Department
#                                             ORDER BY Department DESC) AS temp);
# Out:
#    postgresql://postgres:***@localhost/myDB
#  * sqlite:///db/attr_data.db
# Done.
# [('Research & Development', 12072568)]

# %%
# %%sql
#
# WITH t1 AS
#         (SELECT Department, SUM(MonthlyIncome) total_monthly_income
#         FROM attrition_records
#         GROUP BY Department)
#
# SELECT * FROM t1;
# Out:
#    postgresql://postgres:***@localhost/myDB
#  * sqlite:///db/attr_data.db
# Done.
# [('Human Resources', 838468),
#  ('Research & Development', 12072568),
#  ('Sales', 6207582)]

# %%
# %%sql
#
# WITH t1 AS
#         (SELECT Department, SUM(MonthlyIncome) total_monthly_income
#         FROM attrition_records
#         GROUP BY Department)
#
# SELECT * FROM t1
# WHERE total_monthly_income > (SELECT ROUND(AVG(total_monthly_income),2) avg_total_monthly_income
#                                 FROM t1
#                               ORDER BY Department DESC);
# Out:
#    postgresql://postgres:***@localhost/myDB
#  * sqlite:///db/attr_data.db
# Done.
# [('Research & Development', 12072568)]

# %%
# Out:
# 4

# %%
# Step 1

# %%
# %%sql
#
# SELECT Department, SUM(MonthlyIncome) total_monthly_income
# FROM attrition_records
# GROUP BY Department;

# %%
# Step 2

# %%
# %%sql
#
# SELECT ROUND(AVG(total_monthly_income), 2) avg_total
# FROM (SELECT Department, SUM(MonthlyIncome) total_monthly_income
#         FROM attrition_records
#         GROUP BY Department) temp;

# %%
# Step 3

# %%
# %%sql
#
# SELECT Department, SUM(MonthlyIncome) total_monthly_income
#     FROM attrition_records
#     GROUP BY Department
# HAVING total_monthly_income > (SELECT ROUND(AVG(total_monthly_income), 2) avg_total
#                                 FROM (SELECT Department, SUM(MonthlyIncome) total_monthly_income
#                                         FROM attrition_records
#                                         GROUP BY Department) temp);

# %% [markdown]
# ### Cleaner Version
#
# * Using **`WITH`** Clause

# %%
# %%sql
#
# WITH salary_sum AS
#     (SELECT Department, SUM(MonthlyIncome) total_monthly_income
#         FROM attrition_records
#         GROUP BY Department)
# SELECT *
#     FROM salary_sum
# WHERE total_monthly_income > (SELECT ROUND(AVG(total_monthly_income), 2) avg_total
#                                 FROM salary_sum);

# %% [markdown]
# ### CASE CLAUSE
#
# #### SYNTAX:
#
# ```sql
# SELECT column_1, column_2, column_3,
# CASE
#     WHEN condition_1 THEN result_1
#     WHEN condition_2 THEN result_2
#     ...
#     WHEN condition_n THEN result_n
#     ELSE result_n+1
# END AS new_column
# FROM table_name;
#
# ```

# %%
# %%sql
#
# SELECT id, Gender, Age, Department, MonthlyIncome
#     FROM attrition_records
# LIMIT 20;
# Out:
#    postgresql://postgres:***@localhost/myDB
#  * sqlite:///db/attr_data.db
# Done.
# [(1, 'Female', 41, 'Sales', 5993),
#  (2, 'Male', 49, 'Research & Development', 5130),
#  (3, 'Male', 37, 'Research & Development', 2090),
#  (4, 'Female', 33, 'Research & Development', 2909),
#  (5, 'Male', 27, 'Research & Development', 3468),
#  (6, 'Male', 32, 'Research & Development', 3068),
#  (7, 'Female', 59, 'Research & Development', 2670),
#  (8, 'Male', 30, 'Research & Development', 2693),
#  (9, 'Male', 38, 'Research & Development', 9526),
#  (10, 'Male', 36, 'Research & Development', 5237),
#  (11, 'Male', 35, 'Research & Development', 2426),
#  (12, 'Female', 29, 'Research & Development', 4193),
#  (13, 'Male', 31, 'Research & Development', 2911),
#  (14, 'Male', 34, 'Research & Development', 2661),
#  (15, 'Male', 28, 'Research & Development', 2028),
#  (16, 'Female', 29, 'Research & Development', 9980),
#  (17, 'Male', 32, 'Research & Development', 3298),
#  (18, 'Male', 22, 'Research & Development', 2935),
#  (19, 'Female', 53, 'Sales', 15427),
#  (20, 'Male', 38, 'Research & Development', 3944)]

# %%
# %%sql
#
# SELECT id, Gender, Age, Department, MonthlyIncome,
#     CASE
#         WHEN MonthlyIncome < 3000 THEN "Low earner!"
#         WHEN MonthlyIncome < 6500 THEN "Moderate earner"
#         ELSE "High earner!"
#         END AS grade
#     FROM attrition_records
# LIMIT 20;
# Out:
#    postgresql://postgres:***@localhost/myDB
#  * sqlite:///db/attr_data.db
# Done.
# [(1, 'Female', 41, 'Sales', 5993, 'Moderate earner'),
#  (2, 'Male', 49, 'Research & Development', 5130, 'Moderate earner'),
#  (3, 'Male', 37, 'Research & Development', 2090, 'Low earner!'),
#  (4, 'Female', 33, 'Research & Development', 2909, 'Low earner!'),
#  (5, 'Male', 27, 'Research & Development', 3468, 'Moderate earner'),
#  (6, 'Male', 32, 'Research & Development', 3068, 'Moderate earner'),
#  (7, 'Female', 59, 'Research & Development', 2670, 'Low earner!'),
#  (8, 'Male', 30, 'Research & Development', 2693, 'Low earner!'),
#  (9, 'Male', 38, 'Research & Development', 9526, None),
#  (10, 'Male', 36, 'Research & Development', 5237, 'Moderate earner'),
#  (11, 'Male', 35, 'Research & Development', 2426, 'Low earner!'),
#  (12, 'Female', 29, 'Research & Development', 4193, 'Moderate earner'),
#  (13, 'Male', 31, 'Research & Development', 2911, 'Low earner!'),
#  (14, 'Male', 34, 'Research & Development', 2661, 'Low earner!'),
#  (15, 'Male', 28, 'Research & Development', 2028, 'Low earner!'),
#  (16, 'Female', 29, 'Research & Development', 9980, None),
#  (17, 'Male', 32, 'Research & Development', 3298, 'Moderate earner'),
#  (18, 'Male', 22, 'Research & Development', 2935, 'Low earner!'),
#  (19, 'Female', 53, 'Sales', 15427, None),
#  (20, 'Male', 38, 'Research & Development', 3944, 'Moderate earner')]

# %% [markdown]
# CASE
#     WHEN ... THEN
#     WHEN ... THEN
#        ...
#    ELSE
#    END AS new_col

# %% [markdown]
# ### Additional Resources
#
# * [Sub-queries](https://www.youtube.com/watch?v=nJIEIzF7tDw&t=3108s)
